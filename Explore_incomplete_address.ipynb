# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
raw_df = pd.read_csv('data/train.csv')

# %%
df = raw_df.copy()

# %%
df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1            1                                 aye, jati sampurna
# 2            2               setu siung 119 rt 5 1 13880 cipayung
# 3            3                               toko dita, kertosono
# 4            4                                      jl. orde baru
# ...        ...                                                ...
# 299995  299995               jend ahmad yani 331 kertasari ciamis
# 299996  299996                 raya cila kko, cilandak timur kel.
# 299997  299997                     tanjung gusta jl. yaya 2 no 17
# 299998  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999  299999          jaya maspion permata blok beryl b2  no.58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                               /
# 2                                          /siung
# 3                                      toko dita/
# 4                                  /jl. orde baru
# ...                                           ...
# 299995                           /jend ahmad yani
# 299996                             /raya cila kko
# 299997                                          /
# 299998                                taman asri/
# 299999                      jaya maspion permata/
#
# [300000 rows x 3 columns]

# %%
df['POI'] = df['POI/street'].str.split('/', expand = True)[0]
df['street'] = df['POI/street'].str.split('/', expand = True)[1]

# %%
df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1            1                                 aye, jati sampurna
# 2            2               setu siung 119 rt 5 1 13880 cipayung
# 3            3                               toko dita, kertosono
# 4            4                                      jl. orde baru
# ...        ...                                                ...
# 299995  299995               jend ahmad yani 331 kertasari ciamis
# 299996  299996                 raya cila kko, cilandak timur kel.
# 299997  299997                     tanjung gusta jl. yaya 2 no 17
# 299998  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999  299999          jaya maspion permata blok beryl b2  no.58
#
#                                        POI/street                   POI  \
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                               /
# 2                                          /siung
# 3                                      toko dita/             toko dita
# 4                                  /jl. orde baru
# ...                                           ...                   ...
# 299995                           /jend ahmad yani
# 299996                             /raya cila kko
# 299997                                          /
# 299998                                taman asri/            taman asri
# 299999                      jaya maspion permata/  jaya maspion permata
#
#                                           street
# 0       jl kapuk timur delta sili iii lippo cika
# 1
# 2                                          siung
# 3
# 4                                  jl. orde baru
# ...                                          ...
# 299995                           jend ahmad yani
# 299996                             raya cila kko
# 299997
# 299998
# 299999
#
# [300000 rows x 5 columns]

# %%
# create new column for boolean value which tells which row has incomplete address
flags = []
for row in tqdm(df.itertuples(index = False), total = len(df)):
    flags.append(row[1].find(row[3]) == -1 or row[1].find(row[4]) == -1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 300000/300000 [00:00<00:00, 526800.40it/s]

# %%
df['POI/street not exact in raw_address'] = flags

# %%
incomplete_address = df[df['POI/street not exact in raw_address']==True].drop(['id','POI','street','POI/street not exact in raw_address'], axis = 1)

# %%
# all rows with incomplete address
pd.set_option('display.max_rows', 100)
pd.set_option('max_colwidth', 400)
incomplete_address.head(100)
# Out:
#                                                                                  raw_address  \
# 10                                            cikahuripan sd neg boj 02 klap boj, no 5 16877
# 11                                                                              yaya atohar,
# 20                                                                            toko bang ajs,
# 40                                                     mar tabl metro iringmulyo metro timur
# 44                                                                         sd neg 12 anggrek
# 48                                                              rumah makan pela, raya jomb,
# 69                                                            cak 11 nagasari karawang barat
# 74                                                            rnd prin, gang pinak, sukarame
# 76                                          pp minhajutt, kh abdul manan, sumberberas muncar
# 77                                                                          tk islam daruss,
# 79                           kemb jepun, no 192 bint jaya ud, rw 1 bongkaran pabean cantikan
# 86                                             simpang tiga kah nasu no 112 28284 bukit raya
# 95                                                                            cau terr, gal,
# 100                                            kedai tenun jep senn, kota bumi, kebon melati
# 110                                                          cv. hin oto kenc, sido ii, q 29
# 117                                                                ahmad dah iv kukusan beji
# 118                                                 caval pizz, dip ukur, lebak gede coblong
# 128                                                                                    grey,
# 130                                                mangla rege no h1 3 cimekar kel. cileunyi
# 134                                                             beng las deny, mendalanwangi
# 135            cipinang besar selatan lintas ibadah, cipi jaya 1a no 3 rw 7 13410 jatinegara
# 137                                                                          ber nadah agung
# 138                                            sd bust islamiah, andi pang petta panakkukang
# 144                                         sd neg palumbungan 1, perum wirasana purbalingga
# 152                                 ujung harapan, no 48a pd. karya warga mand cimb, bahagia
# 155                                   prim warna dan rekan kembang jeruk iv, tlogosari kulon
# 157                                                              alun - alun kuli nusan, kar
# 161  kantor bupati tapa sela serma lian kos, wek ii padang sidempuan utara (padangsidimpuan)
# 166                                                                   smk karya pemban, pon,
# 169                                         taman mer, 13 electr laun system, 2 meruya utara
# 181                                            lelly bout, sum mekar babakan babakan ciparay
# 184                                                          pasi redjeki, man kerto v, mojo
# 187                                                stati accessories roxy mas, cideng gambir
# 188                                                kan desa sumber wangi tps 1, sumber wangi
# 190                                         pang rambut asgar raya kp utan setu, 32 cibitung
# 192                          aempe pluit bat raya pt, soek hatta, no 732 mekar mulya cinambo
# 194                                                                         tk 42 zahra, par
# 198                                             notaris dan ppat emmy halim, sh., mand utara
# 199                                                  beng spesia ac mobil ac rio, ling sala,
# 203                                                        pahl no 6 dpc federasi lome sbsi,
# 205                                                                        ged bersau, pen 1
# 207                                                     mie dan nasi gor pak doey, yos suda,
# 220                                                             war sahabat raya bukit tingg
# 221                                                    waro bakso bunda pampangan, pampangan
# 225                       duren tiga graha mamp 2nd floor raya mamp prap 100 rt 2 1 pancoran
# 227                                       wisnu elektr, raya maja ranca, bojongloa rancaekek
# 237                                                            headmost bkl, putri gad cemp,
# 241                          sayur segar dan semb ibu sur parangt, brontokusuman mantrijeron
# 242                                                            kan desa sumur musuk boyolali
# 251                                      rumah cuci ria cemp besar, mawar banjarmasin tengah
# 252                                                             ba terp an nur, lemahwungkuk
# 255                                                                kan bupati asa mekar baru
# 259                                                       raya pon benda, war nasi cipunjur,
# 265                                                                     tb. kenc, pulau sula
# 266                                                  t-sh design store, vete cilacap selatan
# 275                    she bea hair and spa, dr. soet, no 19c sungai bangkong pontianak kota
# 287                         jaja polet dan vari, k h abdul halim majalengka kulon majalengka
# 288                                                                                  indocar
# 289                             puskesmas mekar, prof. dr. ir. sut, mekar sari rangkasbitung
# 297                                                          toko tyana modi, klepu kranggan
# 302                                         jaya makh konsu, adonis samad, panarung pahandut
# 306                                                        west union, hus sast, no 194 rw 8
# 308                                                      al barokah serv motor, stas ker api
# 315                                                   pab dolomit maros, tenrigangkae mandai
# 317                                      pulori, no ar1 7 gamisalila hijab store, jaka setia
# 323                                                          kawat pena batu, tanah merdeka,
# 326                                                          kedai lup 22, tol waru jua rw 9
# 327                                                                     kar utara banyumanik
# 328          rumah makan citra panyileukan komp bumi panyileukan, cipadung kidul panyileukan
# 331                                                                    mush pare plosoklaten
# 342                                                                             cosmat kejak
# 346                                                            lom vape store, sriwi mataram
# 347                                  sam ratul, k'kini kor & indonesian restoran, ranowangko
# 357                                                    chat terasutra bogor, pajaj indah ii,
# 363                                                          maka d5, cipu 1, kebayoran lama
# 366                                                  dpc asosiasi kontraktor lis, kolo sugi,
# 370                                      ad sandi cakra prat pt, pulau karam, kampung pondok
# 372                                                    slta kart, budi kemul, kampung pelita
# 386                                                                                 nur cho,
# 387                                                          dony batu, bek barat rawa bunga
# 392                                                                   segar hara, bukit tung
# 393                                                                            miftahul jan,
# 394                                                                        arni souv, porong
# 399                                        sekretariat uppkh kecamatan suko jend gatot subr,
# 405                                                toko coun handphone raya kalija, kalijati
# 411                                                          cleine appa, simo gun i sawahan
# 424                                                                                 kan upk,
# 436                                                    taman chem jati, pangkalanjati cinere
# 440                                                         ayam penyet, r. wol mongin, bahu
# 444                                                                war fikri, maulana yusuf,
# 446                                               sd neg ngembeh i, maysend h. soem, ngembeh
# 459                                                           votw co store, waturen, panjer
# 468                                           dok wahi no 46 noyontaan rw 6 pekalongan timur
# 469                                                                  maxime ren kam sragen-,
# 473                                                     toko wad, peta no 54 bojongloa kaler
# 490                                                             sem 1, no 278 toi pertamina,
# 492                                                                  edow cof, ngunut ngunut
# 494                                                                             balige fash,
# 495                                                                              bag resort,
# 496                                                                 toko sol, moch toha muka
#
#                                                   POI/street
# 10                              sd negeri bojong 02/klap boj
# 11                                       yayasan atohariyah/
# 20                                        toko bangunan ajs/
# 40                                     markaz tabligh metro/
# 44                                     sd negeri 12 anggrek/
# 48                             rumah makan pelangi/raya jomb
# 69                                                   /cakrad
# 74                                   rnd printing/gang pinak
# 76                         pp minhajutthollab/kh abdul manan
# 77                                      tk islam darussalam/
# 79                                bintang jaya ud/kemb jepun
# 86                                              /kaharu nasu
# 95                                        causal terrace/gal
# 100                    kedai tenun jepara sennaart/kota bumi
# 110                           cv. hingdi oto kencana/sido ii
# 117                                         /ahmad dahlan iv
# 118                              cavallino pizzaria/dip ukur
# 128                                                 grey101/
# 130                                         /manglayang rege
# 134                                        bengkel las deny/
# 135                           lintas ibadah/cipinang jaya 1a
# 137                                      berkat nadah agung/
# 138                     sd bustanul islamiah/andi pang petta
# 144                   sd negeri palumbungan 1/perum wirasana
# 152               pd. karya warga mandiri cimb/ujung harapan
# 155                primaadi warna dan rekan/kembang jeruk iv
# 157                        alun - alun kuliner nusantara/kar
# 161            kantor bupati tapanuli selatan/serma lian kos
# 166                                smk karya pembangunan/pon
# 169                   electrolux laundry system/taman meruya
# 181                                 lelly boutique/sum mekar
# 184                          pasifik redjeki/man kertoarjo v
# 187                           station88 accessories/roxy mas
# 188                          kantor desa sumber wangi tps 1/
# 190                   pangkas rambut asgar/raya kp utan setu
# 192                    aempe pluit bataco raya pt/soek hatta
# 194                                       tk 42 zahra/parigi
# 198           notaris dan ppat emmy halim, sh.mkn/mand utara
# 199             bengkel spesialist ac mobil ac rio/ling sala
# 203                       dpc federasi lomenik sbsi/pahlawan
# 205                                  gedung bersaudara/pen 1
# 207                 mie dan nasi goreng pak doey/yos sudarso
# 220                          warung sahabat/raya bukit tingg
# 221                           waroeng bakso bunda pampangan/
# 225                  graha mampang, 2nd floor raya/mamp prap
# 227                        wisnu elektronika/raya maja ranca
# 237                           headmost bkl/putri gad cempaka
# 241             sayur segar dan sembako ibu sur/parangtritis
# 242                        kantor desa sumur musuk boyolali/
# 251                             rumah cuci rianda/cemp besar
# 252                                       ba terpadu an nur/
# 255                                    kantor bupati asahan/
# 259                      warung nasi cipunjur/raya pon benda
# 265                                   tb. kencana/pulau sula
# 266                                t-shirt design store/vete
# 275                         she beauty hair and spa/dr. soet
# 287                   jaja polet dan variasi/k h abdul halim
# 288                                           indocarpenter/
# 289                    puskesmas mekarsari/prof. dr. ir. sut
# 297                                      toko tyana modiste/
# 302                      jaya makhasi konsultan/adonis samad
# 306                                             /hus sastran
# 308                    al barokah service motor/stas ker api
# 315                                    pabrik dolomit maros/
# 317                       gamisalila hijab store/puloriburit
# 323                         kawat penahan batu/tanah merdeka
# 326                             kedai lupita 22/tol waru jua
# 327                                            /karang utara
# 328   rumah makan citra panyileukan/komplek bumi panyileukan
# 331                                            musholla/pare
# 342                                        cosmaterial/kejak
# 346                                  lombok vape store/sriwi
# 347            k'kini korean & indonesian restoran/sam ratul
# 357                   chatime terasutra bogor/pajaj indah ii
# 363                                       makaroni d5/cipu 1
# 366                 dpc asosiasi kontraktor listri/kolo sugi
# 370                   ad sandi cakra pratama. pt/pulau karam
# 372                                  slta kartini/budi kemul
# 386                                              nur cholis/
# 387                                  dony baturaja/bek barat
# 392                                 segar harapan/bukit tung
# 393                                         miftahul jannah/
# 394                                           arni souvenir/
# 399  sekretariat uppkh kecamatan sukodono/jend gatot subroto
# 405                   toko counter handphone/raya kalijati-p
# 411                                cleine apparel/simo gun i
# 424                                              kantor upk/
# 436                                      taman chempuck/jati
# 440                            ayam penyet/r. wol monginsidi
# 444                               warteg fikri/maulana yusuf
# 446                      sd negeri ngembeh i/maysend h. soem
# 459                               votw co store/waturenggong
# 468                                             /dok wahidin
# 469                             maxime rental kamera/sragen-
# 473                                         toko wadomi/peta
# 490                                   toilet pertamina/sem 1
# 492                                             edow coffee/
# 494                                          balige fashion/
# 495                                           baguna resort/
# 496                                    toko soleha/moch toha

# %%
all_poi = np.unique(df['POI'])

# %%
'sd negeri bojong 02' in all_poi
# Out:
# True

# %%
len(np.unique(df['street']))
# Out:
# 95123

# %% [markdown]
# ## Experiments

# %%
from fast_autocomplete import AutoComplete

# %%
all_poi = sorted(all_poi)

# %%
all_poi_dict = dict()
for poi in all_poi:
    all_poi_dict[poi] = {}

# %%
all_poi_dict
# Out:
# {'': {},
#  '"taman pemuda"': {},
#  '# jagakarsa': {},
#  '# jakarta': {},
#  '# jatirahayu': {},
#  '# kali malang': {},
#  '# pasar rebo': {},
#  "'arina cell & laundry": {},
#  '(depan': {},
#  '(masuk kampus stkip)': {},
#  '(pintu belakang)': {},
#  '01 "kantor': {},
#  '02 mart': {},
#  '07 cell': {},
#  '0ncez shop': {},
#  '1 stations': {},
#  '1.4.6 kids': {},
#  "10 ten's": {},
#  '100) lotte mart': {},
#  '1001 cctv': {},
#  '117 rental mobil': {},
#  '126 cellular': {},
#  '16 car wash': {},
#  '17 mie ayam bengkel': {},
#  '18 elektronik': {},
#  '182 cell': {},
#  '19 distro box': {},
#  '1999 cell': {},
#  '1a crispy puff': {},
#  '1ciganjur': {},
#  '1mt tutup jam 20:00 wib, warung bu, kp tonggoh rt02 01 desa gunung sari kecamatan citeureup': {},
#  '1perumahan bukit waringin': {},
#  '1st floor, b 110 - trans studio mall bandung': {},
#  '1st home citraland': {},
#  '2 diva': {},
#  '2 serangkai cell': {},
#  '2 tang finest tea': {},
#  '2 x 11 kayu tanam': {},
#  '20 fit': {},
#  '2016 florist semarang': {},
#  '21 cell': {},
#  '21 cinema': {},
#  '21 cineplex': {},
#  '21 express': {},
#  '21 tk sulaeman': {},
#  '212 laundry': {},
#  '212 mart': {},
#  '212 mart jatiasih': {},
#  '216 store': {},
#  '22 twenty two salon': {},
#  '23 maticshop dan sabrina cell': {},
#  '28 cellular': {},
#  '28 dyva hotel': {},
#  '29 cell-ho': {},
#  '29 electronik': {},
#  '29coffeeshop': {},
#  '2b logistics': {},
#  '2l salon and makeup': {},
#  '2m 2mb patokan masuk dr': {},
#  '2m buka 24 jam': {},
#  '2nd floor gedung multy purpose uin sunan kalijaga': {},
#  '2nr autoworks': {},
#  '2nti cybergame': {},
#  '2r computer': {},
#  '2r motor service': {},
#  '2rparty.com': {},
#  '2t net': {},
#  '3 d cell': {},
#  '3 diva': {},
#  '3 g resort': {},
#  '3 in 1': {},
#  '3 jaya ban': {},
#  '3 jaya palstik': {},
#  '3 key salon and spa': {},
#  '3 princess ocean view hotel': {},
#  '3 putra': {},
#  '3 putri ps toko kebutuhan ternak': {},
#  '3 r aluminium': {},
#  '3 saudara ponsel': {},
#  '33 cell': {},
#  '33 rumah makan': {},
#  '33 toko': {},
#  '33 truly': {},
#  '333 computer': {},
#  '35 net': {},
#  '35 nett': {},
#  '354 laundry kiloan pdk kelapa': {},
#  '36 motor': {},
#  '369 billyard': {},
#  '389 cellular': {},
#  '38th floor, pacific century place': {},
#  '39 motor. pd': {},
#  '3d baby print': {},
#  '3d balloon -ho': {},
#  '3d studio foto': {},
#  '3d3n frozen food': {},
#  '3f laundry': {},
#  '3g cell': {},
#  '3g power': {},
#  '3guitar solo': {},
#  '3i networks': {},
#  '3m cuci motor': {},
#  '3net': {},
#  '3r parris': {},
#  '3rd-4th floor gedung sekolah pascasarjana ugm': {},
#  '3s group': {},
#  '3s house bali': {},
#  '3second': {},
#  '3second margocity': {},
#  '4 bulan ustad hamzah': {},
#  '4 sekawan car wash': {},
#  '41 toko': {},
#  '44 car wash': {},
#  '44 trans': {},
#  '45': {},
#  '45 auto cafe & resto': {},
#  '45 fitnes': {},
#  '45 gudang': {},
#  '45 residence': {},
#  '45 toko': {},
#  '459 street coffeeshop & cafe': {},
#  '45hefa ponsel ii': {},
#  '46 net': {},
#  '48 cell': {},
#  '49 english course': {},
#  '4g cell': {},
#  '4g cellular': {},
#  '4g centre': {},
#  '4g gemstone': {},
#  '4x parts': {},
#  '5 photo': {},
#  '5 yogya-solo': {},
#  '51 belakang, bidan dwi dan madrasah asyiratul umaru': {},
#  '527 studio music': {},
#  '531 - hokben rk jt pdg': {},
#  '547 cell': {},
#  '555': {},
#  '555 kamboja depot': {},
#  '5578 cell': {},
#  '565 laundry': {},
#  '57 computer': {},
#  '57 jaya furniture': {},
#  '5758 cell': {},
#  '5758 parfume colection': {},
#  '5758 tour and rent car': {},
#  '58 mapan': {},
#  '59 ponsel': {},
#  '6 komplek kimia farma ii': {},
#  '60 toko': {},
#  '628 tini': {},
#  '63': {},
#  '66 toko': {},
#  '666 cell': {},
#  '671 toko': {},
#  '68 computer': {},
#  '68 vapor bar n resto': {},
#  '699 mobil': {},
#  '7 camera purwokerto': {},
#  '7 eleven': {},
#  '7 lines holiday cirebon': {},
#  '7-eleven': {},
#  '70 dusun krajan kidul': {},
#  '73photoworks': {},
#  '752 driving golf': {},
#  '76 cafe': {},
#  '77 electronic toko': {},
#  '77 toko': {},
#  '77 variasi': {},
#  '78 fhoto copy': {},
#  '79 cold ac spesialis': {},
#  '7dials coffee': {},
#  '7flowers': {},
#  '7r bu reni': {},
#  '7th floor mandiri building': {},
#  '8 babadan': {},
#  '8 blok oj': {},
#  '8 istana profil': {},
#  '8 perum mustika karang satria': {},
#  '81 cellular': {},
#  '83 cell': {},
#  '838 frozen food': {},
#  '86 cell': {},
#  '86 studio': {},
#  '86 vape corner': {},
#  '87 cuci sepatu tas helm jacket jayapura': {},
#  '88': {},
#  '88 auto care-ho': {},
#  '88 cell': {},
#  '88 fashion': {},
#  '88 motor': {},
#  '888 phone cell': {},
#  '88th street': {},
#  '8oss mobil': {},
#  '8treasures jakarta': {},
#  '8war.net': {},
#  '9 kuda mas': {},
#  '91 coffee shop': {},
#  '91 toko tas import-ho': {},
#  '91net': {},
#  '928 art dan antique': {},
#  '929 gordyn': {},
#  '96shop': {},
#  '99 aluminium': {},
#  '99 cling': {},
#  '99 games': {},
#  '99 laundry dan chem': {},
#  '99 perus': {},
#  '99 security professional system. pt': {},
#  '999 erna cake': {},
#  '99ers coffee': {},
#  '99studioart - kado ilustrasi wajah': {},
#  '@lobby hotel sheraton': {},
#  '@niek homestay dan gallery': {},
#  'a & k': {},
#  'a atalanta': {},
#  'a bangkol': {},
#  'a belakang': {},
#  'a boutique': {},
#  'a bun tailor': {},
#  'a cell': {},
#  'a chafid': {},
#  'a collection': {},
#  'a dan b auto repair': {},
#  'a dan m snack coffee': {},
#  'a dan r jaya': {},
#  'a dan t cell': {},
#  'a four': {},
#  'a k tehnik listrik': {},
#  'a kadir toko': {},
#  'a kasoem cikini optika': {},
#  'a kasoem hearing centre': {},
#  'a kasoem optical': {},
#  'a kasoem optikal': {},
#  'a konveksi house': {},
#  'a ngop pujasera': {},
#  'a r i barbershop': {},
#  'a to z bar, wine, brasserie': {},
#  'a tong dinamo': {},
#  'a villa ubud bali by uhm': {},
#  'a x perfume': {},
#  'a&a property citraland': {},
#  'a&e collection': {},
#  'a&w': {},
#  'a&w leather seat': {},
#  'a&wan jaya motor': {},
#  "a'a gym": {},
#  "a'siek ngopi": {},
#  'a+coffee - es kopi rumahan': {},
#  'a- huang shop': {},
#  'a-yang': {},
#  'a-yong': {},
#  'a. azis': {},
#  'a. berkah pasti jaya': {},
#  'a. efendi': {},
#  'a. kasoem cikini': {},
#  'a. nasution': {},
#  'a. suriani': {},
#  'a.a. ngurah sutama': {},
#  'a.a.a. busana tradisional dan tata rias bali': {},
#  'a.j. central asia raya. pt': {},
#  'a.n purnomo': {},
#  'a.p.o distrik': {},
#  'a.s vape': {},
#  'a1 crispy fried chicken': {},
#  'a1 toko': {},
#  'a2 laundry': {},
#  'a3 cell': {},
#  'a6, perkantoran': {},
#  'a8 jasa setrika uap': {},
#  'a_dewe ban': {},
#  'aa ac': {},
#  'aa agen bus citra adi lancar': {},
#  'aa agen telor': {},
#  'aa bakery': {},
#  'aa bonsai': {},
#  'aa busana': {},
#  'aa cell': {},
#  'aa cv': {},
#  'aa decoration': {},
#  'aa decoration ud': {},
#  'aa florest': {},
#  'aa gordyn': {},
#  'aa ikat kasep': {},
#  'aa jayatex toko': {},
#  'aa mart mini market': {},
#  'aa parabot collection': {},
#  'aa photoworks studio': {},
#  'aa racing': {},
#  'aa studio foto': {},
#  'aa tenda': {},
#  'aa toko': {},
#  'aa travel': {},
#  'aa ud': {},
#  'aab cell': {},
#  'aad maheri': {},
#  'aad surya': {},
#  'aafil jaya': {},
#  'aal printing': {},
#  'aam sport': {},
#  'aamirah florist': {},
#  'aan bengkel mobil': {},
#  'aan bersaudara': {},
#  'aan cell': {},
#  'aan kopi 2': {},
#  'aan s': {},
#  'aan seluler': {},
#  'aan servis tv': {},
#  'aan suharno': {},
#  'aan waroeng and caffe': {},
#  'aang warung': {},
#  'aanugrah adi sembako': {},
#  'aarcpulau tidung': {},
#  'aaron playstation 3': {},
#  'aat cellular': {},
#  'ab cell': {},
#  'ab cellular kandangan': {},
#  'ab computer': {},
#  'ab ponsel': {},
#  'ab pro lighting dan studio record': {},
#  'ab q-lap car wash': {},
#  'ab sat 16': {},
#  'ab skatepark': {},
#  'ab surf skate clothing': {},
#  'aba ama': {},
#  'aba firdaus collection': {},
#  'aba penginapan': {},
#  'ababil tour and travel': {},
#  'abacus distribution systems indonesia, pt': {},
#  'abad dua satu eng cons cv': {},
#  'abadi': {},
#  'abadi 1': {},
#  'abadi 2': {},
#  'abadi bahagia citra pt': {},
#  'abadi bakso': {},
#  'abadi cellular': {},
#  'abadi collection': {},
#  'abadi diesel': {},
#  'abadi furniture': {},
#  'abadi game': {},
#  'abadi genteng': {},
#  'abadi genteng jatiwangi': {},
#  'abadi gypsum': {},
#  'abadi hotel yogyakarta': {},
#  'abadi interior': {},
#  'abadi jaya': {},
#  'abadi jaya 2': {},
#  'abadi jaya foto copy': {},
#  'abadi jaya listrik-ho': {},
#  'abadi jaya motor': {},
#  'abadi jaya perabot': {},
#  'abadi jaya toko': {},
#  'abadi juice': {},
#  'abadi karunia sound system dan genset': {},
#  'abadi manunggal jaya': {},
#  'abadi minang': {},
#  'abadi motor': {},
#  'abadi mukti pt': {},
#  'abadi music': {},
#  'abadi photo studio': {},
#  'abadi pt': {},
#  'abadi purwa citra': {},
#  'abadi smilynks pt': {},
#  'abadi susu': {},
#  'abadi tehnik': {},
#  'abadi toko': {},
#  'abadi tour': {},
#  'abadi ud': {},
#  'abadi. cv': {},
#  'abadi. ud': {},
#  'abaditour pekalongan': {},
#  'abah anang': {},
#  'abah faim': {},
#  'abah liong': {},
#  'abah meubel': {},
#  'abah net': {},
#  'abah udin': {},
#  'abang': {},
#  'abang adek': {},
#  'abang ban motor': {},
#  'abang cell': {},
#  'abas': {},
#  'abas arloji': {},
#  'abas baru cell': {},
#  'abason baby product industry. pt': {},
#  'abata fotokopi': {},
#  'abay net': {},
#  'abbasy': {},
#  'abbel': {},
#  'abbussalam': {},
#  'abby muslim shop': {},
#  'abc': {},
#  'abc contractor. cv': {},
#  'abc energy': {},
#  'abc galery': {},
#  'abc school': {},
#  'abd haris': {},
#  'abd. hadi': {},
#  'abd. rauf dg madang': {},
#  'abd. razaq': {},
#  'abdee fishing team 86': {},
#  'abdi agung distributor atk harga termurah': {},
#  'abdi cell': {},
#  'abdi medicca bumbak': {},
#  'abdi tour and travel': {},
#  'abdrochim servis': {},
#  'abdul ajid': {},
#  'abdul basir latuconsina & partners': {},
#  'abdul ghany motor': {},
#  'abdul goni': {},
#  'abdul hadi': {},
#  'abdul hafiz': {},
#  'abdul hakim keliat, s.h. & rekan': {},
#  'abdul haris': {},
#  'abdul holil': {},
#  'abdul jalil layangan': {},
#  'abdul kadir': {},
#  'abdul karim': {},
#  'abdul kohar': {},
#  "abdul ma'at": {},
#  'abdul manan': {},
#  'abdul qodir and partners law firm': {},
#  'abdul rahman tuhepaly, s.h. & partners': {},
#  'abdul roni': {},
#  'abdul wachit servis lampu gundi': {},
#  'abdul wahab': {},
#  'abdul wahid': {},
#  'abdullah ali bin tamim': {},
#  'abdullah books store': {},
#  'abdullah cell': {},
#  'abdullah furniture': {},
#  'abdullah thalib sh': {},
#  'abe celluler': {},
#  'abe chicken cirebon': {},
#  'abe cw': {},
#  'abe food station': {},
#  'abellatin salon dan beauty care': {},
#  'abeng fashion': {},
#  'abeng toko': {},
#  'abeta cell': {},
#  'abez zone': {},
#  'abg': {},
#  'abg sound system lighting': {},
#  'abg tailor': {},
#  'abhiseka computer': {},
#  'abi gorden dan wallpaper': {},
#  'abi jaya teknik': {},
#  'abi ponsel': {},
#  'abi shoes sport': {},
#  'abi zaen olshop': {},
#  'abid mesin': {},
#  'abidin': {},
#  'abidzar': {},
#  'abidzar led': {},
#  'abidzar parfum & laundry': {},
#  'abie cellular': {},
#  'abiee collection': {},
#  'abiel baby shop': {},
#  'abigoes laundry': {},
#  'abik': {},
#  'abika kebab': {},
#  'abil aksesoris': {},
#  'abil collection': {},
#  'abil kids': {},
#  'abil net': {},
#  'abim cell': {},
#  'abimanyu playstation': {},
#  'abion motor 3': {},
#  'abipina': {},
#  'abis': {},
#  'abitextile': {},
#  'abiyan olshop': {},
#  'abizar bird fram': {},
#  'abizhar': {},
#  'aboe laundry': {},
#  'abon ikan kerupuk ikan katebi aisyah': {},
#  'above padalarang train bridge': {},
#  'aboysnack': {},
#  'abpromosindo it event': {},
#  'abqary style': {},
#  'abr foto copy piccolo': {},
#  'abraham godjaja toko': {},
#  'abrakadabra art bnb': {},
#  'abrar reffil parfum praja': {},
#  'abrenx brenx village': {},
#  'abs bikers shop & mewa warkop': {},
#  'abs plaza auto': {},
#  'absolut catering': {},
#  'absolute badminton': {},
#  'absyar': {},
#  'abu homestay': {},
#  'abu husin2': {},
#  'abu kazzam collection': {},
#  'abu nimah sejahtera utama. pt': {},
#  'abu rifa': {},
#  'abu tailor': {},
#  "abu ya'amin": {},
#  'abu zonera': {},
#  'abuba': {},
#  'abuba steak hrpn indah': {},
#  'abuhasdha & co ltd. pt': {},
#  'aby net': {},
#  'aby phone cell': {},
#  'abz guest house': {},
#  'ac cell': {},
#  'ac jaya mobil': {},
#  'ac kuesek': {},
#  'ac laly': {},
#  'ac merah putih': {},
#  'ac mobil': {},
#  'ac mobil 2000': {},
#  'ac mobil era raflesia': {},
#  'ac mobil pkc g2': {},
#  'ac mobil rafi': {},
#  'ac mubil': {},
#  'ac refrigeration part toko': {},
#  'ac rumah': {},
#  'ac sejuk denso': {},
#  'aca on line shop': {},
#  'acacia garden': {},
#  'acai': {},
#  'acak mandiri furniture': {},
#  'acasia fashion': {},
#  'acc': {},
#  'acc astra credit leasing': {},
#  'acc furniture': {},
#  'acc hape ku': {},
#  'acc hp': {},
#  'acc jaya jakarta': {},
#  'acc motor': {},
#  'acc tailor': {},
#  'acca kappa': {},
#  'accacia salon': {},
#  'accelera dsw tyres': {},
#  'accesories 28': {},
#  'accesories hp': {},
#  'access consulting': {},
#  'access net': {},
#  'accessories bycycle shop omkbike': {},
#  'accessories mobil autofal': {},
#  'accessories motor': {},
#  'accu brasil': {},
#  'accu empat putri': {},
#  'accu zr': {},
#  'accurate business centre': {},
#  'accurate jaya computer': {},
#  'accustic indah': {},
#  'ace': {},
#  'ace aswaer': {},
#  'ace computer champion': {},
#  'ace education': {},
#  'ace hardware': {},
#  'ace hardware - mutiara taman palem': {},
#  'ace hardware home center': {},
#  'ace hardware home center - living plaza bekasi': {},
#  'ace hardware indonesia': {},
#  'ace hardware indonesia pt': {},
#  'ace hardware kelapa gading': {},
#  'aceh coffee outlet': {},
#  'aceh inti timber co ltd pt': {},
#  'aceh mulia rumah makan': {},
#  'aceh rasa utama lingke': {},
#  'aceh toys gallery': {},
#  'acen': {},
#  'aceng cell': {},
#  'aceng collection': {},
#  'acep': {},
#  'acep distributor resmi nasa': {},
#  'acer': {},
#  'acer center': {},
#  'aces smartphone service': {},
#  'ach. fudali': {},
#  'ach. sumedi': {},
#  'acha': {},
#  'achilles': {},
#  'achilles service shocbreaker': {},
#  'achmad': {},
#  'achmad ardhi rozak': {},
#  'achmad aulia rachma': {},
#  'achmad faudzy house': {},
#  'achmad rasyid hisbullah dan jerry': {},
#  'achonk photo': {},
#  'achterhuis guest house semarang': {},
#  'aci bakmi singkawang': {},
#  'aci international indonesia': {},
#  'aciak salon': {},
#  'acien pok pia': {},
#  'acik motor': {},
#  'acil bungas': {},
#  'acil wadai': {},
#  'acing': {},
#  'aciwi shop': {},
#  'acochem indonesia': {},
#  'acong': {},
#  'acong kodok goreng': {},
#  'acong perkasa': {},
#  'aconk jaya gypsum': {},
#  'acp cargo': {},
#  'acropora cottage': {},
#  'acs seat covers': {},
#  'act kantor cabang sulawesi selatan': {},
#  'active 1 cell': {},
#  'active indonesia': {},
#  'actual computer': {},
#  'acu pindang': {},
#  'acuan': {},
#  'acun': {},
#  'acun toko': {},
#  'ad': {},
#  'ad cell': {},
#  'ad computer': {},
#  'ad elekttonik servis kulkas frmesin cuci freezer': {},
#  'ad pet shop': {},
#  'ad premiere office park': {},
#  'ad sandi cakra pratama. pt': {},
#  'ada': {},
#  'ada atr cell': {},
#  'ada baru city walk area parkir lantai dasar': {},
#  'ada cell': {},
#  'ada collections': {},
#  'ada espresso bar': {},
#  'ada fashion': {},
#  'ada guest house': {},
#  'ada meubel': {},
#  'ada project': {},
#  'ada telecom': {},
#  'adail elektro': {},
#  'adam': {},
#  'adam aquarium': {},
#  'adam baharu cv': {},
#  'adam barbershop': {},
#  'adam kere bambu': {},
#  'adam kerudung': {},
#  'adam minimarket': {},
#  'adam mobil cv': {},
#  'adam ponsel': {},
#  'adam ridwan cakes': {},
#  'adam salad buah': {},
#  'adam swalayan': {},
#  'adam wiratama': {},
#  'adamsyaerra cake mart': {},
#  'adara kosmetik': {},
#  'adarasa': {},
#  'adau putra network': {},
#  'addict': {},
#  'addin art': {},
#  'addin toys suruh salatiga': {},
#  'ade': {},
#  'ade ayu': {},
#  'ade bird': {},
#  'ade collection': {},
#  'ade f': {},
#  'ade florist': {},
#  'ade hadifah': {},
#  'ade kurniati': {},
#  'ade laundry': {},
#  'ade modifikasi': {},
#  'ade pompa. cv': {},
#  'ade ponsel': {},
#  'ade print scan': {},
#  'ade ray - celebrity fitness': {},
#  'ade ruminat': {},
#  'ade tehnik konstruksi. cv': {},
#  "ade' jeans": {},
#  'adec cell': {},
#  'adeeva cake': {},
#  "adek's saloon": {},
#  'adel buah': {},
#  'adel parfume': {},
#  'adel ponsel': {},
#  'adel salon': {},
#  'adel studio musik bulian': {},
#  'adelia 2': {},
#  'adelia salon': {},
#  'adelia tour & travel': {},
#  'adella armah toko': {},
#  'adem ayem': {},
#  'aden resi': {},
#  'adennan meubel': {},
#  'aderio rental rental mobil bangka': {},
#  'aderlina marpaung & partners': {},
#  'ades alfindo putrasetia pt': {},
#  'ades water indonesia pt': {},
#  'adetex pusat grosir pakaian': {},
#  'adf': {},
#  'adfa cell': {},
#  'adha ponsel': {},
#  'adhe herwindo at home': {},
#  'adhe toko': {},
#  'adhellia laundry': {},
#  'adhi': {},
#  'adhi metalindo pt': {},
#  'adhi putragraha sentosa pt': {},
#  'adhi semesta teknik. cv': {},
#  'adhi warna photo': {},
#  'adhie tailor': {},
#  'adhiim freid chicken': {},
#  'adhika darma sejati pt': {},
#  'adhika swara pt': {},
#  'adhisti spa': {},
#  'adhiswara radio': {},
#  'adhitya andrebina agung. pt': {},
#  'adhitya chandra export': {},
#  'adhye n friend studio': {},
#  'adi': {},
#  'adi ari villa': {},
#  'adi beton perkasa 2': {},
#  'adi computer': {},
#  'adi daya solusi': {},
#  'adi dental': {},
#  'adi foto digital': {},
#  'adi garage nouvo parts': {},
#  'adi glass': {},
#  'adi gordyn': {},
#  'adi gunawansyah sh and partners': {},
#  'adi halalmart': {},
#  'adi jaya': {},
#  'adi jaya abadi. cv': {},
#  'adi jaya bengkel': {},
#  'adi jaya electro': {},
#  'adi jaya elektronik': {},
#  'adi jaya meubel': {},
#  'adi jaya motor': {},
#  'adi jaya ponsel': {},
#  'adi jaya putra': {},
#  'adi jaya sarana. cv': {},
#  'adi kartika utama': {},
#  'adi karya': {},
#  'adi luhung abadi pt': {},
#  'adi makmur sentosa. pt': {},
#  'adi mandiri': {},
#  'adi mandiri sakti. pt': {},
#  'adi motor': {},
#  'adi multi sarana pt': {},
#  'adi mustika meubel': {},
#  'adi oli toko': {},
#  'adi pasee jaya': {},
#  'adi perkasa anugrah pt': {},
#  'adi photo': {},
#  'adi praya cv': {},
#  'adi putra bengkel mitra bersaudara': {},
#  'adi putra motor ud': {},
#  'adi putra. cv': {},
#  'adi roso': {},
#  'adi sablon': {},
#  'adi salon': {},
#  'adi sarana armada. pt': {},
#  'adi surya abadi. cv': {},
#  'adi surya. cv': {},
#  'adi teknik. cv': {},
#  'adi toko': {},
#  'adi trans logistics pt': {},
#  'adi wiraguna usaha tama. pt': {},
#  'adiantum agency': {},
#  'adibba rental ps3 dan ps2': {},
#  'adicell': {},
#  'adicipta': {},
#  'adidas': {},
#  'adidas cuci motor': {},
#  'adidas grand indonesia': {},
#  'adidas toko': {},
#  'adidaya': {},
#  'adiguna shipyard pt': {},
#  'adijaya gypsum': {},
#  'adijaya motor bengkel': {},
#  'adijaya trading cv': {},
#  'adika cell': {},
#  'adikarma & rekan': {},
#  'adikuarta perdana. pt': {},
#  'adil': {},
#  'adil bahagia furniture': {},
#  'adil collection': {},
#  'adinda collection supplier hijab stuff': {},
#  'adinegoro': {},
#  'adinuansa wiraswasta gemilang pt': {},
#  'adiona sejahtera advertising': {},
#  'adioro soetojo dr, drg ms spkg': {},
#  'adiprabu gallery': {},
#  'adiputra ud': {},
#  'adira club member': {},
#  'adira dinamika': {},
#  'adira dinamika multi finance pt tbk': {},
#  'adira dinamika multifinance': {},
#  'adira faces of indonesia': {},
#  'adira finance': {},
#  'adira finance kabanjahe': {},
#  'adira finance,tbk, pt': {},
#  'adira kredit': {},
#  'adira motor': {},
#  'adira quantum multifinance. pt': {},
#  'adira tebet mobil': {},
#  'adiral pt': {},
#  'adirand multi millenia pt': {},
#  'adirasa': {},
#  'adisa accesories': {},
#  'adisarana purwakrida': {},
#  'adisra': {},
#  'aditama': {},
#  'aditama dan napuri': {},
#  'aditania primakarsa perdana pt': {},
#  'aditya aquarium toko ikan hias': {},
#  'aditya cell': {},
#  'aditya collection': {},
#  'aditya doorsmeer': {},
#  'aditya hotel': {},
#  'aditya laundry': {},
#  'aditya motor': {},
#  'aditya pt': {},
#  'aditya rias pengantin': {},
#  'aditya sablon': {},
#  'aditya salon': {},
#  'aditya shop': {},
#  'aditya tours & rent car': {},
#  'aditya ukir 2': {},
#  'aditya vape shop': {},
#  'aditya wijaya': {},
#  'adiwiyata': {},
#  'adiyasa': {},
#  'adiz souvenir': {},
#  'adiza photography': {},
#  'adjiz & yani salon': {},
#  'adlan electronic': {},
#  'adli hakim apriliawan cv': {},
#  'adly putri cell': {},
#  'adman perobot': {},
#  'admedika': {},
#  'administrasi, pembangunan setda': {},
#  'admore corp. pt': {},
#  'adna ud': {},
#  'adnan arminareka tour dan travel': {},
#  'adnan jaya tailor': {},
#  'adnan ppob': {},
#  'adnan tax consultant': {},
#  'adnyani collection': {},
#  'adorableprojects': {},
#  'adp sinar makmur': {},
#  'adr variasi': {},
#  'adreena hijab': {},
#  'adrem aneka rasa mbak dewi': {},
#  'adres jaya motor aksesoris': {},
#  'adri putra tour travel & umroh': {},
#  'adrian armando': {},
#  'adrian cell': {},
#  'adrinusa esatama pt': {},
#  'adsindo tama': {},
#  'adtyjln': {},
#  'aduen card ii': {},
#  'aduma jaya toko': {},
#  'advance': {},
#  'advance festival city link': {},
#  'advanced computer training center': {},
#  'adventist aviation indonesia office': {},
#  'adventure house': {},
#  'adventure travel': {},
#  'adventures summerland': {},
#  'advertising & digital printing idalia': {},
#  'advertising dan tech yoben': {},
#  'advertising zeefa': {},
#  'advocat agnes margono, s.h': {},
#  'advokat & konsultan hukum rony na sh': {},
#  'advokat & konsultan hukum yoyo caryonih, sh & rekan': {},
#  'advokat & penasehat hukum moh ridwan sh': {},
#  'advokat & penasihat hukum lutfi sanaki & rekan': {},
#  'advokat & pengacara watiran, s.h., m.h.': {},
#  'advokat antoni silo dan associates': {},
#  'advokat gunarto, s.h. & rekan': {},
#  'advokat h yusrizal ghazali,s.h.,m.h': {},
#  'advokat lbh indonesia': {},
#  'advokat meina i.n simanungkalit, sh': {},
#  'advokat misrullani, sh & rekan': {},
#  'advokat pengacara & penasehat hukum charles s': {},
#  'advokat sm law office': {},
#  'advokat zahir rusyad, sh. m. hum': {},
#  'adwaya paint': {},
#  'ady cell': {},
#  'ady clothing.wadi olshop': {},
#  'ady jaya motor': {},
#  'ady salon': {},
#  'adyar perkasa .pt': {},
#  'adyastha motor': {},
#  'adyfara': {},
#  'adzikra': {},
#  'adzkia cell': {},
#  'adzkia fotokopi & percetakan': {},
#  'adzkia kids wear': {},
#  'adzkiya': {},
#  'adzkiya advertising': {},
#  'ae gypsum': {},
#  'aedelia cell': {},
#  'aeini salon': {},
#  'aek kanopan': {},
#  'aek pancur kel.': {},
#  'aempe pluit bataco raya pt': {},
#  'aemtobe premiere': {},
#  'aeno': {},
#  'aeobah': {},
#  'aeon mall 3rd floor': {},
#  'aeps': {},
#  'aerialrows': {},
#  'aerin gorden': {},
#  'aero': {},
#  'aero boutique': {},
#  'aerofood acs building': {},
#  'aeroland residence': {},
#  'aeropolis apartemen': {},
#  'aeropolis complex': {},
#  'aesthetic specialist dental klinik': {},
#  'aesthetic studio': {},
#  'aestia & co': {},
#  'afan cell': {},
#  'afan net': {},
#  'afandy florist': {},
#  'afar': {},
#  'afara wedding': {},
#  'afat surajati': {},
#  'afc fried chicken': {},
#  'afda travel': {},
#  'afdal': {},
#  'afdar': {},
#  'afdema nusantara, pt': {},
#  'afdil fashion': {},
#  'afdilla': {},
#  'afe net dan de c afe coffee': {},
#  'afen image nathaniel global toko': {},
#  'afendi kupi': {},
#  'affal jaya ss': {},
#  'affan': {},
#  'affansa phone service': {},
#  'affi farma pt': {},
#  'affordable tour & activities in bali': {},
#  'afgan nada entertaiment': {},
#  'afi group (amanah fadhilah insani)': {},
#  'afi jaya 2': {},
#  'afi laundry': {},
#  'afi ristiyana': {},
#  'afiat bestari santosa pt': {},
#  'afie collection olshop': {},
#  'afie foto': {},
#  'afif crc jaya': {},
#  'afif pulsa': {},
#  'afif shoes': {},
#  'afifa': {},
#  'afifa cell': {},
#  'afifah': {},
#  'afifah computer': {},
#  'afifah khoirunnisah': {},
#  'afifah laundry': {},
#  'afiffa cell': {},
#  'afika jus buah dan bubble drink': {},
#  'afiliasi shop': {},
#  'afiq': {},
#  'afiq tailor': {},
#  'afit motor': {},
#  'afit tailor': {},
#  'afiza collection': {},
#  'afizah salon': {},
#  'afkar butik': {},
#  'afla bio fresh': {},
#  'aflah laundry': {},
#  'aflah moeslim collection': {},
#  'afnan collection': {},
#  'afninar': {},
#  'afo': {},
#  'afphotography': {},
#  'afrakids gorontalo': {},
#  'afri. cv': {},
#  'afrian motor': {},
#  'afrianto': {},
#  'afriman': {},
#  'afriza collection': {},
#  'afs hijab store': {},
#  'afterall store': {},
#  'afui kin ci pan': {},
#  'afzacom': {},
#  'ag air gunung': {},
#  'ag fried chicken': {},
#  'ag glass': {},
#  'ag jeans': {},
#  'ag kaca aluminium & kayu': {},
#  'ag servis': {},
#  'ag steak & ribs': {},
#  'ag textil toko': {},
#  'ag. cellular': {},
#  'agadipa. pt': {},
#  'againt street shop': {},
#  'agam benoa cargo. pt': {},
#  'agam creative computer': {},
#  'aganio optik': {},
#  'agape church samarinda': {},
#  'agape regenci': {},
#  'agarista': {},
#  'agashi cell': {},
#  'agatis meubel': {},
#  'agatos jatiasih': {},
#  'agave laundry': {},
#  'age bakti purnama pt': {},
#  'agen & grosir sancu bogor': {},
#  'agen accesories dan mainan': {},
#  'agen afrakids': {},
#  'agen ahad - net internasional': {},
#  'agen air axology': {},
#  ...}

# %%
autocomplete = AutoComplete(words=all_poi_dict)

# %%
autocomplete.search(word='electr laun system')
# Out:
# [['electra'], ['electra jaya']]

# %%
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# %%
'LnwZa/JomLnwKing'.find('Lnw', 'LnwZa/JomLnwKing'.find('/'))
# Out:
# 9

# %%
'yayasan atohariyah' in all_poi
# Out:
# True

# %%
len(all_poi)
# Out:
# 93412

# %%
process.extract('yaya atohar', choices = all_poi, limit = 5)
# Out:
# [('toha', 90), ('ay ay', 86), ('hari', 77), ('yahya', 76), ('yayak', 76)]

# %%
fuzz.ratio('yaya atohar,','yayasan atohariyah')
# Out:
# 73

# %%
fuzz.ratio('yaya atohar,','toha')
# Out:
# 50

# %%
process.extractOne('cikahuripan sd neg boj 02 klap boj, no 5 16877', all_poi)
# Out:
# ('02 mart', 86)

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.1.0-py3-none-any.whl (112 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.1.0

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="my-app")
location = geolocator.geocode("cikahuripan sd neg boj 02 klap boj")
print(location.address)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-a3a03c6e88e4> in <module>
#       1 geolocator = Nominatim(user_agent="my-app")
#       2 location = geolocator.geocode("cikahuripan sd neg boj 02 klap boj")
# ----> 3 print(location.address)
#
# AttributeError: 'NoneType' object has no attribute 'address'
