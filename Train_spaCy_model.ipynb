# %%
import spacy
import pickle
import random
import warnings

from tqdm import tqdm
from spacy.util import minibatch, compounding
from spacy.training import Example
from pathlib import Path

# %%
with open('pickle/spacy_train.pickle','rb') as file:
    train_data = pickle.load(file)

# %%
train_data
# Out:
# [('jl kapuk timur delta sili iii lippo cika 11 a cicau cikarang pusat',
#   {'entities': [(0, 40, 'STREET')]}),
#  ('aye, jati sampurna', {'entities': []}),
#  ('setu siung 119 rt 5 1 13880 cipayung', {'entities': [(5, 10, 'STREET')]}),
#  ('toko dita, kertosono', {'entities': [(0, 9, 'POI')]}),
#  ('jl. orde baru', {'entities': [(0, 13, 'STREET')]}),
#  ('raya samb gede, 299 toko bb kids',
#   {'entities': [(20, 32, 'POI'), (0, 14, 'STREET')]}),
#  ('kem mel raya, no 4 bojong rawalumbu rt 1 36 rawalumbu',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('tela keuramat kuta alam', {'entities': [(0, 4, 'STREET')]}),
#  ('gg. i wates magersari', {'entities': [(0, 5, 'STREET')]}),
#  ('bunga ncole ix 2', {'entities': [(0, 14, 'STREET')]}),
#  ('cikahuripan sd neg boj 02 klap boj, no 5 16877',
#   {'entities': [(26, 34, 'STREET')]}),
#  ('yaya atohar,', {'entities': []}),
#  ('abim ix 24 5', {'entities': [(0, 7, 'STREET')]}),
#  ('gang xiii rungkut', {'entities': [(0, 9, 'STREET')]}),
#  ('kamp utan jaya, 23 rt 3 rw 8 16433 beji', {'entities': []}),
#  ('kampung.gudang areng,desa:anyer, kecamatan:anyar, kabupaten: serang, belakang bca anyar',
#   {'entities': [(8, 20, 'POI')]}),
#  ('maru baru 2 18 marunda rt 13 3 cilincing',
#   {'entities': [(0, 11, 'STREET')]}),
#  ('pangkalan lareh kel.ikurkoto koto panjang.kec koto tangah kota padang',
#   {'entities': [(0, 15, 'POI')]}),
#  ('tanah sereal pekap raya 5 rt 9 4 11210 tambora',
#   {'entities': [(13, 23, 'STREET')]}),
#  ('tam tama barat v, banyumanik', {'entities': [(0, 16, 'STREET')]}),
#  ('toko bang ajs,', {'entities': []}),
#  ('stadion kobelete,', {'entities': [(0, 16, 'POI')]}),
#  ('tam asri, gg. 7 16 6 morokrembangan krembangan',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('ramb i, pranti', {'entities': [(0, 6, 'STREET')]}),
#  ('angg raya i, jatinegara cakung', {'entities': []}),
#  ('pondok benda bumi raya, no 9 15416 pamulang',
#   {'entities': [(13, 22, 'STREET')]}),
#  ('tajurhalang seta 58 4 16320 tajurhalang',
#   {'entities': [(12, 16, 'STREET')]}),
#  ('jln.tirta tawar, br. junjungan, ubud, barat jalan dajan rurung',
#   {'entities': [(17, 30, 'POI'), (0, 15, 'STREET')]}),
#  ('sadar i lubang buaya kel. cipayung', {'entities': [(0, 7, 'STREET')]}),
#  ('meruya selatan gg. h. juki 59 8 11610 kembangan',
#   {'entities': [(15, 26, 'STREET')]}),
#  ('nogos tlogosari kulon pedurungan', {'entities': [(0, 5, 'STREET')]}),
#  ('jl. amd, komplek borneo lestari, blok 2, no. 30',
#   {'entities': [(9, 31, 'POI'), (0, 7, 'STREET')]}),
#  ('sungai burung raya sege 78351 segedong',
#   {'entities': [(14, 23, 'STREET')]}),
#  ('perumahan bayur sarana indah blok j 5 rt :007 001',
#   {'entities': [(0, 28, 'POI')]}),
#  ('gg. per gunung pangilun padang utara', {'entities': [(0, 7, 'STREET')]}),
#  ('sal gg. iv dangin puri kaja denpasar utara',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('kamp rawa bebek 53 kota baru rt 1 15 bekasi barat',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('selam vii 27a', {'entities': [(0, 9, 'STREET')]}),
#  ('bukit kemuning lin liwa bukit kemuning',
#   {'entities': [(15, 23, 'STREET')]}),
#  ('jln raya solok pad selayo kubung', {'entities': [(0, 18, 'STREET')]}),
#  ('mar tabl metro iringmulyo metro timur', {'entities': []}),
#  ('aa gallery sport pasar muara labuh sungai pagu', {'entities': []}),
#  ('raya kopo babakan asih bojongloa kaler', {'entities': []}),
#  ('roos timur ii, 6 rt 15 5 bukit duri tebet',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('sd neg 12 anggrek', {'entities': []}),
#  ('mulia 6 gajah sakti mandau', {'entities': [(0, 5, 'STREET')]}),
#  ('gg. kera 4 mayong', {'entities': [(0, 10, 'STREET')]}),
#  ('raya cira ciracas ciracas', {'entities': [(0, 9, 'STREET')]}),
#  ('rumah makan pela, raya jomb,', {'entities': [(18, 27, 'STREET')]}),
#  ('kebalen raya babe 43 6 babelan', {'entities': [(8, 17, 'STREET')]}),
#  ('pt. hugo global logistik jl. lavionda blok f11 no. 5 griya loka, bsd city tangerang 15321',
#   {'entities': [(65, 73, 'POI'), (25, 37, 'STREET')]}),
#  ('jatiwarna fajar motor, raya han no 9 pondok melati',
#   {'entities': [(10, 21, 'POI'), (23, 31, 'STREET')]}),
#  ('mah iv 403 margahayu rt 5 rw 16 bekasi timur',
#   {'entities': [(0, 6, 'STREET')]}),
#  ('mas ii 24 rt 2 11', {'entities': [(0, 6, 'STREET')]}),
#  ('samping kiri sd inp. 3 77 tellongeng desa tellongeng kec. mare kab. bone',
#   {'entities': [(58, 72, 'POI')]}),
#  ('beng las listrik rah, raya sorea, cangkuang',
#   {'entities': [(22, 32, 'STREET')]}),
#  ('asrama cpm, jl. lagoa kanal 2a rt. 01 rw. 16, kel. bawang',
#   {'entities': [(0, 10, 'POI'), (12, 30, 'STREET')]}),
#  ('kebon manggis matr 122 3 matraman', {'entities': [(14, 18, 'STREET')]}),
#  ('matr dalam i, 13 pegangsaan rw 8 menteng',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('ple bane siantar utara', {'entities': [(0, 3, 'STREET')]}),
#  ('jl. alm mampang prapatan mampang prapatan',
#   {'entities': [(0, 7, 'STREET')]}),
#  ('sedu put, 8 ilir ilir timur ii', {'entities': []}),
#  ('jl sunan giri, no 22 pondok pucung', {'entities': []}),
#  ('toko depa sambu,', {'entities': [(0, 9, 'POI'), (10, 15, 'STREET')]}),
#  ('cibuluh pangk raya 1 2 16151 bogor utara - kota',
#   {'entities': [(8, 20, 'STREET')]}),
#  ('saka jaya, sum urip', {'entities': []}),
#  ('wol mon kranjingan sumber sari', {'entities': [(0, 7, 'STREET')]}),
#  ('pluit pluit karang jel 13, 8 rt 4 3 14450 penjaringan',
#   {'entities': [(6, 25, 'STREET')]}),
#  ('habitat terrace residence blok d8, jl..masjid ciater, ciater, serpong, 15317.',
#   {'entities': [(0, 25, 'POI'), (35, 45, 'STREET')]}),
#  ('cak 11 nagasari karawang barat', {'entities': []}),
#  ('belakang sdlb lengayang, nagari kambang, kampung medan baik',
#   {'entities': [(49, 59, 'POI')]}),
#  ('aspol spn batua kec panakukang', {'entities': [(0, 9, 'POI')]}),
#  ('raya jepa, 57 depan indomaret rt 1 1 bangsri',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('lebe kader, 389 merah mersa lut tawar', {'entities': [(0, 10, 'STREET')]}),
#  ('rnd prin, gang pinak, sukarame', {'entities': [(10, 20, 'STREET')]}),
#  ('batagor kuah ku bakuku, pahl revo, pondok bambu',
#   {'entities': [(0, 22, 'POI'), (24, 33, 'STREET')]}),
#  ('pp minhajutt, kh abdul manan, sumberberas muncar',
#   {'entities': [(14, 28, 'STREET')]}),
#  ('tk islam daruss,', {'entities': []}),
#  ('lele 1', {'entities': [(0, 6, 'STREET')]}),
#  ('kemb jepun, no 192 bint jaya ud, rw 1 bongkaran pabean cantikan',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('amuntai tengah, hulu sungai utara, kalimantan selatan, turunan jembatan banua lima,',
#   {'entities': [(63, 82, 'POI')]}),
#  ('lidah hara xvii 43 rw 5 60213 lakar santri',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('raya teja pak ginarsa, tejakula',
#   {'entities': [(10, 21, 'POI'), (0, 9, 'STREET')]}),
#  ('jl. raya tlogo gang 1 68 tlogomas rt 5 6 lowokwaru',
#   {'entities': [(0, 21, 'STREET')]}),
#  ('alfamrt 1me5 gs gold pembangunan, no 7 kedunghalang',
#   {'entities': [(0, 20, 'POI'), (21, 32, 'STREET')]}),
#  ('jupi 1 a 4 pisangan rw 13 ciputat timur', {'entities': [(0, 8, 'STREET')]}),
#  ('simpang tiga kah nasu no 112 28284 bukit raya', {'entities': []}),
#  ('sambi 46 kayu putih rt 4 rw 7 pulo gadung',
#   {'entities': [(0, 5, 'STREET')]}),
#  ('jati i 132 pelutan pemalang', {'entities': []}),
#  ('pulau damar, kembangan utara kel.', {'entities': [(0, 11, 'STREET')]}),
#  ('stasiun bekasi kota', {'entities': [(0, 14, 'POI')]}),
#  ('lor batu kar 26 ilir', {'entities': [(0, 12, 'STREET')]}),
#  ('jalan tipar cakung no 26 depan rusun albo garasi dumtruk',
#   {'entities': [(31, 41, 'POI'), (0, 18, 'STREET')]}),
#  ('ngupasan sur 33 gondomanan', {'entities': [(9, 12, 'STREET')]}),
#  ('gg. rah, 26 binjai medan denai', {'entities': [(0, 7, 'STREET')]}),
#  ('cau terr, gal,', {'entities': [(10, 13, 'STREET')]}),
#  ('taman kota kedaung kali angke gg.h.musanif no 54c rt 001 08',
#   {'entities': [(0, 10, 'POI')]}),
#  ('aren jaya sumb iv 319 rt 3 10 17111 bekasi timur',
#   {'entities': [(10, 17, 'STREET')]}),
#  ('shi mel, nanggalo', {'entities': [(0, 7, 'STREET')]}),
#  ('pamoyanan town house blok g no 1', {'entities': []}),
#  ('kedai tenun jep senn, kota bumi, kebon melati',
#   {'entities': [(22, 31, 'STREET')]}),
#  ('wadungasri dalam waru raya wad asri, 24 sidoarjo',
#   {'entities': [(11, 21, 'POI'), (22, 35, 'STREET')]}),
#  ('bulusan tim barat iii, no 35 3 tembalang',
#   {'entities': [(8, 21, 'STREET')]}),
#  ('bakti jaya bukit perm vii 8 15315 setu',
#   {'entities': [(11, 25, 'STREET')]}),
#  ('jl terusan buah batu no 185. samping indomaret. bandung.',
#   {'entities': [(29, 46, 'POI'), (0, 20, 'STREET')]}),
#  ('setia indah, jati, no 12',
#   {'entities': [(0, 11, 'POI'), (13, 17, 'STREET')]}),
#  ('kepuhkiriman gg. bca 61256 waru', {'entities': [(13, 20, 'STREET')]}),
#  ('raya cigan 21 cipagalo bojongsoang', {'entities': [(0, 10, 'STREET')]}),
#  ('selo timur viii 390 12 panggung lor semarang utara',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('gang indah,', {'entities': [(0, 10, 'STREET')]}),
#  ('cv. hin oto kenc, sido ii, q 29', {'entities': [(18, 25, 'STREET')]}),
#  ('jaya utama pramudita pt, holis per 1,',
#   {'entities': [(0, 23, 'POI'), (25, 36, 'STREET')]}),
#  ('pabu 8 rawa arum gerogol', {'entities': [(0, 4, 'STREET')]}),
#  ('cibu no 14 duri pulo rt 8 2 gambir', {'entities': [(0, 4, 'STREET')]}),
#  ('jatisampurna raya pasar kran 1 rt 1 3 jati sampurna',
#   {'entities': [(13, 28, 'STREET')]}),
#  ('send ser 15 rw 8 50273 tembalang', {'entities': [(0, 8, 'STREET')]}),
#  ('batas kampar-ban, pkl unisati, kampar',
#   {'entities': [(18, 29, 'POI'), (0, 16, 'STREET')]}),
#  ('ahmad dah iv kukusan beji', {'entities': []}),
#  ('caval pizz, dip ukur, lebak gede coblong',
#   {'entities': [(12, 20, 'STREET')]}),
#  ('wanajaya intan 4, 2 17520 cibitung', {'entities': [(9, 16, 'STREET')]}),
#  ('gala klam asri sela ii 42 rt 0 0 sukolilo', {'entities': []}),
#  ('panggr ib, 16 kranggan prajurit kulon', {'entities': [(0, 9, 'STREET')]}),
#  ('mas bah ii,', {'entities': []}),
#  ('suka maju propertree coffee-ho, taman mang indah, l 6',
#   {'entities': [(10, 30, 'POI'), (32, 48, 'STREET')]}),
#  ('haji oemar said cokr 129 kalijaya', {'entities': []}),
#  ('p.d anita, gang budi mulia, andir',
#   {'entities': [(0, 9, 'POI'), (11, 26, 'STREET')]}),
#  ('jl. ramba 3 baiya palu utara', {'entities': [(0, 9, 'STREET')]}),
#  ('prat 17 medan satria', {'entities': [(0, 7, 'STREET')]}),
#  ('grey,', {'entities': []}),
#  ('gg. vif no 21 bandulan sukun', {'entities': [(0, 7, 'STREET')]}),
#  ('mangla rege no h1 3 cimekar kel. cileunyi', {'entities': []}),
#  ('haji oemar said cokr jombatan jombang', {'entities': []}),
#  ('dah no 12a cilegon', {'entities': [(0, 3, 'STREET')]}),
#  ('karangduren raya kar 51 rt 7 2 65162', {'entities': [(12, 20, 'STREET')]}),
#  ('beng las deny, mendalanwangi', {'entities': []}),
#  ('cipinang besar selatan lintas ibadah, cipi jaya 1a no 3 rw 7 13410 jatinegara',
#   {'entities': [(23, 36, 'POI')]}),
#  ('sd gmist bethel minanga,', {'entities': [(0, 23, 'POI')]}),
#  ('ber nadah agung', {'entities': []}),
#  ('sd bust islamiah, andi pang petta panakkukang',
#   {'entities': [(18, 33, 'STREET')]}),
#  ('kupang krajan kup kra i 38-f rt 2 3 sawahan',
#   {'entities': [(14, 23, 'STREET')]}),
#  ('cilincing cilin bakti 22 rt 9 6 cilincing',
#   {'entities': [(10, 21, 'STREET')]}),
#  ('sdn gadog o6, raya pun gadog,', {'entities': []}),
#  ('lembu i 5 tatura selatan palu selatan', {'entities': [(0, 7, 'STREET')]}),
#  ('cileunyi kulon h. hol, 77 cileunyi', {'entities': [(15, 21, 'STREET')]}),
#  ('sd neg palumbungan 1, perum wirasana purbalingga',
#   {'entities': [(22, 36, 'STREET')]}),
#  ('jl. dalam malabar lengkong', {'entities': [(0, 9, 'STREET')]}),
#  ('batur vii, no 13 mekarjaya rancasari', {'entities': [(0, 9, 'STREET')]}),
#  ('cafe 4wd, dr. wahi s., pontianak kota', {'entities': []}),
#  ('perum graha gesya, gesya resid, belian',
#   {'entities': [(0, 17, 'POI'), (19, 30, 'STREET')]}),
#  ('jl.pramuka raya no 59a limo depok,depan jembatan 17 .',
#   {'entities': [(40, 51, 'POI'), (0, 15, 'STREET')]}),
#  ('panunggangan barat nn no 23 rt 1 rw 9 cibodas', {'entities': []}),
#  ('bukit tiban selaras a no 3', {'entities': [(0, 19, 'POI')]}),
#  ('ujung harapan, no 48a pd. karya warga mand cimb, bahagia',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('paku 32-26 pakuncen wirobrajan', {'entities': [(0, 4, 'STREET')]}),
#  ('pis, no 8 63132', {'entities': []}),
#  ('prim warna dan rekan kembang jeruk iv, tlogosari kulon',
#   {'entities': [(21, 37, 'STREET')]}),
#  ('paseban kra sawah 24 7 10450 senen', {'entities': [(8, 17, 'STREET')]}),
#  ('alun - alun kuli nusan, kar', {'entities': [(24, 27, 'STREET')]}),
#  ('koala sela jaka mulya bekasi selatan', {'entities': [(0, 10, 'STREET')]}),
#  ('jatim, tegalrejo', {'entities': [(0, 5, 'STREET')]}),
#  ('rawa buaya mang raya, 48 rt 1 8 11740 cengkareng',
#   {'entities': [(11, 20, 'STREET')]}),
#  ('kantor bupati tapa sela serma lian kos, wek ii padang sidempuan utara (padangsidimpuan)',
#   {'entities': [(24, 38, 'STREET')]}),
#  ('kasw 8 kampung anyar buleleng', {'entities': [(0, 4, 'STREET')]}),
#  ('bojong nangka arcadia raya, no 126 16963 gunung putri',
#   {'entities': [(14, 26, 'STREET')]}),
#  ('nga rejo utara 1 ngagelrejo wonokromo', {'entities': [(0, 16, 'STREET')]}),
#  ('rusun pinus elok tower c lt 11no 14', {'entities': []}),
#  ('smk karya pemban, pon,', {'entities': [(18, 21, 'STREET')]}),
#  ('pulo gebang raya pulo geb no 9 rt 2 rw 6 cakung',
#   {'entities': [(12, 25, 'STREET')]}),
#  ('lengkong kulon lengkong kulon 1 pagedangan',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('taman mer, 13 electr laun system, 2 meruya utara', {'entities': []}),
#  ('bambu kun no 25 agen radar, sepanjang jaya',
#   {'entities': [(16, 26, 'POI'), (0, 9, 'STREET')]}),
#  ('mel ledug prigen', {'entities': [(0, 3, 'STREET')]}),
#  ('marina frozen food, pluit per, rt 17 14450',
#   {'entities': [(0, 18, 'POI'), (20, 29, 'STREET')]}),
#  ('depan rth maron(lapangan maron)', {'entities': [(6, 15, 'POI')]}),
#  ('anjas i, no 18 3', {'entities': [(0, 7, 'STREET')]}),
#  ('cica boutique.. jl. ruko kuala mas raya cb 34 semarang utara',
#   {'entities': [(40, 45, 'POI')]}),
#  ('penggilingan padi, ban, bangkingan lakar santri',
#   {'entities': [(0, 17, 'POI'), (19, 22, 'STREET')]}),
#  ('let ars raya no 156 rt 1 rw 1 bekasi selatan',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('green bay condominium, jl. pluit karang ayu barat no. b1 (tower j - 26 al)',
#   {'entities': [(0, 9, 'POI'), (23, 49, 'STREET')]}),
#  ('manisrejo pagu indah iii 15 taman', {'entities': [(10, 24, 'STREET')]}),
#  ('raya mauk pisangan jaya sepatan', {'entities': [(0, 9, 'STREET')]}),
#  ('lelly bout, sum mekar babakan babakan ciparay',
#   {'entities': [(12, 21, 'STREET')]}),
#  ('raya kebon karet - pasar kemis sukaasih pasar kemis', {'entities': []}),
#  ('dadapsari petek 134 1 semarang utara', {'entities': [(10, 15, 'STREET')]}),
#  ('pasi redjeki, man kerto v, mojo', {'entities': []}),
#  ('lokom kaliabang tengah bekasi utara', {'entities': [(0, 5, 'STREET')]}),
#  ('bencongan indah danau toba 3 16 rt 2 6 kelapa dua',
#   {'entities': [(16, 28, 'STREET')]}),
#  ('stati accessories roxy mas, cideng gambir',
#   {'entities': [(18, 26, 'STREET')]}),
#  ('kan desa sumber wangi tps 1, sumber wangi', {'entities': []}),
#  ('desa pangkalan batang barat bukit batu', {'entities': [(0, 27, 'POI')]}),
#  ('pang rambut asgar raya kp utan setu, 32 cibitung',
#   {'entities': [(18, 35, 'STREET')]}),
#  ('mas al latif kademangan setu', {'entities': [(0, 12, 'STREET')]}),
#  ('aempe pluit bat raya pt, soek hatta, no 732 mekar mulya cinambo',
#   {'entities': [(25, 35, 'STREET')]}),
#  ('tulusrejo candi men sela vii no 20 65141 lowokwaru',
#   {'entities': [(10, 28, 'STREET')]}),
#  ('tk 42 zahra, par', {'entities': [(0, 11, 'POI')]}),
#  ('cilandak barat lebak bulus iii 77 rt 9 cilandak',
#   {'entities': [(15, 30, 'STREET')]}),
#  ('seruni hills jl swadaya 3 rt 003 rw 006 jatiranggon',
#   {'entities': [(0, 12, 'POI'), (13, 25, 'STREET')]}),
#  ('mayang 60235 gayungan', {'entities': [(0, 6, 'STREET')]}),
#  ('notaris dan ppat emmy halim, sh., mand utara',
#   {'entities': [(34, 44, 'STREET')]}),
#  ('beng spesia ac mobil ac rio, ling sala,',
#   {'entities': [(29, 38, 'STREET')]}),
#  ('toko sae, tulakan-tegalombo',
#   {'entities': [(0, 8, 'POI'), (10, 27, 'STREET')]}),
#  ('sungai beringin toko taher sound, sungai beri, no 62 tembilahan',
#   {'entities': [(16, 32, 'POI'), (0, 11, 'STREET')]}),
#  ('bau mass, no 173 pt. mirama bacukiki barat',
#   {'entities': [(17, 27, 'POI'), (0, 8, 'STREET')]}),
#  ('pahl no 6 dpc federasi lome sbsi,', {'entities': []}),
#  ('kalij barat i pacar kembang tambaksari', {'entities': [(0, 13, 'STREET')]}),
#  ('ged bersau, pen 1', {'entities': [(12, 17, 'STREET')]}),
#  ('doger cilandak anjatan', {'entities': [(0, 5, 'STREET')]}),
#  ('mie dan nasi gor pak doey, yos suda,', {'entities': []}),
#  ('batu ampar mas con 47 rw 3 kramat jati',
#   {'entities': [(11, 18, 'STREET')]}),
#  ('cahaya abadi, raya cang,',
#   {'entities': [(0, 12, 'POI'), (14, 23, 'STREET')]}),
#  ('toko tan jaya a m sang',
#   {'entities': [(0, 13, 'POI'), (14, 22, 'STREET')]}),
#  ('mantap jaya, raya wono, ketimang',
#   {'entities': [(0, 11, 'POI'), (13, 22, 'STREET')]}),
#  ('stasiun pemalang, j veteran no.28, pelutan,kec. pemalang, kab. pemalang, jawa tengah 52312',
#   {'entities': [(0, 16, 'POI')]}),
#  ('brig kata cangakan karanganyar', {'entities': [(0, 9, 'STREET')]}),
#  ('cengkareng timur taman palem muti 19 rt 6 14 11730 cengkareng',
#   {'entities': [(17, 33, 'STREET')]}),
#  ('suta jaya pekand indra 3 plumbon', {'entities': [(0, 22, 'STREET')]}),
#  ('taman mpu sen 01 selong rt 8 3 kebayoran baru',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('ciman, no 42a ciputat', {'entities': [(0, 5, 'STREET')]}),
#  ('lumbungrejo tem turi pasar tem 55552 tempel',
#   {'entities': [(12, 30, 'STREET')]}),
#  ('pedur mes 2 karet kuningan setia budi', {'entities': [(0, 11, 'STREET')]}),
#  ('war sahabat raya bukit tingg', {'entities': [(12, 28, 'STREET')]}),
#  ('waro bakso bunda pampangan, pampangan', {'entities': []}),
#  ('jl. kon 99 caringin wetan rt 3 4 caringin',
#   {'entities': [(0, 7, 'STREET')]}),
#  ('koja lor z. timur 1 14220 koja', {'entities': [(5, 17, 'STREET')]}),
#  ('nua hijau utama xvii 11 ubung kaja denpasar utara',
#   {'entities': [(0, 20, 'STREET')]}),
#  ('duren tiga graha mamp 2nd floor raya mamp prap 100 rt 2 1 pancoran',
#   {'entities': [(37, 46, 'STREET')]}),
#  ('raya kubu tanj, 79 aur birugo tigo baleh',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('wisnu elektr, raya maja ranca, bojongloa rancaekek',
#   {'entities': [(14, 29, 'STREET')]}),
#  ('jl dirgantara raya depan taman dirgantara rt 07 r w 05 nomor rumah 35a',
#   {'entities': [(25, 41, 'POI'), (0, 18, 'STREET')]}),
#  ('tambal ban eri entiss taman fitness jl. teuku umar',
#   {'entities': [(22, 35, 'POI'), (36, 50, 'STREET')]}),
#  ('raff hills boule jati sampurna', {'entities': [(0, 16, 'STREET')]}),
#  ('kebonsari gg. 9, no 66 sumber sari', {'entities': [(10, 15, 'STREET')]}),
#  ('mt hary 22 purwokerto wetan purwokerto timur',
#   {'entities': [(0, 7, 'STREET')]}),
#  ('pancoran mas 194', {'entities': [(0, 12, 'STREET')]}),
#  ('sanur halte smp 92 by pass ngu rai 340 denpasar selatan',
#   {'entities': [(6, 18, 'POI'), (19, 34, 'STREET')]}),
#  ('rsup persahabatan, gd. rasmin rasjid lt. 1 ipspj (yansos) rawamangun',
#   {'entities': [(0, 17, 'POI')]}),
#  ('darul imarah', {'entities': []}),
#  ('headmost bkl, putri gad cemp,', {'entities': [(0, 12, 'POI')]}),
#  ('stj ( semacam tempat jajan ) ruko pondok nurul fikri . jl tugu raya no.61',
#   {'entities': [(29, 52, 'POI'), (55, 67, 'STREET')]}),
#  ('bukit x no 14 sariwangi parongpong', {'entities': [(0, 7, 'STREET')]}),
#  ('simok iii, 23a rt 3 rw 4 simokerto simokerto',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('sayur segar dan semb ibu sur parangt, brontokusuman mantrijeron',
#   {'entities': []}),
#  ('kan desa sumur musuk boyolali', {'entities': []}),
#  ('kel gad ii kramat jati kramat jati', {'entities': [(0, 10, 'STREET')]}),
#  ('par baris v, pedurungan', {'entities': [(0, 11, 'STREET')]}),
#  ('dewi sart 34 a ciputat ciputat', {'entities': [(0, 9, 'STREET')]}),
#  ('jl. edy raya jl. hali raya setia budi', {'entities': []}),
#  ('bri unit balai selasa', {'entities': [(9, 21, 'POI')]}),
#  ('vita luxe, teuku umar dauh puri kauh',
#   {'entities': [(0, 9, 'POI'), (11, 21, 'STREET')]}),
#  ('toko sejahtera sungai penuh', {'entities': [(0, 14, 'POI')]}),
#  ('arj no 14 jasa ketik yutef wirobrajan wirobrajan',
#   {'entities': [(10, 26, 'POI'), (0, 3, 'STREET')]}),
#  ('rumah cuci ria cemp besar, mawar banjarmasin tengah',
#   {'entities': [(15, 25, 'STREET')]}),
#  ('ba terp an nur, lemahwungkuk', {'entities': []}),
#  ('metal iii, tanjung mulia kel. medan deli',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('kota bambu utara 1 4 rt 16 3 kota bambu utara palmerah',
#   {'entities': [(0, 18, 'STREET')]}),
#  ('kan bupati asa mekar baru', {'entities': []}),
#  ('jl. teknik elektro asrama mahasiswa its gedung h 417,',
#   {'entities': [(19, 39, 'POI'), (0, 18, 'STREET')]}),
#  ('yos suda,', {'entities': [(0, 8, 'STREET')]}),
#  ('asidiq toko,', {'entities': [(0, 11, 'POI')]}),
#  ('raya pon benda, war nasi cipunjur,', {'entities': [(0, 14, 'STREET')]}),
#  ('raya gatot subr 28 turen', {'entities': []}),
#  ('air langga a2 no 2 rt 2 8 tanah sereal', {'entities': [(0, 13, 'STREET')]}),
#  ('jalan sumur bor raya rt  rw 004 012 kel. kalideres kec.kalideres_jakarta barat',
#   {'entities': []}),
#  ('raya baur, 23 baureno', {'entities': [(0, 9, 'STREET')]}),
#  ('luk 296 pejagoan pejagoan', {'entities': [(0, 3, 'STREET')]}),
#  ('tb. kenc, pulau sula', {'entities': [(10, 20, 'STREET')]}),
#  ('t-sh design store, vete cilacap selatan',
#   {'entities': [(19, 23, 'STREET')]}),
#  ('kelapa indah jl. kiha dewan tha cipo keta cipo tange ban 15147 tangerang',
#   {'entities': [(13, 56, 'STREET')]}),
#  ('nota & ppat ary,', {'entities': []}),
#  ('kp. lebak jero', {'entities': [(4, 14, 'POI')]}),
#  ('coun kiis, biringbulu', {'entities': []}),
#  ('gugus depan no 14 rt 12 1 matraman', {'entities': []}),
#  ('tranboge village blok f no 6 kedung waringin bojong gede bogor',
#   {'entities': [(0, 16, 'POI')]}),
#  ('raya pad - pai nanggalo koto xi tarusan',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('warung mbak santi, sumber suko', {'entities': [(0, 17, 'POI')]}),
#  ('she bea hair and spa, dr. soet, no 19c sungai bangkong pontianak kota',
#   {'entities': [(22, 30, 'STREET')]}),
#  ('prodia tower. jl kramat raya no 150',
#   {'entities': [(0, 12, 'POI'), (14, 28, 'STREET')]}),
#  ('beryl barat,', {'entities': []}),
#  ('sukabumi selatan haji raidi 40 rt 10 4 11560 kebon jeruk',
#   {'entities': [(17, 27, 'STREET')]}),
#  ('palem 6 14 helvetia', {'entities': [(0, 7, 'STREET')]}),
#  ('kantor desa manusak,', {'entities': [(0, 19, 'POI')]}),
#  ('macan kumb ix, 5005 siring agung ilir barat i',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('ahass 10306, prof. dr. buny purwokerto utara',
#   {'entities': [(0, 11, 'POI'), (13, 27, 'STREET')]}),
#  ('rambutan raya bogor, 7 rt 4 5 13830 ciracas',
#   {'entities': [(9, 19, 'STREET')]}),
#  ('jatil barat iii ngesrep banyumanik', {'entities': [(0, 15, 'STREET')]}),
#  ('simo tamb 13 exterior store, 5 simomulyo sukomanunggal',
#   {'entities': [(13, 27, 'POI'), (0, 9, 'STREET')]}),
#  ('jasm,', {'entities': [(0, 4, 'STREET')]}),
#  ('jaja polet dan vari, k h abdul halim majalengka kulon majalengka',
#   {'entities': [(21, 36, 'STREET')]}),
#  ('indocar', {'entities': []}),
#  ('puskesmas mekar, prof. dr. ir. sut, mekar sari rangkasbitung',
#   {'entities': [(17, 34, 'STREET')]}),
#  ('tanah sareal ahmad yani 60 rt 1 3 tanah sereal',
#   {'entities': [(13, 23, 'STREET')]}),
#  ('toko wandhe muria, k h ahmad kholil, genteng',
#   {'entities': [(0, 17, 'POI'), (19, 35, 'STREET')]}),
#  ('sky laundry, kamp klit lor, gondokusuman',
#   {'entities': [(0, 11, 'POI'), (13, 26, 'STREET')]}),
#  ('rejo - suruh medayu suruh', {'entities': [(0, 12, 'STREET')]}),
#  ('nasi goreng alazka, sunan ampel',
#   {'entities': [(0, 18, 'POI'), (20, 31, 'STREET')]}),
#  ('poris plawad nn 8 rt 4 1 15141 cipondoh',
#   {'entities': [(13, 15, 'STREET')]}),
#  ('anggrek rosl 2 kemanggisan rt 5 5 palmerah',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('toko tyana modi, klepu kranggan', {'entities': []}),
#  ('bulak kyai tam deres 109 rt 2 3 60124 bulak',
#   {'entities': [(6, 20, 'STREET')]}),
#  ('tanah kali kedinding gg. kemu i 13 rw 1 60127 kenjeran',
#   {'entities': [(21, 31, 'STREET')]}),
#  ('tropodo raya taman bunga 32 61253', {'entities': [(8, 24, 'STREET')]}),
#  ('sisir sul agu gg. 2 1 batu', {'entities': [(6, 19, 'STREET')]}),
#  ('jaya makh konsu, adonis samad, panarung pahandut',
#   {'entities': [(17, 29, 'STREET')]}),
#  ('jl. cinta barl ban baru city tanjung karang timur',
#   {'entities': [(0, 18, 'STREET')]}),
#  ('kebun kac 44 no 10 kebon kacang rt 5 8 tanah abang',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('rafa cell, tent pela, bumijo',
#   {'entities': [(0, 9, 'POI'), (11, 20, 'STREET')]}),
#  ('west union, hus sast, no 194 rw 8', {'entities': []}),
#  ('dupak ban dupak krembangan', {'entities': []}),
#  ('al barokah serv motor, stas ker api', {'entities': [(23, 35, 'STREET')]}),
#  ('cibeureum jend. sudi 851 40535 cimahi selatan',
#   {'entities': [(10, 20, 'STREET')]}),
#  ('mutiara regency b 20, kec. sidoarjo, kabupaten sidoarjo, jawa timur, 61226',
#   {'entities': [(0, 15, 'POI')]}),
#  ('rs qadr komplek islamic village. kelapa dua. karawaci tangerang (titip di satpam ugd )',
#   {'entities': [(8, 31, 'POI')]}),
#  ('kalikotes toko putra jaya, raya tamb kulon, kalikotes',
#   {'entities': [(10, 25, 'POI'), (27, 42, 'STREET')]}),
#  ('biting mawar 90 68191 arjasa', {'entities': [(7, 12, 'STREET')]}),
#  ('kali dha iv,', {'entities': [(0, 11, 'STREET')]}),
#  ('pab dolomit maros, tenrigangkae mandai', {'entities': []}),
#  ('cipaku cip 27 40383', {'entities': [(0, 3, 'STREET')]}),
#  ('pulori, no ar1 7 gamisalila hijab store, jaka setia',
#   {'entities': [(17, 39, 'POI')]}),
#  ('kementerian agama vi, no 1',
#   {'entities': [(0, 17, 'POI'), (18, 20, 'STREET')]}),
#  ('ditresnarkoba polda sumut', {'entities': [(14, 25, 'POI')]}),
#  ('kb auliya, pers alam, no a1 1 16913',
#   {'entities': [(0, 9, 'POI'), (11, 20, 'STREET')]}),
#  ('hang raya cibodas baru cibodas', {'entities': [(0, 9, 'STREET')]}),
#  ('toko wahyu jaya batu ukir lekol s. praw,',
#   {'entities': [(0, 25, 'POI'), (26, 39, 'STREET')]}),
#  ('kawat pena batu, tanah merdeka,', {'entities': [(17, 30, 'STREET')]}),
#  ('daan mogot, batuceper batuceper', {'entities': [(0, 10, 'STREET')]}),
#  ('mar, no 12 turangga lengkong', {'entities': [(0, 3, 'STREET')]}),
#  ('kedai lup 22, tol waru jua rw 9', {'entities': [(14, 26, 'STREET')]}),
#  ('kar utara banyumanik', {'entities': []}),
#  ('rumah makan citra panyileukan komp bumi panyileukan, cipadung kidul panyileukan',
#   {'entities': [(0, 29, 'POI')]}),
#  ('sul iska muda kebayoran lama utara kebayoran lama',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('ser kko badar ii 162 5 3 ilir ilir timur ii',
#   {'entities': [(0, 16, 'STREET')]}),
#  ('mush pare plosoklaten', {'entities': [(5, 9, 'STREET')]}),
#  ('tanj raya ii, 4 parit mayor pontianak timur',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('johunut musholla ataqwa, 57678', {'entities': [(8, 23, 'POI')]}),
#  ('raya man besar no 100 rt 5 6 mangga besar taman sari',
#   {'entities': [(0, 14, 'STREET')]}),
#  ("hani' legging collection, mohammad toha,",
#   {'entities': [(0, 24, 'POI'), (26, 39, 'STREET')]}),
#  ('graha tirta akasia no 96, kec. waru kab. sidoarjo 61256 jatim',
#   {'entities': []}),
#  ('denis massage & spa', {'entities': []}),
#  ('baureno babat boj 153', {'entities': [(8, 17, 'STREET')]}),
#  ('g m. mid mekarsari cimanggis', {'entities': [(0, 8, 'STREET')]}),
#  ('gad indah utara vi, 22 rw 5 bulak', {'entities': [(0, 18, 'STREET')]}),
#  ('bangunjiwo tk pertiwi 20 sps bunga lily kar 55799 kasihan',
#   {'entities': []}),
#  ('cosmat kejak', {'entities': [(7, 12, 'STREET')]}),
#  ('nasi uduk mbak sum, kota bambu sela ii palmerah',
#   {'entities': [(0, 18, 'POI'), (20, 38, 'STREET')]}),
#  ('kantor pos, raya slorok slorok',
#   {'entities': [(0, 10, 'POI'), (12, 23, 'STREET')]}),
#  ('gun tamp i larangan harjamukti', {'entities': [(0, 10, 'STREET')]}),
#  ('lom vape store, sriwi mataram', {'entities': [(16, 21, 'STREET')]}),
#  ("sam ratul, k'kini kor & indonesian restoran, ranowangko",
#   {'entities': [(0, 9, 'STREET')]}),
#  ('raya busu no 1 mojosongo', {'entities': [(0, 9, 'STREET')]}),
#  ('kiangroke pahl rt 3 rw 13 banjaran', {'entities': [(10, 14, 'STREET')]}),
#  ('hesin collection, idrus',
#   {'entities': [(0, 16, 'POI'), (18, 23, 'STREET')]}),
#  ('kre bun iv no 19 pasar baru 6 sawah besar',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('gun anyar lor, gg. i 44 rw 1 gunung anyar gununganyar',
#   {'entities': [(0, 20, 'STREET')]}),
#  ('bont 18 paccinongang somba opu (upu)', {'entities': [(0, 4, 'STREET')]}),
#  ('petamburan pet i 18 rt 3 2 10260 tanah abang',
#   {'entities': [(11, 16, 'STREET')]}),
#  ('haji zai ari,', {'entities': []}),
#  ('lele 2,', {'entities': [(0, 6, 'STREET')]}),
#  ('chat terasutra bogor, pajaj indah ii,', {'entities': [(22, 36, 'STREET')]}),
#  ('dr. suba, ond grup, jember lor',
#   {'entities': [(10, 18, 'POI'), (0, 8, 'STREET')]}),
#  ('jl. raya cilem gang tung bha 4 cigugur tengah cimahi tengah',
#   {'entities': [(0, 30, 'STREET')]}),
#  ('pasar baru kel. palangkaraya, 30 20212',
#   {'entities': [(16, 28, 'STREET')]}),
#  ('maphar hayam wuruk, no 50 rt 9 5 taman sari',
#   {'entities': [(7, 18, 'STREET')]}),
#  ('m. nasir, ogan,', {'entities': [(0, 8, 'POI'), (10, 14, 'STREET')]}),
#  ('maka d5, cipu 1, kebayoran lama', {'entities': [(9, 15, 'STREET')]}),
#  ('jl r.a kartini no 24 dekat alun-alun jepara kota',
#   {'entities': [(27, 43, 'POI')]}),
#  ('east wood, prof. dr. satrio,',
#   {'entities': [(0, 9, 'POI'), (11, 27, 'STREET')]}),
#  ('dpc asosiasi kontraktor lis, kolo sugi,',
#   {'entities': [(29, 38, 'STREET')]}),
#  ('unyur lebak sili gem kasemen', {'entities': [(6, 20, 'STREET')]}),
#  ('rawa bin lubang buaya', {'entities': [(0, 8, 'STREET')]}),
#  ('babakan nasi xi 16 dramaga', {'entities': [(8, 15, 'STREET')]}),
#  ('ad sandi cakra prat pt, pulau karam, kampung pondok',
#   {'entities': [(24, 35, 'STREET')]}),
#  ('intan motor, god, 19', {'entities': [(0, 11, 'POI'), (13, 16, 'STREET')]}),
#  ('slta kart, budi kemul, kampung pelita', {'entities': [(11, 21, 'STREET')]}),
#  ('laiz collection kena, no 15 82111 tabanan',
#   {'entities': [(0, 15, 'POI'), (16, 20, 'STREET')]}),
#  ('giri mekar indah i, cilengkrang', {'entities': [(0, 18, 'STREET')]}),
#  ('gun batu putih 51 maricaya baru makassar',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('reklame percetakan spudnik, sedap malam no 43 rw 1 senen',
#   {'entities': [(0, 26, 'POI'), (28, 39, 'STREET')]}),
#  ('taman mata utama pejuang kel.', {'entities': [(0, 16, 'STREET')]}),
#  ('gg. h. mah bahagia babelan', {'entities': [(0, 10, 'STREET')]}),
#  ('dukuh gg. h. tabah, 26 rt 12 3 13550 kramat jati',
#   {'entities': [(6, 18, 'STREET')]}),
#  ('sd negeri 217x parit culum i, muara sabak timur',
#   {'entities': [(0, 28, 'POI')]}),
#  ('bukit indah 11,', {'entities': [(0, 14, 'STREET')]}),
#  ('bha abri,', {'entities': [(0, 8, 'STREET')]}),
#  ('gani cell, raya dieng krasak',
#   {'entities': [(0, 9, 'POI'), (11, 21, 'STREET')]}),
#  ('kebon jeruk mawar iii 4c rt 2 7 kebon jeruk',
#   {'entities': [(12, 21, 'STREET')]}),
#  ('kese', {'entities': [(0, 4, 'STREET')]}),
#  ('nur cho,', {'entities': []}),
#  ('dony batu, bek barat rawa bunga', {'entities': [(11, 20, 'STREET')]}),
#  ('batu ceper 2, gambir', {'entities': [(0, 12, 'STREET')]}),
#  ('tk al mubar, watu-watu lentarai jaya s. (lantari jaya)', {'entities': []}),
#  ('swad raya 3a sate tongseng gule solo, larangan indah larangan',
#   {'entities': []}),
#  ('argowiyoto, 26 ledok argomulyo', {'entities': [(0, 10, 'STREET')]}),
#  ('segar hara, bukit tung', {'entities': [(12, 22, 'STREET')]}),
#  ('miftahul jan,', {'entities': []}),
#  ('arni souv, porong', {'entities': []}),
#  ('glagah raya pakuniran rt 8 1 67292 pakuniran',
#   {'entities': [(7, 21, 'STREET')]}),
#  ('bromo 5 221 lambangsari rt 2 6 tambun selatan',
#   {'entities': [(0, 7, 'STREET')]}),
#  ('larangan indah bas raya, 77 rt 3 2 15154 larangan',
#   {'entities': [(15, 23, 'STREET')]}),
#  ('pakelan brawi 55 64129', {'entities': [(8, 13, 'STREET')]}),
#  ('sekretariat uppkh kecamatan suko jend gatot subr,', {'entities': []}),
#  ('bumi perm sudi sudiang biring kanaya', {'entities': [(0, 14, 'STREET')]}),
#  ('kaum kulon cigending ujung berung', {'entities': [(0, 10, 'STREET')]}),
#  ('mutiara gading city cluster royal london blok j16 no 16 babelan bekasi',
#   {'entities': [(20, 40, 'POI')]}),
#  ('rumah susun kapuk muara blok b lantai dasar no.13 jl smp 122 kapuk muara',
#   {'entities': [(0, 11, 'POI'), (50, 60, 'STREET')]}),
#  ('pale, 37 paledang lengkong', {'entities': [(9, 17, 'STREET')]}),
#  ('toko coun handphone raya kalija, kalijati', {'entities': []}),
#  ('ciptomulyo kolo sugi 142c 65149 sukun', {'entities': [(11, 20, 'STREET')]}),
#  ('malaka jaya mawar merah ii 140 rt 6 1 duren sawit',
#   {'entities': [(12, 26, 'STREET')]}),
#  ('kp. warung kiara rt rw 001 005 ds mesjid peryayi kec. kasemen',
#   {'entities': [(4, 16, 'POI')]}),
#  ('plu kar el 11 pluit rt 4 12 penjaringan',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('cimuning zam utara raya 19 rt 1 7 17155 mustika jaya',
#   {'entities': [(9, 23, 'STREET')]}),
#  ('cleine appa, simo gun i sawahan', {'entities': [(13, 23, 'STREET')]}),
#  ('mahoni, em cell, giri', {'entities': [(8, 15, 'POI'), (0, 6, 'STREET')]}),
#  ('gedung alfamart bandar tinggi. jalinsum kebun kopi kec. sei suka kab. batubara',
#   {'entities': [(16, 29, 'POI')]}),
#  ('har tho no 48 gresik', {'entities': [(0, 7, 'STREET')]}),
#  ('dah 1 no 76 rt 2 rw 8 jakasampurna bekasi barat',
#   {'entities': [(0, 5, 'STREET')]}),
#  ('gang ramb, 20352 sunggal', {'entities': [(0, 9, 'STREET')]}),
#  ('jend ahmad yani, pt an-nur maarif, macanang tanete riattang barat',
#   {'entities': [(17, 33, 'POI'), (0, 15, 'STREET')]}),
#  ('koperasi putra jaya raya gatot subr barat no 389', {'entities': []}),
#  ('basuk, ayu logam kastolani, balaradin',
#   {'entities': [(7, 26, 'POI'), (0, 5, 'STREET')]}),
#  ('men, 9 andreas, cimanggis', {'entities': []}),
#  ('penerima : ibu nunu suhardini. alamat : anjungan aceh-taman mini indonesia indah',
#   {'entities': []}),
#  ('sukaresmi raya cile, 4 rt 1 3 16165 tanah sereal',
#   {'entities': [(10, 19, 'STREET')]}),
#  ('fifastra motor, mang jombang wetan',
#   {'entities': [(0, 14, 'POI'), (16, 20, 'STREET')]}),
#  ('kan upk,', {'entities': []}),
#  ('sudirejo ii saud 81 20226 medan kota', {'entities': [(12, 16, 'STREET')]}),
#  ('raya cia cika 63 cikaret rt 1 4 bogor selatan - kota',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('komp unil, 9 karang mulya rt 3 6 karang tengah',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('rusa 1, cilincing', {'entities': [(0, 6, 'STREET')]}),
#  ('let supr cempaka baru kemayoran', {'entities': [(0, 8, 'STREET')]}),
#  ('rancaekek wetan raya maja - ranca 243 rancaekek',
#   {'entities': [(16, 33, 'STREET')]}),
#  ('feryal clinic, angg raya, paropo',
#   {'entities': [(0, 13, 'POI'), (15, 24, 'STREET')]}),
#  ('mage, kios total, loano loano', {'entities': []}),
#  ('pasar minggu gur raya 70 rt 3 9 pasar minggu',
#   {'entities': [(13, 21, 'STREET')]}),
#  ('perum bci bukit cileungsi indah no 14 rt26 11', {'entities': []}),
#  ('raya kodam bint 19 rt 5 3 pesanggrahan pesanggrahan',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('taman chem jati, pangkalanjati cinere', {'entities': [(11, 15, 'STREET')]}),
#  ('kebonsari kebon ten 19b 1 60233 jambangan',
#   {'entities': [(10, 19, 'STREET')]}),
#  ('adiwerna salak 33 adiwerna', {'entities': [(9, 14, 'STREET')]}),
#  ('rij, 45 kel karang panjang sirimau', {'entities': [(0, 3, 'STREET')]}),
#  ('ayam penyet, r. wol mongin, bahu', {'entities': [(0, 11, 'POI')]}),
#  ('v star resto, cent raya, batam kota',
#   {'entities': [(0, 12, 'POI'), (14, 23, 'STREET')]}),
#  ('serdang serd ba xiii 24 rt 12 5', {'entities': [(8, 20, 'STREET')]}),
#  ('ps. bertais, lancar mandiri bertais',
#   {'entities': [(13, 27, 'POI'), (0, 11, 'STREET')]}),
#  ('war fikri, maulana yusuf,', {'entities': [(11, 24, 'STREET')]}),
#  ('habib muda seun, meugat meuh seunagan timur',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('sd neg ngembeh i, maysend h. soem, ngembeh',
#   {'entities': [(18, 33, 'STREET')]}),
#  ('veteran utara 224 makassar', {'entities': [(0, 13, 'STREET')]}),
#  ('handil jaya roni sani 40 36125 jelutung',
#   {'entities': [(12, 21, 'STREET')]}),
#  ('badan pemberdayaan masyarakat dan pemerintahan desa, jl. pendidikan no. 43',
#   {'entities': [(0, 51, 'POI'), (53, 67, 'STREET')]}),
#  ('fahriz salon, ujung bori, antang manggala',
#   {'entities': [(0, 12, 'POI'), (14, 24, 'STREET')]}),
#  ('dieng 659 dawuhan lor sukodono', {'entities': [(0, 5, 'STREET')]}),
#  ('pondok betung wij kus ujung, 150 12320 pondok aren',
#   {'entities': [(14, 27, 'STREET')]}),
#  ('toko tasik rawa kun, pulo gebang',
#   {'entities': [(0, 10, 'POI'), (11, 19, 'STREET')]}),
#  ('depan simpang bandara bandara syekh hamzah fansyuri airport',
#   {'entities': [(30, 59, 'POI')]}),
#  ('rawa bangun haji bakri 33684 taman sari',
#   {'entities': [(12, 22, 'STREET')]}),
#  ('perumahan taman carina, no 12 17', {'entities': [(0, 22, 'STREET')]}),
#  ('sid sidotentrem bangilan', {'entities': [(0, 3, 'STREET')]}),
#  ('del bukit raya tenggarong seberang', {'entities': [(0, 3, 'STREET')]}),
#  ('votw co store, waturen, panjer', {'entities': [(0, 13, 'POI')]}),
#  ('toko babun,', {'entities': [(0, 10, 'POI')]}),
#  ('manggala kecaping raya 4 manggala', {'entities': [(9, 22, 'STREET')]}),
#  ('ud rosma group, dusun tanah cellae,desa ulubalang,salomekko,bone,sulawesi selatan',
#   {'entities': [(22, 34, 'POI')]}),
#  ('kayu jati no 2 indriani,',
#   {'entities': [(15, 23, 'POI'), (0, 9, 'STREET')]}),
#  ('stokis hpai lamdi,', {'entities': []}),
#  ('ciputat raya rt 06 07 no 16 gg 45 (sebrang halte selapa)',
#   {'entities': [(43, 55, 'POI')]}),
#  ('sengon jl. mayj sung 14 jombang', {'entities': [(7, 20, 'STREET')]}),
#  ('toko jamu, komar, 92 rw 8 cakung', {'entities': []}),
#  ('dok wahi no 46 noyontaan rw 6 pekalongan timur', {'entities': []}),
#  ('maxime ren kam sragen-,', {'entities': [(15, 22, 'STREET')]}),
#  ('grand pamulang residence blok h no.9, jl. sukamulya raya, kelurahan serua',
#   {'entities': []}),
#  ('masjid lippo cikarang, taman lembah hijau, jl. melati 15',
#   {'entities': [(23, 41, 'POI'), (43, 56, 'STREET')]}),
#  ('perumahan hilltop no. 20, jl. haji japat i rt 011 rw01, abadijaya',
#   {'entities': [(0, 17, 'POI'), (26, 42, 'STREET')]}),
#  ('toko wad, peta no 54 bojongloa kaler', {'entities': [(10, 14, 'STREET')]}),
#  ('kuta alam, asrama tni ad kuta alam. barak 4 no.58.',
#   {'entities': [(11, 24, 'POI')]}),
#  ('sawo 6, lubangbuaya kel.', {'entities': [(0, 6, 'STREET')]}),
#  ('desa pon kanc timur no 1c pondok aren', {'entities': [(0, 19, 'STREET')]}),
#  ('good game stas, gampi r 1 wirobrajan', {'entities': [(16, 21, 'STREET')]}),
#  ('cemp 41 turi', {'entities': [(0, 4, 'STREET')]}),
#  ('jela barat no 21c mie ayam bang dul, rw 10 grogol petamburan',
#   {'entities': [(18, 35, 'POI'), (0, 10, 'STREET')]}),
#  ('pancoran panc barat 9d 23 rt 11 4 12780',
#   {'entities': [(9, 22, 'STREET')]}),
#  ('budi luhur cv rifa, duren sawit',
#   {'entities': [(0, 13, 'POI'), (14, 18, 'STREET')]}),
#  ('ha sarm i bendungan hilir', {'entities': []}),
#  ('pasir nangka jl. aria jaya sent rt 4 2 15720 tigaraksa',
#   {'entities': [(13, 31, 'STREET')]}),
#  ('kec serua ciputat', {'entities': [(0, 3, 'STREET')]}),
#  ('jalan. bangka raya no.4a, pela mampang. warkop aa, seberang pintu keluar kampus mh thamrin',
#   {'entities': [(40, 49, 'POI'), (0, 18, 'STREET')]}),
#  ('vika sela i 1 rt 7 5 kapuk muara penjaringan',
#   {'entities': [(0, 11, 'STREET')]}),
#  ('dokter gigi golden k, manyar kerto v gubeng',
#   {'entities': [(0, 20, 'POI'), (22, 36, 'STREET')]}),
#  ('kapuk pintu seng 78 rt 1 13 cengkareng', {'entities': [(6, 16, 'STREET')]}),
#  ('kebon bawang yos suda, rt 6 14 14320 tanjung priok',
#   {'entities': [(13, 21, 'STREET')]}),
#  ('sem 1, no 278 toi pertamina,', {'entities': [(0, 5, 'STREET')]}),
#  ('mira, dr. moh hatta, pasar pandan air mati tanjung harapan',
#   {'entities': [(0, 4, 'POI'), (6, 19, 'STREET')]}),
#  ('edow cof, ngunut ngunut', {'entities': []}),
#  ('hamalau jend sudi no 141 71261 sungai raya',
#   {'entities': [(8, 17, 'STREET')]}),
#  ('balige fash,', {'entities': []}),
#  ('bag resort,', {'entities': []}),
#  ('toko sol, moch toha muka', {'entities': [(10, 19, 'STREET')]}),
#  ('sd neg 1 sukasada, sukasada', {'entities': []}),
#  ('mata 4, 222', {'entities': [(0, 6, 'STREET')]}),
#  ('optik kania, purwak,', {'entities': [(0, 11, 'POI'), (13, 19, 'STREET')]}),
#  ('toko sami anyar', {'entities': [(0, 15, 'POI')]}),
#  ('30 ilir dok cipto, 31 30121 ilir barat ii',
#   {'entities': [(8, 17, 'STREET')]}),
#  ('atm mand dr suma, cakung', {'entities': [(9, 16, 'STREET')]}),
#  ('rintis alfa busana, hasanuddin, 6', {'entities': [(20, 30, 'STREET')]}),
#  ('tajur puri kart v 10 rt 4 9 15152 ciledug',
#   {'entities': [(6, 17, 'STREET')]}),
#  ('prapen raya manda 1 83511 praya', {'entities': [(7, 17, 'STREET')]}),
#  ('baru jl. poros maje mam 145 banggae', {'entities': [(5, 23, 'STREET')]}),
#  ('toko vera nasio, mayangan',
#   {'entities': [(0, 9, 'POI'), (10, 15, 'STREET')]}),
#  ("alice cake's & cook", {'entities': []}),
#  ('distributor tupper pt. margo pangestu perk mal, jend ahmad yani, no 91 purwodadi blimbing',
#   {'entities': [(48, 63, 'STREET')]}),
#  ('taman maru no 2', {'entities': [(0, 10, 'STREET')]}),
#  ('pekojan bande utara 2, 19 rt 6 9 11240 tambora',
#   {'entities': [(8, 21, 'STREET')]}),
#  ('jln. cilamaya no. 05 (bank bjb kcp gedung sate) kel.citarum kec. bandung wetan kota bandun',
#   {'entities': [(35, 46, 'POI'), (0, 13, 'STREET')]}),
#  ('sd negeri ciki 4, rawa ten pangk 2, bantar gebang',
#   {'entities': [(18, 34, 'STREET')]}),
#  ('dekat pasar terminal subang rt 55rw 14 rumah kontr deket mesjid al falah sukamelang subang',
#   {'entities': [(12, 27, 'POI')]}),
#  ('ika salon, cilangkap, cipayung',
#   {'entities': [(0, 9, 'POI'), (11, 20, 'STREET')]}),
#  ('gado-gado, embong keno', {'entities': [(0, 9, 'POI'), (11, 22, 'STREET')]}),
#  ('kalib, 91 8 pucang sewu gubeng', {'entities': [(0, 5, 'STREET')]}),
#  ('kar ten karang tengah', {'entities': [(0, 7, 'STREET')]}),
#  ('arn mono, sukur kel.', {'entities': [(0, 8, 'STREET')]}),
#  ('raya banjarn - pur, 98 sokaraja tengah sokaraja', {'entities': []}),
#  ('indo tek, raya indu, pasirsari cikarang selatan',
#   {'entities': [(10, 19, 'STREET')]}),
#  ('gang sas ciroyom andir', {'entities': [(0, 8, 'STREET')]}),
#  ('raya kerob 89 kerobokan kuta utara', {'entities': [(0, 10, 'STREET')]}),
#  ('war pla, tamalate', {'entities': []}),
#  ('badan pertan nasional kabupaten jayawi, wamena kota wamena',
#   {'entities': []}),
#  ('ir suci 31 pasar sayur pagi gg bakar,', {'entities': [(11, 36, 'POI')]}),
#  ('warung bunda july, macc sawah, maccini gusung',
#   {'entities': [(0, 17, 'POI')]}),
#  ('tanah tinggi asian high 25, 117 binjai timur',
#   {'entities': [(13, 26, 'STREET')]}),
#  ('jl. raya ser cikande jayanti', {'entities': [(0, 12, 'STREET')]}),
#  ('gatot subr cikarang utara', {'entities': [(0, 10, 'STREET')]}),
#  ('kutisari kuti indah utara x 70 6 tenggilis mejoyo',
#   {'entities': [(9, 27, 'STREET')]}),
#  ('gd. graha matapel jalan arjuna utara no.46 duri kepa',
#   {'entities': [(4, 17, 'POI'), (18, 36, 'STREET')]}),
#  ('pandean lamper bant utara xi, rw 5 gayamsari',
#   {'entities': [(15, 28, 'STREET')]}),
#  ('teuku umar barat 99 kerobokan kelod kuta utara',
#   {'entities': [(0, 16, 'STREET')]}),
#  ('bojongherang ir. haji djua, no 40 43216 cianjur',
#   {'entities': [(13, 26, 'STREET')]}),
#  ('perumahan wahana cikarang, blok f12 no 17 sukadami, cikarang selatan',
#   {'entities': [(0, 16, 'POI')]}),
#  ('dir i, 4 bandung kulon', {'entities': []}),
#  ('raya pasar kemis gelam jaya kel.', {'entities': [(0, 16, 'STREET')]}),
#  ('smk bhakti kartini jalan caringin no.8 jembatan 14, bojong menteng',
#   {'entities': [(39, 50, 'POI'), (19, 33, 'STREET')]}),
#  ('kap cek syeh 183 ilir timur i', {'entities': [(0, 12, 'STREET')]}),
#  ('rm cak anjun kh agus salim, kepek wonosari',
#   {'entities': [(0, 12, 'POI'), (13, 26, 'STREET')]}),
#  ('hang tuah, madras hulu kel.', {'entities': [(0, 9, 'STREET')]}),
#  ('tura barat i no 10 40263 lengkong', {'entities': [(0, 12, 'STREET')]}),
#  ('soto bu nah, bibis, kasihan',
#   {'entities': [(0, 11, 'POI'), (13, 18, 'STREET')]}),
#  ('sug pran, upt mojogedang,',
#   {'entities': [(10, 24, 'POI'), (0, 8, 'STREET')]}),
#  ('gg. perm i 87 jawa singkawang tengah', {'entities': [(0, 10, 'STREET')]}),
#  ('mulia elektr vete tipes serengan', {'entities': [(13, 17, 'STREET')]}),
#  ('tmp kali, martabak top bandung 55 rt 4 7',
#   {'entities': [(10, 33, 'POI'), (0, 8, 'STREET')]}),
#  ('usman cell, diponegoro, gambiran',
#   {'entities': [(0, 10, 'POI'), (12, 22, 'STREET')]}),
#  ('sul sya kasim, kampung dalam siak', {'entities': [(0, 13, 'STREET')]}),
#  ('mel 9 bantaeng', {'entities': [(0, 3, 'STREET')]}),
#  ('bengkulu tengah gula tubu gunung labuhan',
#   {'entities': [(16, 25, 'STREET')]}),
#  ('mariso gagak no 27 90121 mariso', {'entities': [(7, 12, 'STREET')]}),
#  ('wr. ayu, ratna denpasar utara',
#   {'entities': [(0, 7, 'POI'), (9, 14, 'STREET')]}),
#  ('toko crn, gar sakti,', {'entities': [(0, 8, 'POI'), (10, 19, 'STREET')]}),
#  ('the cell, raya ubu, nyerot jonggat', {'entities': []}),
#  ('sida, anda, gaddong bontoala',
#   {'entities': [(0, 4, 'POI'), (6, 10, 'STREET')]}),
#  ('sukamaju jl bukit ment ruko bukit ment r3 #2 jonggol',
#   {'entities': [(9, 44, 'STREET')]}),
#  ('merd, no a18 14 pon kur lassofi,', {'entities': [(0, 4, 'STREET')]}),
#  ('btn kolam blok l 39 doyo baru', {'entities': [(0, 9, 'POI')]}),
#  ('kantor camat mbeliling', {'entities': [(0, 22, 'POI')]}),
#  ('masjid al amin, widodaren', {'entities': [(0, 14, 'POI')]}),
#  ('tk kesaya mutiara blang kolak i bebesen', {'entities': []}),
#  ('sla riyadi, negara indonesia,',
#   {'entities': [(12, 28, 'POI'), (0, 10, 'STREET')]}),
#  ('karet pasar ba bar no 36 rt 12 rw 4 tanah abang',
#   {'entities': [(0, 18, 'STREET')]}),
#  ('colu ten ii 15 nagrak gunung putri', {'entities': []}),
#  ('marga sari 16 babelan', {'entities': [(0, 13, 'STREET')]}),
#  ('pang sudi 17-19 67115 purworejo', {'entities': [(0, 9, 'STREET')]}),
#  ('war mbah suwar purwo martani kalasan', {'entities': []}),
#  ('talang buluh tal kera 1 30961 talang kelapa', {'entities': []}),
#  ('sd panca dharma don bosco 1, bule timur kel gading 8 rt 1 16',
#   {'entities': [(0, 27, 'POI')]}),
#  ('rizky baro,', {'entities': []}),
#  ('kerta bakti, 17 dukuhwaru kel. dukuhwaru',
#   {'entities': [(0, 11, 'STREET')]}),
#  ('kam i 46 utan kayu selatan 6', {'entities': [(0, 5, 'STREET')]}),
#  ('benoa werdi media cem ii no 4 kuta selatan', {'entities': []}),
#  ('raya jat pasar minggu', {'entities': [(0, 8, 'STREET')]}),
#  ('kludan rt 03 rw 03 (belakang sdn kludan)', {'entities': [(29, 39, 'POI')]}),
#  ('gbi sak, sak cengkareng barat', {'entities': []}),
#  ('miea dan bakso kra, wangandawa', {'entities': []}),
#  ('cluster griya sakinah tahap 2 no a5 rt 06 rw 04 jatikramat jatiasih',
#   {'entities': [(8, 29, 'POI')]}),
#  ('petamburan 3, 5b rt 2 3 tanah abang', {'entities': [(0, 12, 'STREET')]}),
#  ('bumi daya raya 9a cinere 9 cinere', {'entities': [(0, 14, 'STREET')]}),
#  ('warung ibu diva kay, 54 rw 4 60271',
#   {'entities': [(0, 15, 'POI'), (16, 19, 'STREET')]}),
#  ('kup kra i kupang krajan sawahan', {'entities': [(0, 9, 'STREET')]}),
#  ('bank rakyat indonesia, pisa baru ten, no 37a 14 13110 matraman',
#   {'entities': [(0, 21, 'POI'), (23, 36, 'STREET')]}),
#  ('karangmangu ser ii, 6 53282', {'entities': [(12, 18, 'STREET')]}),
#  ('raya taman asri no 32 waru', {'entities': [(0, 15, 'STREET')]}),
#  ('kapuas kanan hulu kolo sugi 82 78613 sintang', {'entities': []}),
#  ('cipi muara raya jatinegara', {'entities': []}),
#  ('nusa indah 8 serua ciputat', {'entities': [(0, 10, 'STREET')]}),
#  ('macc gus,', {'entities': []}),
#  ('al maqbul (jalan raya kuwolu ) rt 9 rw 3',
#   {'entities': [(0, 9, 'POI'), (11, 28, 'STREET')]}),
#  ('bat internasional finansindo pt gajah mada, no 13cd rw 1',
#   {'entities': [(32, 42, 'STREET')]}),
#  ('alian 21 toko optimal,', {'entities': [(9, 21, 'POI'), (0, 5, 'STREET')]}),
#  ('ruko perm cibu, no 27 toko uda colection cileungsi kidul cileungsi',
#   {'entities': [(22, 40, 'POI'), (0, 14, 'STREET')]}),
#  ('lin timur, kios ika sekijang bandar sei kijang',
#   {'entities': [(11, 19, 'POI')]}),
#  ('jelambar emp baha gg. ix emp baha 4 no 60 rt 11 6 grogol petamburan',
#   {'entities': [(9, 35, 'STREET')]}),
#  ('getuk goreng murni asli soka,', {'entities': []}),
#  ('pondok labu pon labu i 36c rt 2 7 cilandak',
#   {'entities': [(12, 22, 'STREET')]}),
#  ('kamp baba 19 pasirkuda bogor barat - kota',
# ...
#  ('focus collec kebon jeruk 6, maphar taman sari',
#   {'entities': [(13, 26, 'STREET')]}),
#  ('cibogo raya tangk par, 47 40391', {'entities': [(7, 21, 'STREET')]}),
#  ('soto dag cak mul, bhayan juwet kenongo porong',
#   {'entities': [(18, 24, 'STREET')]}),
#  ('sun sadan 35 nunu palu barat', {'entities': [(0, 9, 'STREET')]}),
#  ('pt surya serba mulia laksa malahayati, telukbetung selatan',
#   {'entities': [(0, 20, 'POI'), (21, 37, 'STREET')]}),
#  ('wono no 40 banguntapan', {'entities': [(0, 4, 'STREET')]}),
#  ('tanj 1 no 6 rt 7 rw 2 jagakarsa', {'entities': [(0, 6, 'STREET')]}),
#  ('tukad penat, 27 serangan denpasar selatan', {'entities': []}),
#  ('flamb can, no 9 sultan house of moshi pudd halal 12 rempoa',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('tegal mraen sendangadi mlati', {'entities': []}),
#  ('rumah makan riyan, kuta', {'entities': []}),
#  ('i b bulakan balai kandih payakumbuh barat',
#   {'entities': [(0, 3, 'STREET')]}),
#  ('forest hill, jl. raya kabasiran, kabasiran, parung panjang, bogor, west java',
#   {'entities': [(0, 11, 'POI'), (13, 31, 'STREET')]}),
#  ('pad ii, gg. 5 3 rt 12 rw 6 pademangan', {'entities': [(0, 13, 'STREET')]}),
#  ('mawar raya, 62 wanasari cibitung', {'entities': [(0, 10, 'STREET')]}),
#  ('teluk gong raya, no 32 rubi murni perk pt rt 4 penjaringan',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('marto soto wijirejo', {'entities': [(0, 10, 'POI')]}),
#  ('derw no 105a derwati rancasari', {'entities': [(0, 4, 'STREET')]}),
#  ('gerbang permai pamengkang f6 no8 cirebon', {'entities': [(0, 14, 'POI')]}),
#  ('toko tripena, brastagi (berastagi)', {'entities': []}),
#  ('.h.n raya pondok gede', {'entities': [(0, 9, 'STREET')]}),
#  ('waru raya 62 jatimulya tambun selatan', {'entities': [(0, 9, 'STREET')]}),
#  ('siwa no 18 nyatnyono ungaran barat', {'entities': [(0, 4, 'STREET')]}),
#  ('sib barat 3 mojosongo jebres', {'entities': [(0, 9, 'STREET')]}),
#  ('kedung badak kol. enjo mart 26-41 rt 5 12 16164 tanah sereal',
#   {'entities': [(13, 27, 'STREET')]}),
#  ('ramona artiran bakery, raya panc,', {'entities': [(0, 21, 'POI')]}),
#  ('haji namin cipete utara kel.', {'entities': []}),
#  ('purwoyoso purwo slt i, 39 11 ngaliyan', {'entities': [(10, 21, 'STREET')]}),
#  ('kebo iwa 27 padangsambian kaja kel.', {'entities': []}),
#  ('maje tak arra, abung barat', {'entities': []}),
#  ('simomulyo sim baru vii no 41 5', {'entities': [(10, 22, 'STREET')]}),
#  ('menanggal jl. gay timur mgp, no 2 6 gayungan', {'entities': []}),
#  ('war maknyak kutuk barat, as 10', {'entities': [(12, 23, 'STREET')]}),
#  ('vina cell, ampel gad, ngijo',
#   {'entities': [(0, 9, 'POI'), (11, 20, 'STREET')]}),
#  ('toko jam je one, jl. pocut baren no. 44 a, laksana',
#   {'entities': [(0, 15, 'POI'), (17, 32, 'STREET')]}),
#  ('oleh-oleh peuyeum khas bandung, r e mar, pulomerak',
#   {'entities': [(0, 30, 'POI'), (32, 39, 'STREET')]}),
#  ('soek hatta, no 726 ayam penyet and sam goang d 45 da, situsaeur bojongloa kidul',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('mts tan, wad asri dalam no 170', {'entities': [(9, 23, 'STREET')]}),
#  ('tre barat 3 mertasinga 3 cilacap utara', {'entities': [(0, 9, 'STREET')]}),
#  ('warung valen 27 gar kunjung mae', {'entities': [(16, 19, 'STREET')]}),
#  ('smp 13 no 39 krukut kel. limo', {'entities': [(0, 6, 'STREET')]}),
#  ('villa verde timur, no 23r', {'entities': [(0, 17, 'STREET')]}),
#  ('bugis jl. jalal tantu kota timur', {'entities': [(6, 21, 'STREET')]}),
#  ('pluit pluit barat iiia 4 rt 16 7', {'entities': [(6, 22, 'STREET')]}),
#  ('air face clot, asep, regol', {'entities': [(15, 19, 'STREET')]}),
#  ('pondok karya agung no.da 10 rt.19', {'entities': [(0, 18, 'POI')]}),
#  ('gg. buana rukun, padangsambian denpasar barat',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('ice tea gopek, tegal barat', {'entities': [(0, 13, 'POI')]}),
#  ('lin bono balam merah pangkalan kuras', {'entities': [(0, 8, 'STREET')]}),
#  ('raya darmo per utara 34 7 pradahkalikendal dukuh pakis',
#   {'entities': [(0, 20, 'STREET')]}),
#  ('timur kelapa gading gad putih raya utara 14 rt 11 12 kelapa gading',
#   {'entities': [(20, 40, 'STREET')]}),
#  ('sentra mand consolindo pt sudi, batam kota',
#   {'entities': [(26, 30, 'STREET')]}),
#  ('gg. usup ii rengas pulau medan marelan', {'entities': [(0, 11, 'STREET')]}),
#  ('pukat v no 39c bantan timur kel.', {'entities': [(0, 7, 'STREET')]}),
#  ('soto dag, dukuh kup,', {'entities': [(10, 19, 'STREET')]}),
#  ('ase, 8 tulungrejo pare', {'entities': [(0, 3, 'STREET')]}),
#  ('lintas sumbawa, ruhil, langam',
#   {'entities': [(16, 21, 'POI'), (0, 14, 'STREET')]}),
#  ('indom, rs ancol, sunter agung tanjung priok',
#   {'entities': [(7, 15, 'STREET')]}),
#  ('cile regol garut kota', {'entities': [(0, 4, 'STREET')]}),
#  ('hima char for palu,si dong, dewi sart,', {'entities': []}),
#  ('peri kem, no 8 warung makan pelangi, rw 1 pudakpayung',
#   {'entities': [(15, 35, 'POI')]}),
#  ('kamp dukuh raya, no 2 toko putra, 6 kebayoran lama utara',
#   {'entities': [(22, 32, 'POI'), (0, 15, 'STREET')]}),
#  ('banyuwangi, genteng, depan rth maron blakang sd 5, rt6, rw1, dusun maron',
#   {'entities': [(27, 36, 'POI')]}),
#  ('bakti jaya bukit perm vii, 2 15315 setu', {'entities': []}),
#  ('cikarang kota kamp jati bumi asih 31 rt 4 rw 11 cikarang utara',
#   {'entities': [(14, 33, 'STREET')]}),
#  ('ks. tubun luar dadi mulya samarinda ulu',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('teluk pucung nanas iiia 8', {'entities': [(13, 23, 'STREET')]}),
#  ('pert sum usaha aruna, cicendo', {'entities': [(15, 20, 'STREET')]}),
#  ('abadi ii, 7-15 gegerkalong', {'entities': [(0, 8, 'STREET')]}),
#  ('ter ii,', {'entities': []}),
#  ('kebon manggis civeilized kesatrian 7, no 22 rw 3 13150',
#   {'entities': [(14, 24, 'POI'), (25, 36, 'STREET')]}),
#  ('pegadaian, sisin,', {'entities': [(0, 9, 'POI'), (11, 16, 'STREET')]}),
#  ('karangtengah sula, 100 66137 sanan wetan',
#   {'entities': [(13, 17, 'STREET')]}),
#  ('kotapontianak,kecamatan barat,provinsi kalbar,jln tabrani ahmad,komplek duta marta,nomor16',
#   {'entities': [(64, 82, 'POI'), (46, 63, 'STREET')]}),
#  ('p. suryaa, no 3 ban nug bang kumis, regol wetan', {'entities': []}),
#  ('pad ii, gg. 1 no 23 pademangan timur rt 11 4',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('abc, merah del 1', {'entities': [(0, 3, 'POI'), (5, 16, 'STREET')]}),
#  ('andi seberida', {'entities': [(0, 4, 'POI')]}),
#  ('asem baris 6 18 kebon baru rt 6 5 tebet',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('kel lilin v curug sangereng kelapa dua', {'entities': [(0, 11, 'STREET')]}),
#  ('asosiasi hutan rak prib hijau, parung kuda', {'entities': []}),
#  ('raya batu jajar, cimareme kel.', {'entities': [(0, 15, 'STREET')]}),
#  ('pol peureulak barat, gampong jawa langsa kota', {'entities': []}),
#  ('kembangan ayu, no 43a rw 5 11610 kembangan',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('refleksi keluarga tiara, putri karin langkai pahandut',
#   {'entities': [(0, 23, 'POI'), (25, 36, 'STREET')]}),
#  ('mas baru, no 4 rt 6 1 pejaten timur pasar minggu',
#   {'entities': [(0, 8, 'STREET')]}),
#  ('kampung batursari batur sari, denpasar selatan',
#   {'entities': [(0, 17, 'POI'), (18, 28, 'STREET')]}),
#  ('fahri pro soek hatta', {'entities': [(10, 20, 'STREET')]}),
#  ('jojo iiic mojo gubeng', {'entities': [(0, 9, 'STREET')]}),
#  ('pipit 6 sukapura rt 2 6 cilincing', {'entities': [(0, 5, 'STREET')]}),
#  ('alams ud, wahid has samarinda utara', {'entities': [(10, 19, 'STREET')]}),
#  ('gg. 3 no 101 rt 3 rw 1', {'entities': [(0, 5, 'STREET')]}),
#  ('prometama sar graha pt ruko sen niaga', {'entities': [(23, 37, 'STREET')]}),
#  ('foto copy natasya , terminal simpang nangka',
#   {'entities': [(20, 43, 'POI')]}),
#  ('jembatan cilaki perbatasan garut cianjur di lesarea cod anya',
#   {'entities': [(0, 15, 'POI')]}),
#  ('zahra pesta, lobak', {'entities': [(0, 11, 'POI'), (13, 18, 'STREET')]}),
#  ('duy, kary novo hotel batam (kop novo), lubuk baja',
#   {'entities': [(0, 3, 'STREET')]}),
#  ('mie ayam bakso pak de darso, polta',
#   {'entities': [(0, 27, 'POI'), (29, 34, 'STREET')]}),
#  ('gg. 5 no 165', {'entities': [(0, 5, 'STREET')]}),
#  ('ran gad, tanimulya ngamprah', {'entities': [(0, 7, 'STREET')]}),
#  ('jelambar baru jela barat iic 52a rt 6 rw 11 11460 grogol petamburan',
#   {'entities': [(14, 28, 'STREET')]}),
#  ('jend sudi 483 rt 1 rw 3 gelora tanah abang', {'entities': []}),
#  ('pesan salafiyah baitur rafki as sadiyah, talu', {'entities': []}),
#  ('moh husni tham no 49 kan penga windu winarso sh,',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('bantan timur pukat v dalam 64 medan tembung',
#   {'entities': [(13, 26, 'STREET')]}),
#  ('kan pu kab. tanah datar', {'entities': []}),
#  ('telaga biru salon santy, 70119', {'entities': [(12, 23, 'POI')]}),
#  ('gg. 14, no 69 sukun', {'entities': [(0, 6, 'STREET')]}),
#  ('kpu kab.gorontalo limboto', {'entities': [(0, 17, 'POI')]}),
#  ('grogol ciare wista 115 rt 7 2 42436 gerogol',
#   {'entities': [(7, 18, 'STREET')]}),
#  ('ulu benteng p. wang marabahan', {'entities': [(12, 19, 'STREET')]}),
#  ('darmaw ii, 4 mas almutathohhirin, rw 1', {'entities': []}),
#  ('munaha dg naba, poros takal', {'entities': []}),
#  ('ahmad yani 1-130 pleburan 1 semarang selatan',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('mts muhamma 4 tel ram, purwodadi sidayu', {'entities': []}),
#  ('tk fit, johar baru utara 2, johar baru johar baru', {'entities': []}),
#  ('mah 29 yosowilangun manyar', {'entities': [(0, 3, 'STREET')]}),
#  ('pt.infomedia nusantara (gedung cambridge lt 3 jl.s. parman medan perisah',
#   {'entities': []}),
#  ('margo rukun xii 6 gundih 9 bubutan', {'entities': [(0, 15, 'STREET')]}),
#  ('tb.mekar abadi, tegalsari', {'entities': [(0, 14, 'POI')]}),
#  ('karsamenak seng, 3 46182 kawalu', {'entities': [(11, 15, 'STREET')]}),
#  ('sakuli pram 7 latambaga', {'entities': [(7, 11, 'STREET')]}),
#  ('selapajang jaya mars surya darma 22-20 rt 1 4',
#   {'entities': [(16, 32, 'STREET')]}),
#  ('jalan aria putra cluster paradise resort blok a2 no 18 serua indah ciputat tangsel',
#   {'entities': [(25, 40, 'POI'), (0, 16, 'STREET')]}),
#  ('kios tani raya, terbanggi besar', {'entities': [(0, 14, 'POI')]}),
#  ('toko alf fashion raya kali royo,', {'entities': [(17, 31, 'STREET')]}),
#  ('sli 4 16 slipi rt 1 3 palmerah', {'entities': [(0, 5, 'STREET')]}),
#  ('po. putra nipah di terminal rawasari', {'entities': [(19, 36, 'POI')]}),
#  ('sastrodirjan ag jeans,', {'entities': [(13, 21, 'POI')]}),
#  ('restoran tang’s. pusat makanan taman sari, boulevard palem raya 2809',
#   {'entities': [(31, 41, 'POI')]}),
#  ('blim no 16-12 kerten laweyan', {'entities': [(0, 4, 'STREET')]}),
#  ('dok setia 141 gegerkalong sukasari', {'entities': []}),
#  ('ahmad yani badan permusyawaratan desa ketanggungan ketanggungan',
#   {'entities': [(11, 50, 'POI'), (0, 10, 'STREET')]}),
#  ('kiori 154 palimanan timur palimanan', {'entities': [(0, 5, 'STREET')]}),
#  ('prabu kolo h r hadij, rw 4 sekaran', {'entities': [(6, 20, 'STREET')]}),
#  ('parit pis mas bagan keladi dumai barat', {'entities': []}),
#  ('pala 2 176 palasari cibiru', {'entities': []}),
#  ('muha rangkapan jaya pancoran mas', {'entities': [(0, 4, 'STREET')]}),
#  ('melody house pen, sayan ubud',
#   {'entities': [(0, 12, 'POI'), (13, 16, 'STREET')]}),
#  ('jun komu mbl griya raya 1, 3 sukawarna',
#   {'entities': [(13, 25, 'STREET')]}),
#  ("jln palmarosa viii blok d9 5 d'amerta residence ciganitri",
#   {'entities': []}),
#  ('smkn 1 purworejo, jl. tentara pelajar kotak pos 127 banyuurip, purworejo 54101',
#   {'entities': [(38, 51, 'POI'), (18, 37, 'STREET')]}),
#  ('tk islam nurul huda', {'entities': [(0, 19, 'POI')]}),
#  ('toko bar, awi bit,', {'entities': [(10, 17, 'STREET')]}),
#  ('kamal raya outer ring road 28b rt 6 rw 14 cengkareng timur kel.',
#   {'entities': [(0, 26, 'STREET')]}),
#  ('rasa say, wijaya kesuma kel. grogol petamburan',
#   {'entities': [(0, 8, 'STREET')]}),
#  ('gg. krad sunggingan kudus kota', {'entities': [(0, 8, 'STREET')]}),
#  ('genteng indah pd raya cile,', {'entities': []}),
#  ('balas klumprik gg. viii 24 rt 6 6 60222', {'entities': []}),
#  ('ikan dor baru 68b 5 krembangan', {'entities': [(0, 13, 'STREET')]}),
#  ('inp 1 sidomulyo timur marpoyan damai', {'entities': []}),
#  ('cempaka putih timur cemp war 10 rt 16 4 cempaka putih',
#   {'entities': [(20, 28, 'STREET')]}),
#  ('bin per no 10 rt 7 3 suka bakti curug', {'entities': []}),
#  ('citra raya cikupa cluster pesona atlantis blok m22 no 30',
#   {'entities': [(18, 41, 'POI')]}),
#  ('urip sumoh pelutan', {'entities': [(0, 10, 'STREET')]}),
#  ('elektrindo perkasa utama pang perjua, tanjung pura',
#   {'entities': [(0, 24, 'POI'), (25, 36, 'STREET')]}),
#  ('kemanggisan sakti viii 45 rt 8 rw 9 palmerah',
#   {'entities': [(12, 22, 'STREET')]}),
#  ('bekasi jaya irig pers ii no 7 rt 9 11 bekasi timur',
#   {'entities': [(12, 24, 'STREET')]}),
#  ('boim cell kem ilir raya, kemanggisan palmerah',
#   {'entities': [(0, 9, 'POI'), (10, 23, 'STREET')]}),
#  ('ansan computer,', {'entities': [(0, 14, 'POI')]}),
#  ('abadi motor, bungah', {'entities': [(0, 11, 'POI')]}),
#  ('cilin lama 1, 41 cilincing rt 5 8 cilincing',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('yudanagara k must 50 46121 cihideung', {'entities': [(11, 17, 'STREET')]}),
#  ('cangkuang kulon sayu 102 40239 dayeuhkolot',
#   {'entities': [(16, 20, 'STREET')]}),
#  ('kedu baru 77 rw 2 kedurus karangpilang', {'entities': [(0, 9, 'STREET')]}),
#  ('eka sari lor transport. pt - agen andongsari - jem (hara, dharmaw, jubung',
#   {'entities': [(58, 65, 'STREET')]}),
#  ('urip sumoh ko pu, tello baru', {'entities': [(0, 16, 'STREET')]}),
#  ('kali baru timur 4, bungur senen', {'entities': [(0, 17, 'STREET')]}),
#  ('taman crys 1,', {'entities': []}),
#  ('sd neg nagrak i, raya buah, buahdua', {'entities': [(17, 26, 'STREET')]}),
#  ('kalidoni mayor zen lor wana 34 kalidoni',
#   {'entities': [(9, 27, 'STREET')]}),
#  ('ciwidey cika sind sari 5', {'entities': [(8, 22, 'STREET')]}),
#  ('menteng masjid agung sunda kelapa, taman sunda kelapa no 16 10310 menteng',
#   {'entities': [(8, 33, 'POI'), (35, 53, 'STREET')]}),
#  ('haji abdul ghani 1 margasari karawaci', {'entities': [(0, 18, 'STREET')]}),
#  ('apartemen green bay pluit tower f, unit f 27 af. jl pluit karang ayu barat,penjaringan,jkt',
#   {'entities': [(10, 19, 'POI'), (49, 74, 'STREET')]}),
#  ('robin jaket, ikan gur telukbetung selatan',
#   {'entities': [(0, 11, 'POI'), (13, 21, 'STREET')]}),
#  ('rusun pinus elok blok a6 -01 penggilingan', {'entities': []}),
#  ('sawah besar dem barat 12 8 50163 gayamsari',
#   {'entities': [(12, 21, 'STREET')]}),
#  ('media cell, denp raya kuningan timur',
#   {'entities': [(0, 10, 'POI'), (12, 21, 'STREET')]}),
#  ("wendy's, vete sidomukti", {'entities': []}),
#  ('jl. mh tham, no 1 kb kebon melati seibu grand indon ug floor tanah abang',
#   {'entities': [(0, 11, 'STREET')]}),
#  ('knalpot putra mahakam, maha 11 65111 klojen',
#   {'entities': [(0, 21, 'POI'), (14, 18, 'STREET')]}),
#  ('rahan unt floating cafe, flamb khay, pahandut',
#   {'entities': [(25, 35, 'STREET')]}),
#  ('muti 57', {'entities': [(0, 4, 'STREET')]}),
#  ("bati aji i salon aliya, pa'batang mamajang",
#   {'entities': [(11, 22, 'POI'), (0, 10, 'STREET')]}),
#  ('perum brd residence jl sunan gresik blok j1 no.8 rt 05 rw 20 pringrejo',
#   {'entities': [(0, 19, 'POI'), (20, 35, 'STREET')]}),
#  ('surya toserba jl karanggetas no 23',
#   {'entities': [(0, 13, 'POI'), (14, 28, 'STREET')]}),
#  ('ptpn viii talun sant sind sirna gegerkalong sukasari',
#   {'entities': [(21, 31, 'STREET')]}),
#  ('cace parf peri kemerd no 80 jati', {'entities': []}),
#  ('jend sudi, no 332 randudongkal randudongkal',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('sungai panas raja haji fisabilillah, 25 batam kota',
#   {'entities': [(13, 35, 'STREET')]}),
#  ('21 cine cih cipaganti', {'entities': []}),
#  ('margahayu tengah sad, 79 margahayu', {'entities': [(17, 20, 'STREET')]}),
#  ('pawon solo, aryo beba,',
#   {'entities': [(0, 10, 'POI'), (12, 21, 'STREET')]}),
#  ('mawar iii, no 19 telukjambe timur', {'entities': [(0, 9, 'STREET')]}),
#  ('soek - hatta 60 kepuhkembeng peterongan',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('yaya pelayanan halieluyah, tebet raya, 30d rw 1 tebet',
#   {'entities': [(27, 37, 'STREET')]}),
#  ('purman tanj beri no al 0 4 pasar rebo', {'entities': [(12, 16, 'STREET')]}),
#  ...]

# %%
with open('pickle/spacy_train_final.pickle','rb') as file:
    train_data_final = pickle.load(file)

# %%
train_data_final
# Out:
# [('jl kapuk timur delta sili iii lippo cika 11 a cicau cikarang pusat',
#   {'entities': [(0, 40, 'STREET')]}),
#  ('aye, jati sampurna', {'entities': []}),
#  ('setu siung 119 rt 5 1 13880 cipayung', {'entities': [(5, 10, 'STREET')]}),
#  ('toko dita, kertosono', {'entities': [(0, 9, 'POI')]}),
#  ('jl. orde baru', {'entities': [(0, 13, 'STREET')]}),
#  ('raya samb gede, 299 toko bb kids',
#   {'entities': [(20, 32, 'POI'), (0, 14, 'STREET')]}),
#  ('kem mel raya, no 4 bojong rawalumbu rt 1 36 rawalumbu',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('tela keuramat kuta alam', {'entities': [(0, 4, 'STREET')]}),
#  ('gg. i wates magersari', {'entities': [(0, 5, 'STREET')]}),
#  ('bunga ncole ix 2', {'entities': [(0, 14, 'STREET')]}),
#  ('cikahuripan sd neg boj 02 klap boj, no 5 16877',
#   {'entities': [(26, 34, 'STREET')]}),
#  ('yaya atohar,', {'entities': []}),
#  ('abim ix 24 5', {'entities': [(0, 7, 'STREET')]}),
#  ('gang xiii rungkut', {'entities': [(0, 9, 'STREET')]}),
#  ('kamp utan jaya, 23 rt 3 rw 8 16433 beji', {'entities': []}),
#  ('kampung.gudang areng,desa:anyer, kecamatan:anyar, kabupaten: serang, belakang bca anyar',
#   {'entities': [(8, 20, 'POI')]}),
#  ('maru baru 2 18 marunda rt 13 3 cilincing',
#   {'entities': [(0, 11, 'STREET')]}),
#  ('pangkalan lareh kel.ikurkoto koto panjang.kec koto tangah kota padang',
#   {'entities': [(0, 15, 'POI')]}),
#  ('tanah sereal pekap raya 5 rt 9 4 11210 tambora',
#   {'entities': [(13, 23, 'STREET')]}),
#  ('tam tama barat v, banyumanik', {'entities': [(0, 16, 'STREET')]}),
#  ('toko bang ajs,', {'entities': []}),
#  ('stadion kobelete,', {'entities': [(0, 16, 'POI')]}),
#  ('tam asri, gg. 7 16 6 morokrembangan krembangan',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('ramb i, pranti', {'entities': [(0, 6, 'STREET')]}),
#  ('angg raya i, jatinegara cakung', {'entities': []}),
#  ('pondok benda bumi raya, no 9 15416 pamulang',
#   {'entities': [(13, 22, 'STREET')]}),
#  ('tajurhalang seta 58 4 16320 tajurhalang',
#   {'entities': [(12, 16, 'STREET')]}),
#  ('jln.tirta tawar, br. junjungan, ubud, barat jalan dajan rurung',
#   {'entities': [(17, 30, 'POI'), (0, 15, 'STREET')]}),
#  ('sadar i lubang buaya kel. cipayung', {'entities': [(0, 7, 'STREET')]}),
#  ('meruya selatan gg. h. juki 59 8 11610 kembangan',
#   {'entities': [(15, 26, 'STREET')]}),
#  ('nogos tlogosari kulon pedurungan', {'entities': [(0, 5, 'STREET')]}),
#  ('jl. amd, komplek borneo lestari, blok 2, no. 30',
#   {'entities': [(9, 31, 'POI'), (0, 7, 'STREET')]}),
#  ('sungai burung raya sege 78351 segedong',
#   {'entities': [(14, 23, 'STREET')]}),
#  ('perumahan bayur sarana indah blok j 5 rt :007 001',
#   {'entities': [(0, 28, 'POI')]}),
#  ('gg. per gunung pangilun padang utara', {'entities': [(0, 7, 'STREET')]}),
#  ('sal gg. iv dangin puri kaja denpasar utara',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('kamp rawa bebek 53 kota baru rt 1 15 bekasi barat',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('selam vii 27a', {'entities': [(0, 9, 'STREET')]}),
#  ('bukit kemuning lin liwa bukit kemuning',
#   {'entities': [(15, 23, 'STREET')]}),
#  ('jln raya solok pad selayo kubung', {'entities': [(0, 18, 'STREET')]}),
#  ('mar tabl metro iringmulyo metro timur', {'entities': []}),
#  ('aa gallery sport pasar muara labuh sungai pagu', {'entities': []}),
#  ('raya kopo babakan asih bojongloa kaler', {'entities': []}),
#  ('roos timur ii, 6 rt 15 5 bukit duri tebet',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('sd neg 12 anggrek', {'entities': []}),
#  ('mulia 6 gajah sakti mandau', {'entities': [(0, 5, 'STREET')]}),
#  ('gg. kera 4 mayong', {'entities': [(0, 10, 'STREET')]}),
#  ('raya cira ciracas ciracas', {'entities': [(0, 9, 'STREET')]}),
#  ('rumah makan pela, raya jomb,', {'entities': [(18, 27, 'STREET')]}),
#  ('kebalen raya babe 43 6 babelan', {'entities': [(8, 17, 'STREET')]}),
#  ('pt. hugo global logistik jl. lavionda blok f11 no. 5 griya loka, bsd city tangerang 15321',
#   {'entities': [(65, 73, 'POI'), (25, 37, 'STREET')]}),
#  ('jatiwarna fajar motor, raya han no 9 pondok melati',
#   {'entities': [(10, 21, 'POI'), (23, 31, 'STREET')]}),
#  ('mah iv 403 margahayu rt 5 rw 16 bekasi timur',
#   {'entities': [(0, 6, 'STREET')]}),
#  ('mas ii 24 rt 2 11', {'entities': [(0, 6, 'STREET')]}),
#  ('samping kiri sd inp. 3 77 tellongeng desa tellongeng kec. mare kab. bone',
#   {'entities': [(58, 72, 'POI')]}),
#  ('beng las listrik rah, raya sorea, cangkuang',
#   {'entities': [(22, 32, 'STREET')]}),
#  ('asrama cpm, jl. lagoa kanal 2a rt. 01 rw. 16, kel. bawang',
#   {'entities': [(0, 10, 'POI'), (12, 30, 'STREET')]}),
#  ('kebon manggis matr 122 3 matraman', {'entities': [(14, 18, 'STREET')]}),
#  ('matr dalam i, 13 pegangsaan rw 8 menteng',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('ple bane siantar utara', {'entities': [(0, 3, 'STREET')]}),
#  ('jl. alm mampang prapatan mampang prapatan',
#   {'entities': [(0, 7, 'STREET')]}),
#  ('sedu put, 8 ilir ilir timur ii', {'entities': []}),
#  ('jl sunan giri, no 22 pondok pucung', {'entities': []}),
#  ('toko depa sambu,', {'entities': [(0, 9, 'POI'), (10, 15, 'STREET')]}),
#  ('cibuluh pangk raya 1 2 16151 bogor utara - kota',
#   {'entities': [(8, 20, 'STREET')]}),
#  ('saka jaya, sum urip', {'entities': []}),
#  ('wol mon kranjingan sumber sari', {'entities': [(0, 7, 'STREET')]}),
#  ('pluit pluit karang jel 13, 8 rt 4 3 14450 penjaringan',
#   {'entities': [(6, 25, 'STREET')]}),
#  ('habitat terrace residence blok d8, jl..masjid ciater, ciater, serpong, 15317.',
#   {'entities': [(0, 25, 'POI'), (35, 45, 'STREET')]}),
#  ('cak 11 nagasari karawang barat', {'entities': []}),
#  ('belakang sdlb lengayang, nagari kambang, kampung medan baik',
#   {'entities': [(49, 59, 'POI')]}),
#  ('aspol spn batua kec panakukang', {'entities': [(0, 9, 'POI')]}),
#  ('raya jepa, 57 depan indomaret rt 1 1 bangsri',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('lebe kader, 389 merah mersa lut tawar', {'entities': [(0, 10, 'STREET')]}),
#  ('rnd prin, gang pinak, sukarame', {'entities': [(10, 20, 'STREET')]}),
#  ('batagor kuah ku bakuku, pahl revo, pondok bambu',
#   {'entities': [(0, 22, 'POI'), (24, 33, 'STREET')]}),
#  ('pp minhajutt, kh abdul manan, sumberberas muncar',
#   {'entities': [(14, 28, 'STREET')]}),
#  ('tk islam daruss,', {'entities': []}),
#  ('lele 1', {'entities': [(0, 6, 'STREET')]}),
#  ('kemb jepun, no 192 bint jaya ud, rw 1 bongkaran pabean cantikan',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('amuntai tengah, hulu sungai utara, kalimantan selatan, turunan jembatan banua lima,',
#   {'entities': [(63, 82, 'POI')]}),
#  ('lidah hara xvii 43 rw 5 60213 lakar santri',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('raya teja pak ginarsa, tejakula',
#   {'entities': [(10, 21, 'POI'), (0, 9, 'STREET')]}),
#  ('jl. raya tlogo gang 1 68 tlogomas rt 5 6 lowokwaru',
#   {'entities': [(0, 21, 'STREET')]}),
#  ('alfamrt 1me5 gs gold pembangunan, no 7 kedunghalang',
#   {'entities': [(0, 20, 'POI'), (21, 32, 'STREET')]}),
#  ('jupi 1 a 4 pisangan rw 13 ciputat timur', {'entities': [(0, 8, 'STREET')]}),
#  ('simpang tiga kah nasu no 112 28284 bukit raya', {'entities': []}),
#  ('sambi 46 kayu putih rt 4 rw 7 pulo gadung',
#   {'entities': [(0, 5, 'STREET')]}),
#  ('jati i 132 pelutan pemalang', {'entities': []}),
#  ('pulau damar, kembangan utara kel.', {'entities': [(0, 11, 'STREET')]}),
#  ('stasiun bekasi kota', {'entities': [(0, 14, 'POI')]}),
#  ('lor batu kar 26 ilir', {'entities': [(0, 12, 'STREET')]}),
#  ('jalan tipar cakung no 26 depan rusun albo garasi dumtruk',
#   {'entities': [(31, 41, 'POI'), (0, 18, 'STREET')]}),
#  ('ngupasan sur 33 gondomanan', {'entities': [(9, 12, 'STREET')]}),
#  ('gg. rah, 26 binjai medan denai', {'entities': [(0, 7, 'STREET')]}),
#  ('cau terr, gal,', {'entities': [(10, 13, 'STREET')]}),
#  ('taman kota kedaung kali angke gg.h.musanif no 54c rt 001 08',
#   {'entities': [(0, 10, 'POI')]}),
#  ('aren jaya sumb iv 319 rt 3 10 17111 bekasi timur',
#   {'entities': [(10, 17, 'STREET')]}),
#  ('shi mel, nanggalo', {'entities': [(0, 7, 'STREET')]}),
#  ('pamoyanan town house blok g no 1', {'entities': []}),
#  ('kedai tenun jep senn, kota bumi, kebon melati',
#   {'entities': [(22, 31, 'STREET')]}),
#  ('wadungasri dalam waru raya wad asri, 24 sidoarjo',
#   {'entities': [(11, 21, 'POI'), (22, 35, 'STREET')]}),
#  ('bulusan tim barat iii, no 35 3 tembalang',
#   {'entities': [(8, 21, 'STREET')]}),
#  ('bakti jaya bukit perm vii 8 15315 setu',
#   {'entities': [(11, 25, 'STREET')]}),
#  ('jl terusan buah batu no 185. samping indomaret. bandung.',
#   {'entities': [(29, 46, 'POI'), (0, 20, 'STREET')]}),
#  ('setia indah, jati, no 12',
#   {'entities': [(0, 11, 'POI'), (13, 17, 'STREET')]}),
#  ('kepuhkiriman gg. bca 61256 waru', {'entities': [(13, 20, 'STREET')]}),
#  ('raya cigan 21 cipagalo bojongsoang', {'entities': [(0, 10, 'STREET')]}),
#  ('selo timur viii 390 12 panggung lor semarang utara',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('gang indah,', {'entities': [(0, 10, 'STREET')]}),
#  ('cv. hin oto kenc, sido ii, q 29', {'entities': [(18, 25, 'STREET')]}),
#  ('jaya utama pramudita pt, holis per 1,',
#   {'entities': [(0, 23, 'POI'), (25, 36, 'STREET')]}),
#  ('pabu 8 rawa arum gerogol', {'entities': [(0, 4, 'STREET')]}),
#  ('cibu no 14 duri pulo rt 8 2 gambir', {'entities': [(0, 4, 'STREET')]}),
#  ('jatisampurna raya pasar kran 1 rt 1 3 jati sampurna',
#   {'entities': [(13, 28, 'STREET')]}),
#  ('send ser 15 rw 8 50273 tembalang', {'entities': [(0, 8, 'STREET')]}),
#  ('batas kampar-ban, pkl unisati, kampar',
#   {'entities': [(18, 29, 'POI'), (0, 16, 'STREET')]}),
#  ('ahmad dah iv kukusan beji', {'entities': []}),
#  ('caval pizz, dip ukur, lebak gede coblong',
#   {'entities': [(12, 20, 'STREET')]}),
#  ('wanajaya intan 4, 2 17520 cibitung', {'entities': [(9, 16, 'STREET')]}),
#  ('gala klam asri sela ii 42 rt 0 0 sukolilo', {'entities': []}),
#  ('panggr ib, 16 kranggan prajurit kulon', {'entities': [(0, 9, 'STREET')]}),
#  ('mas bah ii,', {'entities': []}),
#  ('suka maju propertree coffee-ho, taman mang indah, l 6',
#   {'entities': [(10, 30, 'POI'), (32, 48, 'STREET')]}),
#  ('haji oemar said cokr 129 kalijaya', {'entities': []}),
#  ('p.d anita, gang budi mulia, andir',
#   {'entities': [(0, 9, 'POI'), (11, 26, 'STREET')]}),
#  ('jl. ramba 3 baiya palu utara', {'entities': [(0, 9, 'STREET')]}),
#  ('prat 17 medan satria', {'entities': [(0, 7, 'STREET')]}),
#  ('grey,', {'entities': []}),
#  ('gg. vif no 21 bandulan sukun', {'entities': [(0, 7, 'STREET')]}),
#  ('mangla rege no h1 3 cimekar kel. cileunyi', {'entities': []}),
#  ('haji oemar said cokr jombatan jombang', {'entities': []}),
#  ('dah no 12a cilegon', {'entities': [(0, 3, 'STREET')]}),
#  ('karangduren raya kar 51 rt 7 2 65162', {'entities': [(12, 20, 'STREET')]}),
#  ('beng las deny, mendalanwangi', {'entities': []}),
#  ('cipinang besar selatan lintas ibadah, cipi jaya 1a no 3 rw 7 13410 jatinegara',
#   {'entities': [(23, 36, 'POI')]}),
#  ('sd gmist bethel minanga,', {'entities': [(0, 23, 'POI')]}),
#  ('ber nadah agung', {'entities': []}),
#  ('sd bust islamiah, andi pang petta panakkukang',
#   {'entities': [(18, 33, 'STREET')]}),
#  ('kupang krajan kup kra i 38-f rt 2 3 sawahan',
#   {'entities': [(14, 23, 'STREET')]}),
#  ('cilincing cilin bakti 22 rt 9 6 cilincing',
#   {'entities': [(10, 21, 'STREET')]}),
#  ('sdn gadog o6, raya pun gadog,', {'entities': []}),
#  ('lembu i 5 tatura selatan palu selatan', {'entities': [(0, 7, 'STREET')]}),
#  ('cileunyi kulon h. hol, 77 cileunyi', {'entities': [(15, 21, 'STREET')]}),
#  ('sd neg palumbungan 1, perum wirasana purbalingga',
#   {'entities': [(22, 36, 'STREET')]}),
#  ('jl. dalam malabar lengkong', {'entities': [(0, 9, 'STREET')]}),
#  ('batur vii, no 13 mekarjaya rancasari', {'entities': [(0, 9, 'STREET')]}),
#  ('cafe 4wd, dr. wahi s., pontianak kota', {'entities': []}),
#  ('perum graha gesya, gesya resid, belian',
#   {'entities': [(0, 17, 'POI'), (19, 30, 'STREET')]}),
#  ('jl.pramuka raya no 59a limo depok,depan jembatan 17 .',
#   {'entities': [(40, 51, 'POI'), (0, 15, 'STREET')]}),
#  ('panunggangan barat nn no 23 rt 1 rw 9 cibodas', {'entities': []}),
#  ('bukit tiban selaras a no 3', {'entities': [(0, 19, 'POI')]}),
#  ('ujung harapan, no 48a pd. karya warga mand cimb, bahagia',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('paku 32-26 pakuncen wirobrajan', {'entities': [(0, 4, 'STREET')]}),
#  ('pis, no 8 63132', {'entities': []}),
#  ('prim warna dan rekan kembang jeruk iv, tlogosari kulon',
#   {'entities': [(21, 37, 'STREET')]}),
#  ('paseban kra sawah 24 7 10450 senen', {'entities': [(8, 17, 'STREET')]}),
#  ('alun - alun kuli nusan, kar', {'entities': [(24, 27, 'STREET')]}),
#  ('koala sela jaka mulya bekasi selatan', {'entities': [(0, 10, 'STREET')]}),
#  ('jatim, tegalrejo', {'entities': [(0, 5, 'STREET')]}),
#  ('rawa buaya mang raya, 48 rt 1 8 11740 cengkareng',
#   {'entities': [(11, 20, 'STREET')]}),
#  ('kantor bupati tapa sela serma lian kos, wek ii padang sidempuan utara (padangsidimpuan)',
#   {'entities': [(24, 38, 'STREET')]}),
#  ('kasw 8 kampung anyar buleleng', {'entities': [(0, 4, 'STREET')]}),
#  ('bojong nangka arcadia raya, no 126 16963 gunung putri',
#   {'entities': [(14, 26, 'STREET')]}),
#  ('nga rejo utara 1 ngagelrejo wonokromo', {'entities': [(0, 16, 'STREET')]}),
#  ('rusun pinus elok tower c lt 11no 14', {'entities': []}),
#  ('smk karya pemban, pon,', {'entities': [(18, 21, 'STREET')]}),
#  ('pulo gebang raya pulo geb no 9 rt 2 rw 6 cakung',
#   {'entities': [(12, 25, 'STREET')]}),
#  ('lengkong kulon lengkong kulon 1 pagedangan',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('taman mer, 13 electr laun system, 2 meruya utara', {'entities': []}),
#  ('bambu kun no 25 agen radar, sepanjang jaya',
#   {'entities': [(16, 26, 'POI'), (0, 9, 'STREET')]}),
#  ('mel ledug prigen', {'entities': [(0, 3, 'STREET')]}),
#  ('marina frozen food, pluit per, rt 17 14450',
#   {'entities': [(0, 18, 'POI'), (20, 29, 'STREET')]}),
#  ('depan rth maron(lapangan maron)', {'entities': [(6, 15, 'POI')]}),
#  ('anjas i, no 18 3', {'entities': [(0, 7, 'STREET')]}),
#  ('cica boutique.. jl. ruko kuala mas raya cb 34 semarang utara',
#   {'entities': [(40, 45, 'POI')]}),
#  ('penggilingan padi, ban, bangkingan lakar santri',
#   {'entities': [(0, 17, 'POI'), (19, 22, 'STREET')]}),
#  ('let ars raya no 156 rt 1 rw 1 bekasi selatan',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('green bay condominium, jl. pluit karang ayu barat no. b1 (tower j - 26 al)',
#   {'entities': [(0, 9, 'POI'), (23, 49, 'STREET')]}),
#  ('manisrejo pagu indah iii 15 taman', {'entities': [(10, 24, 'STREET')]}),
#  ('raya mauk pisangan jaya sepatan', {'entities': [(0, 9, 'STREET')]}),
#  ('lelly bout, sum mekar babakan babakan ciparay',
#   {'entities': [(12, 21, 'STREET')]}),
#  ('raya kebon karet - pasar kemis sukaasih pasar kemis', {'entities': []}),
#  ('dadapsari petek 134 1 semarang utara', {'entities': [(10, 15, 'STREET')]}),
#  ('pasi redjeki, man kerto v, mojo', {'entities': []}),
#  ('lokom kaliabang tengah bekasi utara', {'entities': [(0, 5, 'STREET')]}),
#  ('bencongan indah danau toba 3 16 rt 2 6 kelapa dua',
#   {'entities': [(16, 28, 'STREET')]}),
#  ('stati accessories roxy mas, cideng gambir',
#   {'entities': [(18, 26, 'STREET')]}),
#  ('kan desa sumber wangi tps 1, sumber wangi', {'entities': []}),
#  ('desa pangkalan batang barat bukit batu', {'entities': [(0, 27, 'POI')]}),
#  ('pang rambut asgar raya kp utan setu, 32 cibitung',
#   {'entities': [(18, 35, 'STREET')]}),
#  ('mas al latif kademangan setu', {'entities': [(0, 12, 'STREET')]}),
#  ('aempe pluit bat raya pt, soek hatta, no 732 mekar mulya cinambo',
#   {'entities': [(25, 35, 'STREET')]}),
#  ('tulusrejo candi men sela vii no 20 65141 lowokwaru',
#   {'entities': [(10, 28, 'STREET')]}),
#  ('tk 42 zahra, par', {'entities': [(0, 11, 'POI')]}),
#  ('cilandak barat lebak bulus iii 77 rt 9 cilandak',
#   {'entities': [(15, 30, 'STREET')]}),
#  ('seruni hills jl swadaya 3 rt 003 rw 006 jatiranggon',
#   {'entities': [(0, 12, 'POI'), (13, 25, 'STREET')]}),
#  ('mayang 60235 gayungan', {'entities': [(0, 6, 'STREET')]}),
#  ('notaris dan ppat emmy halim, sh., mand utara',
#   {'entities': [(34, 44, 'STREET')]}),
#  ('beng spesia ac mobil ac rio, ling sala,',
#   {'entities': [(29, 38, 'STREET')]}),
#  ('toko sae, tulakan-tegalombo',
#   {'entities': [(0, 8, 'POI'), (10, 27, 'STREET')]}),
#  ('sungai beringin toko taher sound, sungai beri, no 62 tembilahan',
#   {'entities': [(16, 32, 'POI'), (0, 11, 'STREET')]}),
#  ('bau mass, no 173 pt. mirama bacukiki barat',
#   {'entities': [(17, 27, 'POI'), (0, 8, 'STREET')]}),
#  ('pahl no 6 dpc federasi lome sbsi,', {'entities': []}),
#  ('kalij barat i pacar kembang tambaksari', {'entities': [(0, 13, 'STREET')]}),
#  ('ged bersau, pen 1', {'entities': [(12, 17, 'STREET')]}),
#  ('doger cilandak anjatan', {'entities': [(0, 5, 'STREET')]}),
#  ('mie dan nasi gor pak doey, yos suda,', {'entities': []}),
#  ('batu ampar mas con 47 rw 3 kramat jati',
#   {'entities': [(11, 18, 'STREET')]}),
#  ('cahaya abadi, raya cang,',
#   {'entities': [(0, 12, 'POI'), (14, 23, 'STREET')]}),
#  ('toko tan jaya a m sang',
#   {'entities': [(0, 13, 'POI'), (14, 22, 'STREET')]}),
#  ('mantap jaya, raya wono, ketimang',
#   {'entities': [(0, 11, 'POI'), (13, 22, 'STREET')]}),
#  ('stasiun pemalang, j veteran no.28, pelutan,kec. pemalang, kab. pemalang, jawa tengah 52312',
#   {'entities': [(0, 16, 'POI')]}),
#  ('brig kata cangakan karanganyar', {'entities': [(0, 9, 'STREET')]}),
#  ('cengkareng timur taman palem muti 19 rt 6 14 11730 cengkareng',
#   {'entities': [(17, 33, 'STREET')]}),
#  ('suta jaya pekand indra 3 plumbon', {'entities': [(0, 22, 'STREET')]}),
#  ('taman mpu sen 01 selong rt 8 3 kebayoran baru',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('ciman, no 42a ciputat', {'entities': [(0, 5, 'STREET')]}),
#  ('lumbungrejo tem turi pasar tem 55552 tempel',
#   {'entities': [(12, 30, 'STREET')]}),
#  ('pedur mes 2 karet kuningan setia budi', {'entities': [(0, 11, 'STREET')]}),
#  ('war sahabat raya bukit tingg', {'entities': [(12, 28, 'STREET')]}),
#  ('waro bakso bunda pampangan, pampangan', {'entities': []}),
#  ('jl. kon 99 caringin wetan rt 3 4 caringin',
#   {'entities': [(0, 7, 'STREET')]}),
#  ('koja lor z. timur 1 14220 koja', {'entities': [(5, 17, 'STREET')]}),
#  ('nua hijau utama xvii 11 ubung kaja denpasar utara',
#   {'entities': [(0, 20, 'STREET')]}),
#  ('duren tiga graha mamp 2nd floor raya mamp prap 100 rt 2 1 pancoran',
#   {'entities': [(37, 46, 'STREET')]}),
#  ('raya kubu tanj, 79 aur birugo tigo baleh',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('wisnu elektr, raya maja ranca, bojongloa rancaekek',
#   {'entities': [(14, 29, 'STREET')]}),
#  ('jl dirgantara raya depan taman dirgantara rt 07 r w 05 nomor rumah 35a',
#   {'entities': [(25, 41, 'POI'), (0, 18, 'STREET')]}),
#  ('tambal ban eri entiss taman fitness jl. teuku umar',
#   {'entities': [(22, 35, 'POI'), (36, 50, 'STREET')]}),
#  ('raff hills boule jati sampurna', {'entities': [(0, 16, 'STREET')]}),
#  ('kebonsari gg. 9, no 66 sumber sari', {'entities': [(10, 15, 'STREET')]}),
#  ('mt hary 22 purwokerto wetan purwokerto timur',
#   {'entities': [(0, 7, 'STREET')]}),
#  ('pancoran mas 194', {'entities': [(0, 12, 'STREET')]}),
#  ('sanur halte smp 92 by pass ngu rai 340 denpasar selatan',
#   {'entities': [(6, 18, 'POI'), (19, 34, 'STREET')]}),
#  ('rsup persahabatan, gd. rasmin rasjid lt. 1 ipspj (yansos) rawamangun',
#   {'entities': [(0, 17, 'POI')]}),
#  ('darul imarah', {'entities': []}),
#  ('headmost bkl, putri gad cemp,', {'entities': [(0, 12, 'POI')]}),
#  ('stj ( semacam tempat jajan ) ruko pondok nurul fikri . jl tugu raya no.61',
#   {'entities': [(29, 52, 'POI'), (55, 67, 'STREET')]}),
#  ('bukit x no 14 sariwangi parongpong', {'entities': [(0, 7, 'STREET')]}),
#  ('simok iii, 23a rt 3 rw 4 simokerto simokerto',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('sayur segar dan semb ibu sur parangt, brontokusuman mantrijeron',
#   {'entities': []}),
#  ('kan desa sumur musuk boyolali', {'entities': []}),
#  ('kel gad ii kramat jati kramat jati', {'entities': [(0, 10, 'STREET')]}),
#  ('par baris v, pedurungan', {'entities': [(0, 11, 'STREET')]}),
#  ('dewi sart 34 a ciputat ciputat', {'entities': [(0, 9, 'STREET')]}),
#  ('jl. edy raya jl. hali raya setia budi', {'entities': []}),
#  ('bri unit balai selasa', {'entities': [(9, 21, 'POI')]}),
#  ('vita luxe, teuku umar dauh puri kauh',
#   {'entities': [(0, 9, 'POI'), (11, 21, 'STREET')]}),
#  ('toko sejahtera sungai penuh', {'entities': [(0, 14, 'POI')]}),
#  ('arj no 14 jasa ketik yutef wirobrajan wirobrajan',
#   {'entities': [(10, 26, 'POI'), (0, 3, 'STREET')]}),
#  ('rumah cuci ria cemp besar, mawar banjarmasin tengah',
#   {'entities': [(15, 25, 'STREET')]}),
#  ('ba terp an nur, lemahwungkuk', {'entities': []}),
#  ('metal iii, tanjung mulia kel. medan deli',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('kota bambu utara 1 4 rt 16 3 kota bambu utara palmerah',
#   {'entities': [(0, 18, 'STREET')]}),
#  ('kan bupati asa mekar baru', {'entities': []}),
#  ('jl. teknik elektro asrama mahasiswa its gedung h 417,',
#   {'entities': [(19, 39, 'POI'), (0, 18, 'STREET')]}),
#  ('yos suda,', {'entities': [(0, 8, 'STREET')]}),
#  ('asidiq toko,', {'entities': [(0, 11, 'POI')]}),
#  ('raya pon benda, war nasi cipunjur,', {'entities': [(0, 14, 'STREET')]}),
#  ('raya gatot subr 28 turen', {'entities': []}),
#  ('air langga a2 no 2 rt 2 8 tanah sereal', {'entities': [(0, 13, 'STREET')]}),
#  ('jalan sumur bor raya rt  rw 004 012 kel. kalideres kec.kalideres_jakarta barat',
#   {'entities': []}),
#  ('raya baur, 23 baureno', {'entities': [(0, 9, 'STREET')]}),
#  ('luk 296 pejagoan pejagoan', {'entities': [(0, 3, 'STREET')]}),
#  ('tb. kenc, pulau sula', {'entities': [(10, 20, 'STREET')]}),
#  ('t-sh design store, vete cilacap selatan',
#   {'entities': [(19, 23, 'STREET')]}),
#  ('kelapa indah jl. kiha dewan tha cipo keta cipo tange ban 15147 tangerang',
#   {'entities': [(13, 56, 'STREET')]}),
#  ('nota & ppat ary,', {'entities': []}),
#  ('kp. lebak jero', {'entities': [(4, 14, 'POI')]}),
#  ('coun kiis, biringbulu', {'entities': []}),
#  ('gugus depan no 14 rt 12 1 matraman', {'entities': []}),
#  ('tranboge village blok f no 6 kedung waringin bojong gede bogor',
#   {'entities': [(0, 16, 'POI')]}),
#  ('raya pad - pai nanggalo koto xi tarusan',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('warung mbak santi, sumber suko', {'entities': [(0, 17, 'POI')]}),
#  ('she bea hair and spa, dr. soet, no 19c sungai bangkong pontianak kota',
#   {'entities': [(22, 30, 'STREET')]}),
#  ('prodia tower. jl kramat raya no 150',
#   {'entities': [(0, 12, 'POI'), (14, 28, 'STREET')]}),
#  ('beryl barat,', {'entities': []}),
#  ('sukabumi selatan haji raidi 40 rt 10 4 11560 kebon jeruk',
#   {'entities': [(17, 27, 'STREET')]}),
#  ('palem 6 14 helvetia', {'entities': [(0, 7, 'STREET')]}),
#  ('kantor desa manusak,', {'entities': [(0, 19, 'POI')]}),
#  ('macan kumb ix, 5005 siring agung ilir barat i',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('ahass 10306, prof. dr. buny purwokerto utara',
#   {'entities': [(0, 11, 'POI'), (13, 27, 'STREET')]}),
#  ('rambutan raya bogor, 7 rt 4 5 13830 ciracas',
#   {'entities': [(9, 19, 'STREET')]}),
#  ('jatil barat iii ngesrep banyumanik', {'entities': [(0, 15, 'STREET')]}),
#  ('simo tamb 13 exterior store, 5 simomulyo sukomanunggal',
#   {'entities': [(13, 27, 'POI'), (0, 9, 'STREET')]}),
#  ('jasm,', {'entities': [(0, 4, 'STREET')]}),
#  ('jaja polet dan vari, k h abdul halim majalengka kulon majalengka',
#   {'entities': [(21, 36, 'STREET')]}),
#  ('indocar', {'entities': []}),
#  ('puskesmas mekar, prof. dr. ir. sut, mekar sari rangkasbitung',
#   {'entities': [(17, 34, 'STREET')]}),
#  ('tanah sareal ahmad yani 60 rt 1 3 tanah sereal',
#   {'entities': [(13, 23, 'STREET')]}),
#  ('toko wandhe muria, k h ahmad kholil, genteng',
#   {'entities': [(0, 17, 'POI'), (19, 35, 'STREET')]}),
#  ('sky laundry, kamp klit lor, gondokusuman',
#   {'entities': [(0, 11, 'POI'), (13, 26, 'STREET')]}),
#  ('rejo - suruh medayu suruh', {'entities': [(0, 12, 'STREET')]}),
#  ('nasi goreng alazka, sunan ampel',
#   {'entities': [(0, 18, 'POI'), (20, 31, 'STREET')]}),
#  ('poris plawad nn 8 rt 4 1 15141 cipondoh',
#   {'entities': [(13, 15, 'STREET')]}),
#  ('anggrek rosl 2 kemanggisan rt 5 5 palmerah',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('toko tyana modi, klepu kranggan', {'entities': []}),
#  ('bulak kyai tam deres 109 rt 2 3 60124 bulak',
#   {'entities': [(6, 20, 'STREET')]}),
#  ('tanah kali kedinding gg. kemu i 13 rw 1 60127 kenjeran',
#   {'entities': [(21, 31, 'STREET')]}),
#  ('tropodo raya taman bunga 32 61253', {'entities': [(8, 24, 'STREET')]}),
#  ('sisir sul agu gg. 2 1 batu', {'entities': [(6, 19, 'STREET')]}),
#  ('jaya makh konsu, adonis samad, panarung pahandut',
#   {'entities': [(17, 29, 'STREET')]}),
#  ('jl. cinta barl ban baru city tanjung karang timur',
#   {'entities': [(0, 18, 'STREET')]}),
#  ('kebun kac 44 no 10 kebon kacang rt 5 8 tanah abang',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('rafa cell, tent pela, bumijo',
#   {'entities': [(0, 9, 'POI'), (11, 20, 'STREET')]}),
#  ('west union, hus sast, no 194 rw 8', {'entities': []}),
#  ('dupak ban dupak krembangan', {'entities': []}),
#  ('al barokah serv motor, stas ker api', {'entities': [(23, 35, 'STREET')]}),
#  ('cibeureum jend. sudi 851 40535 cimahi selatan',
#   {'entities': [(10, 20, 'STREET')]}),
#  ('mutiara regency b 20, kec. sidoarjo, kabupaten sidoarjo, jawa timur, 61226',
#   {'entities': [(0, 15, 'POI')]}),
#  ('rs qadr komplek islamic village. kelapa dua. karawaci tangerang (titip di satpam ugd )',
#   {'entities': [(8, 31, 'POI')]}),
#  ('kalikotes toko putra jaya, raya tamb kulon, kalikotes',
#   {'entities': [(10, 25, 'POI'), (27, 42, 'STREET')]}),
#  ('biting mawar 90 68191 arjasa', {'entities': [(7, 12, 'STREET')]}),
#  ('kali dha iv,', {'entities': [(0, 11, 'STREET')]}),
#  ('pab dolomit maros, tenrigangkae mandai', {'entities': []}),
#  ('cipaku cip 27 40383', {'entities': [(0, 3, 'STREET')]}),
#  ('pulori, no ar1 7 gamisalila hijab store, jaka setia',
#   {'entities': [(17, 39, 'POI')]}),
#  ('kementerian agama vi, no 1',
#   {'entities': [(0, 17, 'POI'), (18, 20, 'STREET')]}),
#  ('ditresnarkoba polda sumut', {'entities': [(14, 25, 'POI')]}),
#  ('kb auliya, pers alam, no a1 1 16913',
#   {'entities': [(0, 9, 'POI'), (11, 20, 'STREET')]}),
#  ('hang raya cibodas baru cibodas', {'entities': [(0, 9, 'STREET')]}),
#  ('toko wahyu jaya batu ukir lekol s. praw,',
#   {'entities': [(0, 25, 'POI'), (26, 39, 'STREET')]}),
#  ('kawat pena batu, tanah merdeka,', {'entities': [(17, 30, 'STREET')]}),
#  ('daan mogot, batuceper batuceper', {'entities': [(0, 10, 'STREET')]}),
#  ('mar, no 12 turangga lengkong', {'entities': [(0, 3, 'STREET')]}),
#  ('kedai lup 22, tol waru jua rw 9', {'entities': [(14, 26, 'STREET')]}),
#  ('kar utara banyumanik', {'entities': []}),
#  ('rumah makan citra panyileukan komp bumi panyileukan, cipadung kidul panyileukan',
#   {'entities': [(0, 29, 'POI')]}),
#  ('sul iska muda kebayoran lama utara kebayoran lama',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('ser kko badar ii 162 5 3 ilir ilir timur ii',
#   {'entities': [(0, 16, 'STREET')]}),
#  ('mush pare plosoklaten', {'entities': [(5, 9, 'STREET')]}),
#  ('tanj raya ii, 4 parit mayor pontianak timur',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('johunut musholla ataqwa, 57678', {'entities': [(8, 23, 'POI')]}),
#  ('raya man besar no 100 rt 5 6 mangga besar taman sari',
#   {'entities': [(0, 14, 'STREET')]}),
#  ("hani' legging collection, mohammad toha,",
#   {'entities': [(0, 24, 'POI'), (26, 39, 'STREET')]}),
#  ('graha tirta akasia no 96, kec. waru kab. sidoarjo 61256 jatim',
#   {'entities': []}),
#  ('denis massage & spa', {'entities': []}),
#  ('baureno babat boj 153', {'entities': [(8, 17, 'STREET')]}),
#  ('g m. mid mekarsari cimanggis', {'entities': [(0, 8, 'STREET')]}),
#  ('gad indah utara vi, 22 rw 5 bulak', {'entities': [(0, 18, 'STREET')]}),
#  ('bangunjiwo tk pertiwi 20 sps bunga lily kar 55799 kasihan',
#   {'entities': []}),
#  ('cosmat kejak', {'entities': [(7, 12, 'STREET')]}),
#  ('nasi uduk mbak sum, kota bambu sela ii palmerah',
#   {'entities': [(0, 18, 'POI'), (20, 38, 'STREET')]}),
#  ('kantor pos, raya slorok slorok',
#   {'entities': [(0, 10, 'POI'), (12, 23, 'STREET')]}),
#  ('gun tamp i larangan harjamukti', {'entities': [(0, 10, 'STREET')]}),
#  ('lom vape store, sriwi mataram', {'entities': [(16, 21, 'STREET')]}),
#  ("sam ratul, k'kini kor & indonesian restoran, ranowangko",
#   {'entities': [(0, 9, 'STREET')]}),
#  ('raya busu no 1 mojosongo', {'entities': [(0, 9, 'STREET')]}),
#  ('kiangroke pahl rt 3 rw 13 banjaran', {'entities': [(10, 14, 'STREET')]}),
#  ('hesin collection, idrus',
#   {'entities': [(0, 16, 'POI'), (18, 23, 'STREET')]}),
#  ('kre bun iv no 19 pasar baru 6 sawah besar',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('gun anyar lor, gg. i 44 rw 1 gunung anyar gununganyar',
#   {'entities': [(0, 20, 'STREET')]}),
#  ('bont 18 paccinongang somba opu (upu)', {'entities': [(0, 4, 'STREET')]}),
#  ('petamburan pet i 18 rt 3 2 10260 tanah abang',
#   {'entities': [(11, 16, 'STREET')]}),
#  ('haji zai ari,', {'entities': []}),
#  ('lele 2,', {'entities': [(0, 6, 'STREET')]}),
#  ('chat terasutra bogor, pajaj indah ii,', {'entities': [(22, 36, 'STREET')]}),
#  ('dr. suba, ond grup, jember lor',
#   {'entities': [(10, 18, 'POI'), (0, 8, 'STREET')]}),
#  ('jl. raya cilem gang tung bha 4 cigugur tengah cimahi tengah',
#   {'entities': [(0, 30, 'STREET')]}),
#  ('pasar baru kel. palangkaraya, 30 20212',
#   {'entities': [(16, 28, 'STREET')]}),
#  ('maphar hayam wuruk, no 50 rt 9 5 taman sari',
#   {'entities': [(7, 18, 'STREET')]}),
#  ('m. nasir, ogan,', {'entities': [(0, 8, 'POI'), (10, 14, 'STREET')]}),
#  ('maka d5, cipu 1, kebayoran lama', {'entities': [(9, 15, 'STREET')]}),
#  ('jl r.a kartini no 24 dekat alun-alun jepara kota',
#   {'entities': [(27, 43, 'POI')]}),
#  ('east wood, prof. dr. satrio,',
#   {'entities': [(0, 9, 'POI'), (11, 27, 'STREET')]}),
#  ('dpc asosiasi kontraktor lis, kolo sugi,',
#   {'entities': [(29, 38, 'STREET')]}),
#  ('unyur lebak sili gem kasemen', {'entities': [(6, 20, 'STREET')]}),
#  ('rawa bin lubang buaya', {'entities': [(0, 8, 'STREET')]}),
#  ('babakan nasi xi 16 dramaga', {'entities': [(8, 15, 'STREET')]}),
#  ('ad sandi cakra prat pt, pulau karam, kampung pondok',
#   {'entities': [(24, 35, 'STREET')]}),
#  ('intan motor, god, 19', {'entities': [(0, 11, 'POI'), (13, 16, 'STREET')]}),
#  ('slta kart, budi kemul, kampung pelita', {'entities': [(11, 21, 'STREET')]}),
#  ('laiz collection kena, no 15 82111 tabanan',
#   {'entities': [(0, 15, 'POI'), (16, 20, 'STREET')]}),
#  ('giri mekar indah i, cilengkrang', {'entities': [(0, 18, 'STREET')]}),
#  ('gun batu putih 51 maricaya baru makassar',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('reklame percetakan spudnik, sedap malam no 43 rw 1 senen',
#   {'entities': [(0, 26, 'POI'), (28, 39, 'STREET')]}),
#  ('taman mata utama pejuang kel.', {'entities': [(0, 16, 'STREET')]}),
#  ('gg. h. mah bahagia babelan', {'entities': [(0, 10, 'STREET')]}),
#  ('dukuh gg. h. tabah, 26 rt 12 3 13550 kramat jati',
#   {'entities': [(6, 18, 'STREET')]}),
#  ('sd negeri 217x parit culum i, muara sabak timur',
#   {'entities': [(0, 28, 'POI')]}),
#  ('bukit indah 11,', {'entities': [(0, 14, 'STREET')]}),
#  ('bha abri,', {'entities': [(0, 8, 'STREET')]}),
#  ('gani cell, raya dieng krasak',
#   {'entities': [(0, 9, 'POI'), (11, 21, 'STREET')]}),
#  ('kebon jeruk mawar iii 4c rt 2 7 kebon jeruk',
#   {'entities': [(12, 21, 'STREET')]}),
#  ('kese', {'entities': [(0, 4, 'STREET')]}),
#  ('nur cho,', {'entities': []}),
#  ('dony batu, bek barat rawa bunga', {'entities': [(11, 20, 'STREET')]}),
#  ('batu ceper 2, gambir', {'entities': [(0, 12, 'STREET')]}),
#  ('tk al mubar, watu-watu lentarai jaya s. (lantari jaya)', {'entities': []}),
#  ('swad raya 3a sate tongseng gule solo, larangan indah larangan',
#   {'entities': []}),
#  ('argowiyoto, 26 ledok argomulyo', {'entities': [(0, 10, 'STREET')]}),
#  ('segar hara, bukit tung', {'entities': [(12, 22, 'STREET')]}),
#  ('miftahul jan,', {'entities': []}),
#  ('arni souv, porong', {'entities': []}),
#  ('glagah raya pakuniran rt 8 1 67292 pakuniran',
#   {'entities': [(7, 21, 'STREET')]}),
#  ('bromo 5 221 lambangsari rt 2 6 tambun selatan',
#   {'entities': [(0, 7, 'STREET')]}),
#  ('larangan indah bas raya, 77 rt 3 2 15154 larangan',
#   {'entities': [(15, 23, 'STREET')]}),
#  ('pakelan brawi 55 64129', {'entities': [(8, 13, 'STREET')]}),
#  ('sekretariat uppkh kecamatan suko jend gatot subr,', {'entities': []}),
#  ('bumi perm sudi sudiang biring kanaya', {'entities': [(0, 14, 'STREET')]}),
#  ('kaum kulon cigending ujung berung', {'entities': [(0, 10, 'STREET')]}),
#  ('mutiara gading city cluster royal london blok j16 no 16 babelan bekasi',
#   {'entities': [(20, 40, 'POI')]}),
#  ('rumah susun kapuk muara blok b lantai dasar no.13 jl smp 122 kapuk muara',
#   {'entities': [(0, 11, 'POI'), (50, 60, 'STREET')]}),
#  ('pale, 37 paledang lengkong', {'entities': [(9, 17, 'STREET')]}),
#  ('toko coun handphone raya kalija, kalijati', {'entities': []}),
#  ('ciptomulyo kolo sugi 142c 65149 sukun', {'entities': [(11, 20, 'STREET')]}),
#  ('malaka jaya mawar merah ii 140 rt 6 1 duren sawit',
#   {'entities': [(12, 26, 'STREET')]}),
#  ('kp. warung kiara rt rw 001 005 ds mesjid peryayi kec. kasemen',
#   {'entities': [(4, 16, 'POI')]}),
#  ('plu kar el 11 pluit rt 4 12 penjaringan',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('cimuning zam utara raya 19 rt 1 7 17155 mustika jaya',
#   {'entities': [(9, 23, 'STREET')]}),
#  ('cleine appa, simo gun i sawahan', {'entities': [(13, 23, 'STREET')]}),
#  ('mahoni, em cell, giri', {'entities': [(8, 15, 'POI'), (0, 6, 'STREET')]}),
#  ('gedung alfamart bandar tinggi. jalinsum kebun kopi kec. sei suka kab. batubara',
#   {'entities': [(16, 29, 'POI')]}),
#  ('har tho no 48 gresik', {'entities': [(0, 7, 'STREET')]}),
#  ('dah 1 no 76 rt 2 rw 8 jakasampurna bekasi barat',
#   {'entities': [(0, 5, 'STREET')]}),
#  ('gang ramb, 20352 sunggal', {'entities': [(0, 9, 'STREET')]}),
#  ('jend ahmad yani, pt an-nur maarif, macanang tanete riattang barat',
#   {'entities': [(17, 33, 'POI'), (0, 15, 'STREET')]}),
#  ('koperasi putra jaya raya gatot subr barat no 389', {'entities': []}),
#  ('basuk, ayu logam kastolani, balaradin',
#   {'entities': [(7, 26, 'POI'), (0, 5, 'STREET')]}),
#  ('men, 9 andreas, cimanggis', {'entities': []}),
#  ('penerima : ibu nunu suhardini. alamat : anjungan aceh-taman mini indonesia indah',
#   {'entities': []}),
#  ('sukaresmi raya cile, 4 rt 1 3 16165 tanah sereal',
#   {'entities': [(10, 19, 'STREET')]}),
#  ('fifastra motor, mang jombang wetan',
#   {'entities': [(0, 14, 'POI'), (16, 20, 'STREET')]}),
#  ('kan upk,', {'entities': []}),
#  ('sudirejo ii saud 81 20226 medan kota', {'entities': [(12, 16, 'STREET')]}),
#  ('raya cia cika 63 cikaret rt 1 4 bogor selatan - kota',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('komp unil, 9 karang mulya rt 3 6 karang tengah',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('rusa 1, cilincing', {'entities': [(0, 6, 'STREET')]}),
#  ('let supr cempaka baru kemayoran', {'entities': [(0, 8, 'STREET')]}),
#  ('rancaekek wetan raya maja - ranca 243 rancaekek',
#   {'entities': [(16, 33, 'STREET')]}),
#  ('feryal clinic, angg raya, paropo',
#   {'entities': [(0, 13, 'POI'), (15, 24, 'STREET')]}),
#  ('mage, kios total, loano loano', {'entities': []}),
#  ('pasar minggu gur raya 70 rt 3 9 pasar minggu',
#   {'entities': [(13, 21, 'STREET')]}),
#  ('perum bci bukit cileungsi indah no 14 rt26 11', {'entities': []}),
#  ('raya kodam bint 19 rt 5 3 pesanggrahan pesanggrahan',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('taman chem jati, pangkalanjati cinere', {'entities': [(11, 15, 'STREET')]}),
#  ('kebonsari kebon ten 19b 1 60233 jambangan',
#   {'entities': [(10, 19, 'STREET')]}),
#  ('adiwerna salak 33 adiwerna', {'entities': [(9, 14, 'STREET')]}),
#  ('rij, 45 kel karang panjang sirimau', {'entities': [(0, 3, 'STREET')]}),
#  ('ayam penyet, r. wol mongin, bahu', {'entities': [(0, 11, 'POI')]}),
#  ('v star resto, cent raya, batam kota',
#   {'entities': [(0, 12, 'POI'), (14, 23, 'STREET')]}),
#  ('serdang serd ba xiii 24 rt 12 5', {'entities': [(8, 20, 'STREET')]}),
#  ('ps. bertais, lancar mandiri bertais',
#   {'entities': [(13, 27, 'POI'), (0, 11, 'STREET')]}),
#  ('war fikri, maulana yusuf,', {'entities': [(11, 24, 'STREET')]}),
#  ('habib muda seun, meugat meuh seunagan timur',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('sd neg ngembeh i, maysend h. soem, ngembeh',
#   {'entities': [(18, 33, 'STREET')]}),
#  ('veteran utara 224 makassar', {'entities': [(0, 13, 'STREET')]}),
#  ('handil jaya roni sani 40 36125 jelutung',
#   {'entities': [(12, 21, 'STREET')]}),
#  ('badan pemberdayaan masyarakat dan pemerintahan desa, jl. pendidikan no. 43',
#   {'entities': [(0, 51, 'POI'), (53, 67, 'STREET')]}),
#  ('fahriz salon, ujung bori, antang manggala',
#   {'entities': [(0, 12, 'POI'), (14, 24, 'STREET')]}),
#  ('dieng 659 dawuhan lor sukodono', {'entities': [(0, 5, 'STREET')]}),
#  ('pondok betung wij kus ujung, 150 12320 pondok aren',
#   {'entities': [(14, 27, 'STREET')]}),
#  ('toko tasik rawa kun, pulo gebang',
#   {'entities': [(0, 10, 'POI'), (11, 19, 'STREET')]}),
#  ('depan simpang bandara bandara syekh hamzah fansyuri airport',
#   {'entities': [(30, 59, 'POI')]}),
#  ('rawa bangun haji bakri 33684 taman sari',
#   {'entities': [(12, 22, 'STREET')]}),
#  ('perumahan taman carina, no 12 17', {'entities': [(0, 22, 'STREET')]}),
#  ('sid sidotentrem bangilan', {'entities': [(0, 3, 'STREET')]}),
#  ('del bukit raya tenggarong seberang', {'entities': [(0, 3, 'STREET')]}),
#  ('votw co store, waturen, panjer', {'entities': [(0, 13, 'POI')]}),
#  ('toko babun,', {'entities': [(0, 10, 'POI')]}),
#  ('manggala kecaping raya 4 manggala', {'entities': [(9, 22, 'STREET')]}),
#  ('ud rosma group, dusun tanah cellae,desa ulubalang,salomekko,bone,sulawesi selatan',
#   {'entities': [(22, 34, 'POI')]}),
#  ('kayu jati no 2 indriani,',
#   {'entities': [(15, 23, 'POI'), (0, 9, 'STREET')]}),
#  ('stokis hpai lamdi,', {'entities': []}),
#  ('ciputat raya rt 06 07 no 16 gg 45 (sebrang halte selapa)',
#   {'entities': [(43, 55, 'POI')]}),
#  ('sengon jl. mayj sung 14 jombang', {'entities': [(7, 20, 'STREET')]}),
#  ('toko jamu, komar, 92 rw 8 cakung', {'entities': []}),
#  ('dok wahi no 46 noyontaan rw 6 pekalongan timur', {'entities': []}),
#  ('maxime ren kam sragen-,', {'entities': [(15, 22, 'STREET')]}),
#  ('grand pamulang residence blok h no.9, jl. sukamulya raya, kelurahan serua',
#   {'entities': []}),
#  ('masjid lippo cikarang, taman lembah hijau, jl. melati 15',
#   {'entities': [(23, 41, 'POI'), (43, 56, 'STREET')]}),
#  ('perumahan hilltop no. 20, jl. haji japat i rt 011 rw01, abadijaya',
#   {'entities': [(0, 17, 'POI'), (26, 42, 'STREET')]}),
#  ('toko wad, peta no 54 bojongloa kaler', {'entities': [(10, 14, 'STREET')]}),
#  ('kuta alam, asrama tni ad kuta alam. barak 4 no.58.',
#   {'entities': [(11, 24, 'POI')]}),
#  ('sawo 6, lubangbuaya kel.', {'entities': [(0, 6, 'STREET')]}),
#  ('desa pon kanc timur no 1c pondok aren', {'entities': [(0, 19, 'STREET')]}),
#  ('good game stas, gampi r 1 wirobrajan', {'entities': [(16, 21, 'STREET')]}),
#  ('cemp 41 turi', {'entities': [(0, 4, 'STREET')]}),
#  ('jela barat no 21c mie ayam bang dul, rw 10 grogol petamburan',
#   {'entities': [(18, 35, 'POI'), (0, 10, 'STREET')]}),
#  ('pancoran panc barat 9d 23 rt 11 4 12780',
#   {'entities': [(9, 22, 'STREET')]}),
#  ('budi luhur cv rifa, duren sawit',
#   {'entities': [(0, 13, 'POI'), (14, 18, 'STREET')]}),
#  ('ha sarm i bendungan hilir', {'entities': []}),
#  ('pasir nangka jl. aria jaya sent rt 4 2 15720 tigaraksa',
#   {'entities': [(13, 31, 'STREET')]}),
#  ('kec serua ciputat', {'entities': [(0, 3, 'STREET')]}),
#  ('jalan. bangka raya no.4a, pela mampang. warkop aa, seberang pintu keluar kampus mh thamrin',
#   {'entities': [(40, 49, 'POI'), (0, 18, 'STREET')]}),
#  ('vika sela i 1 rt 7 5 kapuk muara penjaringan',
#   {'entities': [(0, 11, 'STREET')]}),
#  ('dokter gigi golden k, manyar kerto v gubeng',
#   {'entities': [(0, 20, 'POI'), (22, 36, 'STREET')]}),
#  ('kapuk pintu seng 78 rt 1 13 cengkareng', {'entities': [(6, 16, 'STREET')]}),
#  ('kebon bawang yos suda, rt 6 14 14320 tanjung priok',
#   {'entities': [(13, 21, 'STREET')]}),
#  ('sem 1, no 278 toi pertamina,', {'entities': [(0, 5, 'STREET')]}),
#  ('mira, dr. moh hatta, pasar pandan air mati tanjung harapan',
#   {'entities': [(0, 4, 'POI'), (6, 19, 'STREET')]}),
#  ('edow cof, ngunut ngunut', {'entities': []}),
#  ('hamalau jend sudi no 141 71261 sungai raya',
#   {'entities': [(8, 17, 'STREET')]}),
#  ('balige fash,', {'entities': []}),
#  ('bag resort,', {'entities': []}),
#  ('toko sol, moch toha muka', {'entities': [(10, 19, 'STREET')]}),
#  ('sd neg 1 sukasada, sukasada', {'entities': []}),
#  ('mata 4, 222', {'entities': [(0, 6, 'STREET')]}),
#  ('optik kania, purwak,', {'entities': [(0, 11, 'POI'), (13, 19, 'STREET')]}),
#  ('toko sami anyar', {'entities': [(0, 15, 'POI')]}),
#  ('30 ilir dok cipto, 31 30121 ilir barat ii',
#   {'entities': [(8, 17, 'STREET')]}),
#  ('atm mand dr suma, cakung', {'entities': [(9, 16, 'STREET')]}),
#  ('rintis alfa busana, hasanuddin, 6', {'entities': [(20, 30, 'STREET')]}),
#  ('tajur puri kart v 10 rt 4 9 15152 ciledug',
#   {'entities': [(6, 17, 'STREET')]}),
#  ('prapen raya manda 1 83511 praya', {'entities': [(7, 17, 'STREET')]}),
#  ('baru jl. poros maje mam 145 banggae', {'entities': [(5, 23, 'STREET')]}),
#  ('toko vera nasio, mayangan',
#   {'entities': [(0, 9, 'POI'), (10, 15, 'STREET')]}),
#  ("alice cake's & cook", {'entities': []}),
#  ('distributor tupper pt. margo pangestu perk mal, jend ahmad yani, no 91 purwodadi blimbing',
#   {'entities': [(48, 63, 'STREET')]}),
#  ('taman maru no 2', {'entities': [(0, 10, 'STREET')]}),
#  ('pekojan bande utara 2, 19 rt 6 9 11240 tambora',
#   {'entities': [(8, 21, 'STREET')]}),
#  ('jln. cilamaya no. 05 (bank bjb kcp gedung sate) kel.citarum kec. bandung wetan kota bandun',
#   {'entities': [(35, 46, 'POI'), (0, 13, 'STREET')]}),
#  ('sd negeri ciki 4, rawa ten pangk 2, bantar gebang',
#   {'entities': [(18, 34, 'STREET')]}),
#  ('dekat pasar terminal subang rt 55rw 14 rumah kontr deket mesjid al falah sukamelang subang',
#   {'entities': [(12, 27, 'POI')]}),
#  ('ika salon, cilangkap, cipayung',
#   {'entities': [(0, 9, 'POI'), (11, 20, 'STREET')]}),
#  ('gado-gado, embong keno', {'entities': [(0, 9, 'POI'), (11, 22, 'STREET')]}),
#  ('kalib, 91 8 pucang sewu gubeng', {'entities': [(0, 5, 'STREET')]}),
#  ('kar ten karang tengah', {'entities': [(0, 7, 'STREET')]}),
#  ('arn mono, sukur kel.', {'entities': [(0, 8, 'STREET')]}),
#  ('raya banjarn - pur, 98 sokaraja tengah sokaraja', {'entities': []}),
#  ('indo tek, raya indu, pasirsari cikarang selatan',
#   {'entities': [(10, 19, 'STREET')]}),
#  ('gang sas ciroyom andir', {'entities': [(0, 8, 'STREET')]}),
#  ('raya kerob 89 kerobokan kuta utara', {'entities': [(0, 10, 'STREET')]}),
#  ('war pla, tamalate', {'entities': []}),
#  ('badan pertan nasional kabupaten jayawi, wamena kota wamena',
#   {'entities': []}),
#  ('ir suci 31 pasar sayur pagi gg bakar,', {'entities': [(11, 36, 'POI')]}),
#  ('warung bunda july, macc sawah, maccini gusung',
#   {'entities': [(0, 17, 'POI')]}),
#  ('tanah tinggi asian high 25, 117 binjai timur',
#   {'entities': [(13, 26, 'STREET')]}),
#  ('jl. raya ser cikande jayanti', {'entities': [(0, 12, 'STREET')]}),
#  ('gatot subr cikarang utara', {'entities': [(0, 10, 'STREET')]}),
#  ('kutisari kuti indah utara x 70 6 tenggilis mejoyo',
#   {'entities': [(9, 27, 'STREET')]}),
#  ('gd. graha matapel jalan arjuna utara no.46 duri kepa',
#   {'entities': [(4, 17, 'POI'), (18, 36, 'STREET')]}),
#  ('pandean lamper bant utara xi, rw 5 gayamsari',
#   {'entities': [(15, 28, 'STREET')]}),
#  ('teuku umar barat 99 kerobokan kelod kuta utara',
#   {'entities': [(0, 16, 'STREET')]}),
#  ('bojongherang ir. haji djua, no 40 43216 cianjur',
#   {'entities': [(13, 26, 'STREET')]}),
#  ('perumahan wahana cikarang, blok f12 no 17 sukadami, cikarang selatan',
#   {'entities': [(0, 16, 'POI')]}),
#  ('dir i, 4 bandung kulon', {'entities': []}),
#  ('raya pasar kemis gelam jaya kel.', {'entities': [(0, 16, 'STREET')]}),
#  ('smk bhakti kartini jalan caringin no.8 jembatan 14, bojong menteng',
#   {'entities': [(39, 50, 'POI'), (19, 33, 'STREET')]}),
#  ('kap cek syeh 183 ilir timur i', {'entities': [(0, 12, 'STREET')]}),
#  ('rm cak anjun kh agus salim, kepek wonosari',
#   {'entities': [(0, 12, 'POI'), (13, 26, 'STREET')]}),
#  ('hang tuah, madras hulu kel.', {'entities': [(0, 9, 'STREET')]}),
#  ('tura barat i no 10 40263 lengkong', {'entities': [(0, 12, 'STREET')]}),
#  ('soto bu nah, bibis, kasihan',
#   {'entities': [(0, 11, 'POI'), (13, 18, 'STREET')]}),
#  ('sug pran, upt mojogedang,',
#   {'entities': [(10, 24, 'POI'), (0, 8, 'STREET')]}),
#  ('gg. perm i 87 jawa singkawang tengah', {'entities': [(0, 10, 'STREET')]}),
#  ('mulia elektr vete tipes serengan', {'entities': [(13, 17, 'STREET')]}),
#  ('tmp kali, martabak top bandung 55 rt 4 7',
#   {'entities': [(10, 33, 'POI'), (0, 8, 'STREET')]}),
#  ('usman cell, diponegoro, gambiran',
#   {'entities': [(0, 10, 'POI'), (12, 22, 'STREET')]}),
#  ('sul sya kasim, kampung dalam siak', {'entities': [(0, 13, 'STREET')]}),
#  ('mel 9 bantaeng', {'entities': [(0, 3, 'STREET')]}),
#  ('bengkulu tengah gula tubu gunung labuhan',
#   {'entities': [(16, 25, 'STREET')]}),
#  ('mariso gagak no 27 90121 mariso', {'entities': [(7, 12, 'STREET')]}),
#  ('wr. ayu, ratna denpasar utara',
#   {'entities': [(0, 7, 'POI'), (9, 14, 'STREET')]}),
#  ('toko crn, gar sakti,', {'entities': [(0, 8, 'POI'), (10, 19, 'STREET')]}),
#  ('the cell, raya ubu, nyerot jonggat', {'entities': []}),
#  ('sida, anda, gaddong bontoala',
#   {'entities': [(0, 4, 'POI'), (6, 10, 'STREET')]}),
#  ('sukamaju jl bukit ment ruko bukit ment r3 #2 jonggol',
#   {'entities': [(9, 44, 'STREET')]}),
#  ('merd, no a18 14 pon kur lassofi,', {'entities': [(0, 4, 'STREET')]}),
#  ('btn kolam blok l 39 doyo baru', {'entities': [(0, 9, 'POI')]}),
#  ('kantor camat mbeliling', {'entities': [(0, 22, 'POI')]}),
#  ('masjid al amin, widodaren', {'entities': [(0, 14, 'POI')]}),
#  ('tk kesaya mutiara blang kolak i bebesen', {'entities': []}),
#  ('sla riyadi, negara indonesia,',
#   {'entities': [(12, 28, 'POI'), (0, 10, 'STREET')]}),
#  ('karet pasar ba bar no 36 rt 12 rw 4 tanah abang',
#   {'entities': [(0, 18, 'STREET')]}),
#  ('colu ten ii 15 nagrak gunung putri', {'entities': []}),
#  ('marga sari 16 babelan', {'entities': [(0, 13, 'STREET')]}),
#  ('pang sudi 17-19 67115 purworejo', {'entities': [(0, 9, 'STREET')]}),
#  ('war mbah suwar purwo martani kalasan', {'entities': []}),
#  ('talang buluh tal kera 1 30961 talang kelapa', {'entities': []}),
#  ('sd panca dharma don bosco 1, bule timur kel gading 8 rt 1 16',
#   {'entities': [(0, 27, 'POI')]}),
#  ('rizky baro,', {'entities': []}),
#  ('kerta bakti, 17 dukuhwaru kel. dukuhwaru',
#   {'entities': [(0, 11, 'STREET')]}),
#  ('kam i 46 utan kayu selatan 6', {'entities': [(0, 5, 'STREET')]}),
#  ('benoa werdi media cem ii no 4 kuta selatan', {'entities': []}),
#  ('raya jat pasar minggu', {'entities': [(0, 8, 'STREET')]}),
#  ('kludan rt 03 rw 03 (belakang sdn kludan)', {'entities': [(29, 39, 'POI')]}),
#  ('gbi sak, sak cengkareng barat', {'entities': []}),
#  ('miea dan bakso kra, wangandawa', {'entities': []}),
#  ('cluster griya sakinah tahap 2 no a5 rt 06 rw 04 jatikramat jatiasih',
#   {'entities': [(8, 29, 'POI')]}),
#  ('petamburan 3, 5b rt 2 3 tanah abang', {'entities': [(0, 12, 'STREET')]}),
#  ('bumi daya raya 9a cinere 9 cinere', {'entities': [(0, 14, 'STREET')]}),
#  ('warung ibu diva kay, 54 rw 4 60271',
#   {'entities': [(0, 15, 'POI'), (16, 19, 'STREET')]}),
#  ('kup kra i kupang krajan sawahan', {'entities': [(0, 9, 'STREET')]}),
#  ('bank rakyat indonesia, pisa baru ten, no 37a 14 13110 matraman',
#   {'entities': [(0, 21, 'POI'), (23, 36, 'STREET')]}),
#  ('karangmangu ser ii, 6 53282', {'entities': [(12, 18, 'STREET')]}),
#  ('raya taman asri no 32 waru', {'entities': [(0, 15, 'STREET')]}),
#  ('kapuas kanan hulu kolo sugi 82 78613 sintang', {'entities': []}),
#  ('cipi muara raya jatinegara', {'entities': []}),
#  ('nusa indah 8 serua ciputat', {'entities': [(0, 10, 'STREET')]}),
#  ('macc gus,', {'entities': []}),
#  ('al maqbul (jalan raya kuwolu ) rt 9 rw 3',
#   {'entities': [(0, 9, 'POI'), (11, 28, 'STREET')]}),
#  ('bat internasional finansindo pt gajah mada, no 13cd rw 1',
#   {'entities': [(32, 42, 'STREET')]}),
#  ('alian 21 toko optimal,', {'entities': [(9, 21, 'POI'), (0, 5, 'STREET')]}),
#  ('ruko perm cibu, no 27 toko uda colection cileungsi kidul cileungsi',
#   {'entities': [(22, 40, 'POI'), (0, 14, 'STREET')]}),
#  ('lin timur, kios ika sekijang bandar sei kijang',
#   {'entities': [(11, 19, 'POI')]}),
#  ('jelambar emp baha gg. ix emp baha 4 no 60 rt 11 6 grogol petamburan',
#   {'entities': [(9, 35, 'STREET')]}),
#  ('getuk goreng murni asli soka,', {'entities': []}),
#  ('pondok labu pon labu i 36c rt 2 7 cilandak',
#   {'entities': [(12, 22, 'STREET')]}),
#  ('kamp baba 19 pasirkuda bogor barat - kota',
# ...
#  ('focus collec kebon jeruk 6, maphar taman sari',
#   {'entities': [(13, 26, 'STREET')]}),
#  ('cibogo raya tangk par, 47 40391', {'entities': [(7, 21, 'STREET')]}),
#  ('soto dag cak mul, bhayan juwet kenongo porong',
#   {'entities': [(18, 24, 'STREET')]}),
#  ('sun sadan 35 nunu palu barat', {'entities': [(0, 9, 'STREET')]}),
#  ('pt surya serba mulia laksa malahayati, telukbetung selatan',
#   {'entities': [(0, 20, 'POI'), (21, 37, 'STREET')]}),
#  ('wono no 40 banguntapan', {'entities': [(0, 4, 'STREET')]}),
#  ('tanj 1 no 6 rt 7 rw 2 jagakarsa', {'entities': [(0, 6, 'STREET')]}),
#  ('tukad penat, 27 serangan denpasar selatan', {'entities': []}),
#  ('flamb can, no 9 sultan house of moshi pudd halal 12 rempoa',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('tegal mraen sendangadi mlati', {'entities': []}),
#  ('rumah makan riyan, kuta', {'entities': []}),
#  ('i b bulakan balai kandih payakumbuh barat',
#   {'entities': [(0, 3, 'STREET')]}),
#  ('forest hill, jl. raya kabasiran, kabasiran, parung panjang, bogor, west java',
#   {'entities': [(0, 11, 'POI'), (13, 31, 'STREET')]}),
#  ('pad ii, gg. 5 3 rt 12 rw 6 pademangan', {'entities': [(0, 13, 'STREET')]}),
#  ('mawar raya, 62 wanasari cibitung', {'entities': [(0, 10, 'STREET')]}),
#  ('teluk gong raya, no 32 rubi murni perk pt rt 4 penjaringan',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('marto soto wijirejo', {'entities': [(0, 10, 'POI')]}),
#  ('derw no 105a derwati rancasari', {'entities': [(0, 4, 'STREET')]}),
#  ('gerbang permai pamengkang f6 no8 cirebon', {'entities': [(0, 14, 'POI')]}),
#  ('toko tripena, brastagi (berastagi)', {'entities': []}),
#  ('.h.n raya pondok gede', {'entities': [(0, 9, 'STREET')]}),
#  ('waru raya 62 jatimulya tambun selatan', {'entities': [(0, 9, 'STREET')]}),
#  ('siwa no 18 nyatnyono ungaran barat', {'entities': [(0, 4, 'STREET')]}),
#  ('sib barat 3 mojosongo jebres', {'entities': [(0, 9, 'STREET')]}),
#  ('kedung badak kol. enjo mart 26-41 rt 5 12 16164 tanah sereal',
#   {'entities': [(13, 27, 'STREET')]}),
#  ('ramona artiran bakery, raya panc,', {'entities': [(0, 21, 'POI')]}),
#  ('haji namin cipete utara kel.', {'entities': []}),
#  ('purwoyoso purwo slt i, 39 11 ngaliyan', {'entities': [(10, 21, 'STREET')]}),
#  ('kebo iwa 27 padangsambian kaja kel.', {'entities': []}),
#  ('maje tak arra, abung barat', {'entities': []}),
#  ('simomulyo sim baru vii no 41 5', {'entities': [(10, 22, 'STREET')]}),
#  ('menanggal jl. gay timur mgp, no 2 6 gayungan', {'entities': []}),
#  ('war maknyak kutuk barat, as 10', {'entities': [(12, 23, 'STREET')]}),
#  ('vina cell, ampel gad, ngijo',
#   {'entities': [(0, 9, 'POI'), (11, 20, 'STREET')]}),
#  ('toko jam je one, jl. pocut baren no. 44 a, laksana',
#   {'entities': [(0, 15, 'POI'), (17, 32, 'STREET')]}),
#  ('oleh-oleh peuyeum khas bandung, r e mar, pulomerak',
#   {'entities': [(0, 30, 'POI'), (32, 39, 'STREET')]}),
#  ('soek hatta, no 726 ayam penyet and sam goang d 45 da, situsaeur bojongloa kidul',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('mts tan, wad asri dalam no 170', {'entities': [(9, 23, 'STREET')]}),
#  ('tre barat 3 mertasinga 3 cilacap utara', {'entities': [(0, 9, 'STREET')]}),
#  ('warung valen 27 gar kunjung mae', {'entities': [(16, 19, 'STREET')]}),
#  ('smp 13 no 39 krukut kel. limo', {'entities': [(0, 6, 'STREET')]}),
#  ('villa verde timur, no 23r', {'entities': [(0, 17, 'STREET')]}),
#  ('bugis jl. jalal tantu kota timur', {'entities': [(6, 21, 'STREET')]}),
#  ('pluit pluit barat iiia 4 rt 16 7', {'entities': [(6, 22, 'STREET')]}),
#  ('air face clot, asep, regol', {'entities': [(15, 19, 'STREET')]}),
#  ('pondok karya agung no.da 10 rt.19', {'entities': [(0, 18, 'POI')]}),
#  ('gg. buana rukun, padangsambian denpasar barat',
#   {'entities': [(0, 15, 'STREET')]}),
#  ('ice tea gopek, tegal barat', {'entities': [(0, 13, 'POI')]}),
#  ('lin bono balam merah pangkalan kuras', {'entities': [(0, 8, 'STREET')]}),
#  ('raya darmo per utara 34 7 pradahkalikendal dukuh pakis',
#   {'entities': [(0, 20, 'STREET')]}),
#  ('timur kelapa gading gad putih raya utara 14 rt 11 12 kelapa gading',
#   {'entities': [(20, 40, 'STREET')]}),
#  ('sentra mand consolindo pt sudi, batam kota',
#   {'entities': [(26, 30, 'STREET')]}),
#  ('gg. usup ii rengas pulau medan marelan', {'entities': [(0, 11, 'STREET')]}),
#  ('pukat v no 39c bantan timur kel.', {'entities': [(0, 7, 'STREET')]}),
#  ('soto dag, dukuh kup,', {'entities': [(10, 19, 'STREET')]}),
#  ('ase, 8 tulungrejo pare', {'entities': [(0, 3, 'STREET')]}),
#  ('lintas sumbawa, ruhil, langam',
#   {'entities': [(16, 21, 'POI'), (0, 14, 'STREET')]}),
#  ('indom, rs ancol, sunter agung tanjung priok',
#   {'entities': [(7, 15, 'STREET')]}),
#  ('cile regol garut kota', {'entities': [(0, 4, 'STREET')]}),
#  ('hima char for palu,si dong, dewi sart,', {'entities': []}),
#  ('peri kem, no 8 warung makan pelangi, rw 1 pudakpayung',
#   {'entities': [(15, 35, 'POI')]}),
#  ('kamp dukuh raya, no 2 toko putra, 6 kebayoran lama utara',
#   {'entities': [(22, 32, 'POI'), (0, 15, 'STREET')]}),
#  ('banyuwangi, genteng, depan rth maron blakang sd 5, rt6, rw1, dusun maron',
#   {'entities': [(27, 36, 'POI')]}),
#  ('bakti jaya bukit perm vii, 2 15315 setu', {'entities': []}),
#  ('cikarang kota kamp jati bumi asih 31 rt 4 rw 11 cikarang utara',
#   {'entities': [(14, 33, 'STREET')]}),
#  ('ks. tubun luar dadi mulya samarinda ulu',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('teluk pucung nanas iiia 8', {'entities': [(13, 23, 'STREET')]}),
#  ('pert sum usaha aruna, cicendo', {'entities': [(15, 20, 'STREET')]}),
#  ('abadi ii, 7-15 gegerkalong', {'entities': [(0, 8, 'STREET')]}),
#  ('ter ii,', {'entities': []}),
#  ('kebon manggis civeilized kesatrian 7, no 22 rw 3 13150',
#   {'entities': [(14, 24, 'POI'), (25, 36, 'STREET')]}),
#  ('pegadaian, sisin,', {'entities': [(0, 9, 'POI'), (11, 16, 'STREET')]}),
#  ('karangtengah sula, 100 66137 sanan wetan',
#   {'entities': [(13, 17, 'STREET')]}),
#  ('kotapontianak,kecamatan barat,provinsi kalbar,jln tabrani ahmad,komplek duta marta,nomor16',
#   {'entities': [(64, 82, 'POI'), (46, 63, 'STREET')]}),
#  ('p. suryaa, no 3 ban nug bang kumis, regol wetan', {'entities': []}),
#  ('pad ii, gg. 1 no 23 pademangan timur rt 11 4',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('abc, merah del 1', {'entities': [(0, 3, 'POI'), (5, 16, 'STREET')]}),
#  ('andi seberida', {'entities': [(0, 4, 'POI')]}),
#  ('asem baris 6 18 kebon baru rt 6 5 tebet',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('kel lilin v curug sangereng kelapa dua', {'entities': [(0, 11, 'STREET')]}),
#  ('asosiasi hutan rak prib hijau, parung kuda', {'entities': []}),
#  ('raya batu jajar, cimareme kel.', {'entities': [(0, 15, 'STREET')]}),
#  ('pol peureulak barat, gampong jawa langsa kota', {'entities': []}),
#  ('kembangan ayu, no 43a rw 5 11610 kembangan',
#   {'entities': [(0, 13, 'STREET')]}),
#  ('refleksi keluarga tiara, putri karin langkai pahandut',
#   {'entities': [(0, 23, 'POI'), (25, 36, 'STREET')]}),
#  ('mas baru, no 4 rt 6 1 pejaten timur pasar minggu',
#   {'entities': [(0, 8, 'STREET')]}),
#  ('kampung batursari batur sari, denpasar selatan',
#   {'entities': [(0, 17, 'POI'), (18, 28, 'STREET')]}),
#  ('fahri pro soek hatta', {'entities': [(10, 20, 'STREET')]}),
#  ('jojo iiic mojo gubeng', {'entities': [(0, 9, 'STREET')]}),
#  ('pipit 6 sukapura rt 2 6 cilincing', {'entities': [(0, 5, 'STREET')]}),
#  ('alams ud, wahid has samarinda utara', {'entities': [(10, 19, 'STREET')]}),
#  ('gg. 3 no 101 rt 3 rw 1', {'entities': [(0, 5, 'STREET')]}),
#  ('prometama sar graha pt ruko sen niaga', {'entities': [(23, 37, 'STREET')]}),
#  ('foto copy natasya , terminal simpang nangka',
#   {'entities': [(20, 43, 'POI')]}),
#  ('jembatan cilaki perbatasan garut cianjur di lesarea cod anya',
#   {'entities': [(0, 15, 'POI')]}),
#  ('zahra pesta, lobak', {'entities': [(0, 11, 'POI'), (13, 18, 'STREET')]}),
#  ('duy, kary novo hotel batam (kop novo), lubuk baja',
#   {'entities': [(0, 3, 'STREET')]}),
#  ('mie ayam bakso pak de darso, polta',
#   {'entities': [(0, 27, 'POI'), (29, 34, 'STREET')]}),
#  ('gg. 5 no 165', {'entities': [(0, 5, 'STREET')]}),
#  ('ran gad, tanimulya ngamprah', {'entities': [(0, 7, 'STREET')]}),
#  ('jelambar baru jela barat iic 52a rt 6 rw 11 11460 grogol petamburan',
#   {'entities': [(14, 28, 'STREET')]}),
#  ('jend sudi 483 rt 1 rw 3 gelora tanah abang', {'entities': []}),
#  ('pesan salafiyah baitur rafki as sadiyah, talu', {'entities': []}),
#  ('moh husni tham no 49 kan penga windu winarso sh,',
#   {'entities': [(0, 14, 'STREET')]}),
#  ('bantan timur pukat v dalam 64 medan tembung',
#   {'entities': [(13, 26, 'STREET')]}),
#  ('kan pu kab. tanah datar', {'entities': []}),
#  ('telaga biru salon santy, 70119', {'entities': [(12, 23, 'POI')]}),
#  ('gg. 14, no 69 sukun', {'entities': [(0, 6, 'STREET')]}),
#  ('kpu kab.gorontalo limboto', {'entities': [(0, 17, 'POI')]}),
#  ('grogol ciare wista 115 rt 7 2 42436 gerogol',
#   {'entities': [(7, 18, 'STREET')]}),
#  ('ulu benteng p. wang marabahan', {'entities': [(12, 19, 'STREET')]}),
#  ('darmaw ii, 4 mas almutathohhirin, rw 1', {'entities': []}),
#  ('munaha dg naba, poros takal', {'entities': []}),
#  ('ahmad yani 1-130 pleburan 1 semarang selatan',
#   {'entities': [(0, 10, 'STREET')]}),
#  ('mts muhamma 4 tel ram, purwodadi sidayu', {'entities': []}),
#  ('tk fit, johar baru utara 2, johar baru johar baru', {'entities': []}),
#  ('mah 29 yosowilangun manyar', {'entities': [(0, 3, 'STREET')]}),
#  ('pt.infomedia nusantara (gedung cambridge lt 3 jl.s. parman medan perisah',
#   {'entities': []}),
#  ('margo rukun xii 6 gundih 9 bubutan', {'entities': [(0, 15, 'STREET')]}),
#  ('tb.mekar abadi, tegalsari', {'entities': [(0, 14, 'POI')]}),
#  ('karsamenak seng, 3 46182 kawalu', {'entities': [(11, 15, 'STREET')]}),
#  ('sakuli pram 7 latambaga', {'entities': [(7, 11, 'STREET')]}),
#  ('selapajang jaya mars surya darma 22-20 rt 1 4',
#   {'entities': [(16, 32, 'STREET')]}),
#  ('jalan aria putra cluster paradise resort blok a2 no 18 serua indah ciputat tangsel',
#   {'entities': [(25, 40, 'POI'), (0, 16, 'STREET')]}),
#  ('kios tani raya, terbanggi besar', {'entities': [(0, 14, 'POI')]}),
#  ('toko alf fashion raya kali royo,', {'entities': [(17, 31, 'STREET')]}),
#  ('sli 4 16 slipi rt 1 3 palmerah', {'entities': [(0, 5, 'STREET')]}),
#  ('po. putra nipah di terminal rawasari', {'entities': [(19, 36, 'POI')]}),
#  ('sastrodirjan ag jeans,', {'entities': [(13, 21, 'POI')]}),
#  ('restoran tang’s. pusat makanan taman sari, boulevard palem raya 2809',
#   {'entities': [(31, 41, 'POI')]}),
#  ('blim no 16-12 kerten laweyan', {'entities': [(0, 4, 'STREET')]}),
#  ('dok setia 141 gegerkalong sukasari', {'entities': []}),
#  ('ahmad yani badan permusyawaratan desa ketanggungan ketanggungan',
#   {'entities': [(11, 50, 'POI'), (0, 10, 'STREET')]}),
#  ('kiori 154 palimanan timur palimanan', {'entities': [(0, 5, 'STREET')]}),
#  ('prabu kolo h r hadij, rw 4 sekaran', {'entities': [(6, 20, 'STREET')]}),
#  ('parit pis mas bagan keladi dumai barat', {'entities': []}),
#  ('pala 2 176 palasari cibiru', {'entities': []}),
#  ('muha rangkapan jaya pancoran mas', {'entities': [(0, 4, 'STREET')]}),
#  ('melody house pen, sayan ubud',
#   {'entities': [(0, 12, 'POI'), (13, 16, 'STREET')]}),
#  ('jun komu mbl griya raya 1, 3 sukawarna',
#   {'entities': [(13, 25, 'STREET')]}),
#  ("jln palmarosa viii blok d9 5 d'amerta residence ciganitri",
#   {'entities': []}),
#  ('smkn 1 purworejo, jl. tentara pelajar kotak pos 127 banyuurip, purworejo 54101',
#   {'entities': [(38, 51, 'POI'), (18, 37, 'STREET')]}),
#  ('tk islam nurul huda', {'entities': [(0, 19, 'POI')]}),
#  ('toko bar, awi bit,', {'entities': [(10, 17, 'STREET')]}),
#  ('kamal raya outer ring road 28b rt 6 rw 14 cengkareng timur kel.',
#   {'entities': [(0, 26, 'STREET')]}),
#  ('rasa say, wijaya kesuma kel. grogol petamburan',
#   {'entities': [(0, 8, 'STREET')]}),
#  ('gg. krad sunggingan kudus kota', {'entities': [(0, 8, 'STREET')]}),
#  ('genteng indah pd raya cile,', {'entities': []}),
#  ('balas klumprik gg. viii 24 rt 6 6 60222', {'entities': []}),
#  ('ikan dor baru 68b 5 krembangan', {'entities': [(0, 13, 'STREET')]}),
#  ('inp 1 sidomulyo timur marpoyan damai', {'entities': []}),
#  ('cempaka putih timur cemp war 10 rt 16 4 cempaka putih',
#   {'entities': [(20, 28, 'STREET')]}),
#  ('bin per no 10 rt 7 3 suka bakti curug', {'entities': []}),
#  ('citra raya cikupa cluster pesona atlantis blok m22 no 30',
#   {'entities': [(18, 41, 'POI')]}),
#  ('urip sumoh pelutan', {'entities': [(0, 10, 'STREET')]}),
#  ('elektrindo perkasa utama pang perjua, tanjung pura',
#   {'entities': [(0, 24, 'POI'), (25, 36, 'STREET')]}),
#  ('kemanggisan sakti viii 45 rt 8 rw 9 palmerah',
#   {'entities': [(12, 22, 'STREET')]}),
#  ('bekasi jaya irig pers ii no 7 rt 9 11 bekasi timur',
#   {'entities': [(12, 24, 'STREET')]}),
#  ('boim cell kem ilir raya, kemanggisan palmerah',
#   {'entities': [(0, 9, 'POI'), (10, 23, 'STREET')]}),
#  ('ansan computer,', {'entities': [(0, 14, 'POI')]}),
#  ('abadi motor, bungah', {'entities': [(0, 11, 'POI')]}),
#  ('cilin lama 1, 41 cilincing rt 5 8 cilincing',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('yudanagara k must 50 46121 cihideung', {'entities': [(11, 17, 'STREET')]}),
#  ('cangkuang kulon sayu 102 40239 dayeuhkolot',
#   {'entities': [(16, 20, 'STREET')]}),
#  ('kedu baru 77 rw 2 kedurus karangpilang', {'entities': [(0, 9, 'STREET')]}),
#  ('eka sari lor transport. pt - agen andongsari - jem (hara, dharmaw, jubung',
#   {'entities': [(58, 65, 'STREET')]}),
#  ('urip sumoh ko pu, tello baru', {'entities': [(0, 16, 'STREET')]}),
#  ('kali baru timur 4, bungur senen', {'entities': [(0, 17, 'STREET')]}),
#  ('taman crys 1,', {'entities': []}),
#  ('sd neg nagrak i, raya buah, buahdua', {'entities': [(17, 26, 'STREET')]}),
#  ('kalidoni mayor zen lor wana 34 kalidoni',
#   {'entities': [(9, 27, 'STREET')]}),
#  ('ciwidey cika sind sari 5', {'entities': [(8, 22, 'STREET')]}),
#  ('menteng masjid agung sunda kelapa, taman sunda kelapa no 16 10310 menteng',
#   {'entities': [(8, 33, 'POI'), (35, 53, 'STREET')]}),
#  ('haji abdul ghani 1 margasari karawaci', {'entities': [(0, 18, 'STREET')]}),
#  ('apartemen green bay pluit tower f, unit f 27 af. jl pluit karang ayu barat,penjaringan,jkt',
#   {'entities': [(10, 19, 'POI'), (49, 74, 'STREET')]}),
#  ('robin jaket, ikan gur telukbetung selatan',
#   {'entities': [(0, 11, 'POI'), (13, 21, 'STREET')]}),
#  ('rusun pinus elok blok a6 -01 penggilingan', {'entities': []}),
#  ('sawah besar dem barat 12 8 50163 gayamsari',
#   {'entities': [(12, 21, 'STREET')]}),
#  ('media cell, denp raya kuningan timur',
#   {'entities': [(0, 10, 'POI'), (12, 21, 'STREET')]}),
#  ("wendy's, vete sidomukti", {'entities': []}),
#  ('jl. mh tham, no 1 kb kebon melati seibu grand indon ug floor tanah abang',
#   {'entities': [(0, 11, 'STREET')]}),
#  ('knalpot putra mahakam, maha 11 65111 klojen',
#   {'entities': [(0, 21, 'POI'), (23, 27, 'STREET')]}),
#  ('rahan unt floating cafe, flamb khay, pahandut',
#   {'entities': [(25, 35, 'STREET')]}),
#  ('muti 57', {'entities': [(0, 4, 'STREET')]}),
#  ("bati aji i salon aliya, pa'batang mamajang",
#   {'entities': [(11, 22, 'POI'), (0, 10, 'STREET')]}),
#  ('perum brd residence jl sunan gresik blok j1 no.8 rt 05 rw 20 pringrejo',
#   {'entities': [(0, 19, 'POI'), (20, 35, 'STREET')]}),
#  ('surya toserba jl karanggetas no 23',
#   {'entities': [(0, 13, 'POI'), (14, 28, 'STREET')]}),
#  ('ptpn viii talun sant sind sirna gegerkalong sukasari',
#   {'entities': [(21, 31, 'STREET')]}),
#  ('cace parf peri kemerd no 80 jati', {'entities': []}),
#  ('jend sudi, no 332 randudongkal randudongkal',
#   {'entities': [(0, 9, 'STREET')]}),
#  ('sungai panas raja haji fisabilillah, 25 batam kota',
#   {'entities': [(13, 35, 'STREET')]}),
#  ('21 cine cih cipaganti', {'entities': []}),
#  ('margahayu tengah sad, 79 margahayu', {'entities': [(17, 20, 'STREET')]}),
#  ('pawon solo, aryo beba,',
#   {'entities': [(0, 10, 'POI'), (12, 21, 'STREET')]}),
#  ('mawar iii, no 19 telukjambe timur', {'entities': [(0, 9, 'STREET')]}),
#  ('soek - hatta 60 kepuhkembeng peterongan',
#   {'entities': [(0, 12, 'STREET')]}),
#  ('yaya pelayanan halieluyah, tebet raya, 30d rw 1 tebet',
#   {'entities': [(27, 37, 'STREET')]}),
#  ('purman tanj beri no al 0 4 pasar rebo', {'entities': [(12, 16, 'STREET')]}),
#  ...]

# %% [markdown]
# ## Model 1 ( with 'xx_ent_wiki_sm' ) multi-language model

# %%
nlp = spacy.load('xx_ent_wiki_sm')

# %%
tokens = nlp("I work at Google, Facebook and Twitter")

# %%
for ent in tokens.ents:
    print(ent.text)
# Out:
# Google
# Facebook
# Twitter

# %%
nlp.pipe_names
# Out:
# ['ner']

# %%
ner = nlp.get_pipe('ner')

# %%
# add POI and street label to ner
for _, annotations in train_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
optimizer = nlp.resume_training()
examples = []
for text, annots in tqdm(train_data):
    try:
        examples.append(Example.from_dict(nlp.make_doc(text), annots))
        warnings.filterwarnings("ignore")
    except:
        continue
    
nlp.initialize(lambda: examples)    
for i in tqdm(range(50)):
    random.shuffle(examples)
    losses = {}

    for batch in minibatch(examples, size=128):
        nlp.update(batch, losses = losses, sgd = optimizer)
        #print('Losses: ', losses)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 300000/300000 [00:34<00:00, 8774.21it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 50/50 [10:33:24<00:00, 760.08s/it]

# %%
tokens = nlp('banjarn scoo club, letjen supr, kutabanjarnegara banjarnegara')
for ent in tokens.ents:
    print(ent.text, ent.label_)
# Out:
# letjen supr STREET

# %%
nlp.to_disk('./id_ner_address')

# %% [markdown]
# ## Model 2 ( with 'en_core_web_lg' ) large english model

# %%
nlp2 = spacy.load('en_core_web_lg')

# %%
tokens2 = nlp2("I work at Google, Facebook and Twitter")

# %%
for ent in tokens2.ents:
    print(ent.text)
# Out:
# Google
# Facebook
# Twitter

# %%
nlp2.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer']

# %%
ner2 = nlp2.get_pipe('ner')

# %%
# add POI and street label to ner2
for _, annotations in train_data:
    for ent in annotations.get("entities"):
        ner2.add_label(ent[2])

# %%
disable_pipes = [pipe for pipe in nlp2.pipe_names if pipe != 'ner']

# %%
with nlp2.disable_pipes(*disable_pipes):
    optimizer = nlp2.resume_training()
    examples = []
    for text, annots in tqdm(train_data):
        try:
            examples.append(Example.from_dict(nlp2.make_doc(text), annots))
            warnings.filterwarnings("ignore")
        except:
            continue

    #nlp2.initialize(lambda: examples)    
    for i in tqdm(range(50)):
        random.shuffle(examples)
        losses = {}

        for batch in minibatch(examples, size=128):
            nlp2.update(batch, losses = losses, sgd = optimizer)
            #print('Losses: ', losses)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 300000/300000 [00:36<00:00, 8194.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 50/50 [7:34:37<00:00, 545.55s/it]

# %%
tokens = nlp2('banjarn scoo club, letjen supr, kutabanjarnegara banjarnegara')
for ent in tokens.ents:
    print(ent.text, ent.label_)
# Out:
# letjen supr STREET

# %%
nlp2.to_disk('./id_ner_address_model_2_from_en')

# %% [markdown]
# ## Model 3 ( with 'xx_ent_wiki_sm' ) but without nlp.initialize()

# %%
nlp3 = spacy.load('xx_ent_wiki_sm')

# %%
tokens3 = nlp3("I work at Google, Facebook and Twitter")

# %%
for ent in tokens3.ents:
    print(ent.text)
# Out:
# Google
# Facebook
# Twitter

# %%
nlp3.pipe_names
# Out:
# ['ner']

# %%
ner3 = nlp3.get_pipe('ner')

# %%
# add POI and street label to ner
for _, annotations in train_data:
    for ent in annotations.get("entities"):
        ner3.add_label(ent[2])

# %%
optimizer = nlp3.resume_training()
examples = []
for text, annots in tqdm(train_data):
    try:
        examples.append(Example.from_dict(nlp3.make_doc(text), annots))
        warnings.filterwarnings("ignore")
    except:
        continue
    
#nlp.initialize(lambda: examples)    
for i in tqdm(range(50)):
    random.shuffle(examples)
    losses = {}

    for batch in minibatch(examples, size=128):
        nlp3.update(batch, losses = losses, sgd = optimizer)
        #print('Losses: ', losses)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 300000/300000 [00:45<00:00, 6633.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 50/50 [7:44:30<00:00, 557.41s/it]

# %%
tokens = nlp3('banjarn scoo club, letjen supr, kutabanjarnegara banjarnegara')
for ent in tokens.ents:
    print(ent.text, ent.label_)
# Out:
# letjen supr STREET

# %%
nlp3.to_disk('./id_ner_address_model_3_multi_no_init')

# %% [markdown]
# ## Final Model ( with 'xx_ent_wiki_sm' ) multi-language model
# Same structure with model 1 cuz model 1 has the best performance

# %%
nlp4 = spacy.load('xx_ent_wiki_sm')

# %%
tokens = nlp4("I work at Google, Facebook and Twitter")

# %%
for ent in tokens.ents:
    print(ent.text)
# Out:
# Google
# Facebook
# Twitter

# %%
nlp4.pipe_names
# Out:
# ['ner']

# %%
ner = nlp4.get_pipe('ner')

# %%
# add POI and street label to ner
for _, annotations in train_data_final:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
optimizer = nlp4.resume_training()
examples = []
for text, annots in tqdm(train_data_final):
    try:
        examples.append(Example.from_dict(nlp4.make_doc(text), annots))
        warnings.filterwarnings("ignore")
    except:
        continue
    
nlp4.initialize(lambda: examples)    
for i in tqdm(range(120)):
    random.shuffle(examples)
    losses = {}

    for batch in minibatch(examples, size=128):
        nlp4.update(batch, losses = losses, sgd = optimizer)
        #print('Losses: ', losses)
    
    if i+1 >= 40 and i+1 % 20 == 0:
        nlp4.to_disk(f'./id_ner_address_final_{i+1}')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 300000/300000 [00:46<00:00, 6485.27it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 120/120 [16:51:22<00:00, 505.69s/it]

# %%
tokens = nlp4('banjarn scoo club, letjen supr, kutabanjarnegara banjarnegara')
for ent in tokens.ents:
    print(ent.text, ent.label_)
# Out:
# letjen supr STREET

# %%
nlp4.to_disk('./id_ner_address_final')

# %% [markdown]
# ## Continue training for final model with different batch size
# (end up with worse result than the previous model)

# %%
nlp5 = spacy.load('id_ner_address_final')

# %%
tokens = nlp5("I work at Google, Facebook and Twitter")

# %%
for ent in tokens.ents:
    print(ent.text)
# Out:
# I work at Google

# %%
nlp5.pipe_names
# Out:
# ['ner']

# %%
ner = nlp5.get_pipe('ner')

# %%
# add POI and street label to ner
for _, annotations in train_data_final:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
optimizer = nlp5.resume_training()
examples = []
for text, annots in tqdm(train_data_final):
    try:
        examples.append(Example.from_dict(nlp5.make_doc(text), annots))
        warnings.filterwarnings("ignore")
    except:
        continue
    
nlp5.initialize(lambda: examples)    
for i in tqdm(range(25)):
    random.shuffle(examples)
    losses = {}

    for batch in minibatch(examples, size=32):
        nlp5.update(batch, losses = losses, sgd = optimizer)
        #print('Losses: ', losses)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 300000/300000 [00:39<00:00, 7594.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 25/25 [7:50:29<00:00, 1129.17s/it]

# %%
tokens = nlp5('banjarn scoo club, letjen supr, kutabanjarnegara banjarnegara')
for ent in tokens.ents:
    print(ent.text, ent.label_)
# Out:
# letjen supr STREET

# %%
nlp5.to_disk('./id_ner_address_final_2')
